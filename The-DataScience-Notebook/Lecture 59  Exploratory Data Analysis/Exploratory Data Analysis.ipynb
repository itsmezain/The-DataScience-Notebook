# %% [markdown]
# # <center> <b>EDA

# %% [markdown]
# We are studying Data Analysis Process:
# 1. Asking Question
# 2. Data Wrangling
#    1. Gathering
#    2. Assessing
#    3. Cleaning
# 3. EDA
# 4. Drawing Conclusions
# 5. Presentation
#
# > We are gonna study 3 & 4 today.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic_dataset.csv')

# %%
'''
PassengerId: is the passenger ID unique to each passenger
Survived: is the passenger available to survived
Pclass: Traveling in which class from 1, 2 and 3. [1-> top, 3 -> bottom]
Name: Passenger name
Sex: sex of the passenger
Age: Age of the passenger
SibSp: did passenger traveling with sibling, or the husband
Parch: did passenger traveling with the parent or the children
Ticket: Ticket number of the passenger
Fare: Cost of the ticket
Cabin: Cabin number in which passenger was traveling
Embarked: From which station you board the titanic [there are 3 stations: C, S, Q each representation a City: Cherbourg, Southampton, Queenstown
'''

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <span style="font-size: 18px;"> <b> We are gonna do EDA step by step today

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers

# %% [markdown]
# <center> <span style="font-size: 44px; color: orange"> <b> Remember EDA is an iterative process

# %% [markdown]
# EDA steps:
#
# 	i. Column label => num, categorical, mixed
# 	ii. Univariate analysis
# 	iii. Bivariate analysis
# 	iv. Multivariate analysis
# 	v. Feature engineering -> outlier detection, missing value detection
# 	vi. Repeat

# %% [markdown]
# <span style="font-size: 24px; color: #91c100ff"> <b>Step 1: Always label the columns into 3 types: Numerical, Categorical and Mixed when doing EDA

# %% [markdown]
# #### Column Types
#
# - **Numerical** - Age, Fare ,PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch, Embarked
# - **Mixed** - Name, Ticket, Cabin

# %% [markdown]
# <span style="font-size: 24px; color: #91c100ff"> <b> Step 2: Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# #### The **shape** of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# > In simple term: Univariate Analysis tell us the:
# >> 1.distribution of the data: shape, central tendency and Dispersion
# >> 2. Potential issues: outliers, skewness, missing values

# %% [markdown]
# <span style="font-size: 22px; color: #f14400ff "> <b> Steps of doing Univariate Analysis on Numerical columns </b>
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %%
# We are gonna do Bivariate analysis on numerical columns but the PassengerID is not important for the predictive analysis, hence we except this column

# %% [markdown]
# <span style="font-size: 22px;"> <b>Age</b>
#
# <span style="font-size: 18px;"> <b>Conclusions:</b>
# - Age is almost normally distributed
# - 20% of the values are missing
# - There are some outliers

# %%
# Descriptive statistics
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Checking if age are really in decimal values
df[df['Age'] < 1] # yeah there are age in decimal values of small children
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78   0.83      0      2  248738   29.0000      NaN        S
# 305  0.92      1      2  113781  151.5500  C22 C26        S
# 469  0.75      2      1    2666   19.2583      NaN        C
# 644  0.75      2      1    2666   19.2583      NaN        C
# ...

# %%
# Data Vis for shape analysis
df['Age'].plot(kind='hist',bins=20) # small children and adults are more => looks like normal
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Skewness analysis
df['Age'].skew() # if this is number is close to 0 then your data is normal distributed
# if this is more positive then positively skewed data and if in negative then negative skewed data
# Out:
# np.float64(0.38910778230082704)

# %%
# Outliers detection
df['Age'].plot(kind='box') # there are outliers in the data
# Out:
# <Axes: >

# %%
df[df['Age'] > 65].sort_values(by='Age', ascending=False) # No big outliers hence no need to remove change any values
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 33            34         0       2                 Wheadon, Mr. Edward H
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0       27042  30.0000   A23        S
# 851  male  74.0      0      0      347060   7.7750   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# ...

# %%
df['Age'].isnull().sum() # missing values
# Out:
# np.int64(177)

# %%
# percentage of missing values

df['Age'].isnull().sum() / df['Age'].shape # 19 percentage of age is missing
# Out:
# array([0.1986532])

# %% [markdown]
# ---

# %% [markdown]
# <span style="font-size: 24px;"> <b>Fare</b>
#
# <span style="font-size: 20px;"> <b>Conclusions:</b>
# - The data is highly(positively) skewed
# - Fare column actually contains the group fare and not the individual fare(This might be an issue)
# - We need to create a new col called individual fare

# %%
# Descriptive statistics
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# Data Vis for shape analysis
df['Fare'].plot(kind='hist', bins=20) # fare is negatively skewed that means many people are traveling in low cost and few has paid high cost
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Skewness analysis
df['Fare'].skew() # highly skewed
# Out:
# np.float64(4.787316519674893)

# %%
df['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Fare'] > 250] # as we can see that fare of the same ticket number are same hence the given fare price is a grouped fare, not individual fare
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <span style="font-size: 22px; color: #f14400ff "> <b> Steps of doing Univariate Analysis on Categorical</b>
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# <span style="font-size: 24px;"> <b>Survive</b>
#
# <span style="font-size: 20px;"> <b>Conclusions:</b>
# - Survival count is 342, died count is 549
# - Around only 61% percentage of people survived, rest of the 39 died

# %%
# Descriptive Statistics
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct= '%0.1f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <span style="font-size: 24px;"> <b>Pclass</b>
#
# <span style="font-size: 20px;"> <b>Conclusions:</b>
# - There are 216 passenger in the first class, 184 in the second class and 491 in the third class
# - Interestingly, 1 first passenger are more then 2nd class, bcz titanic was a luxurious cruse ship. (why this is happening maybe something to do with the fare price maybe)
# - 55.1% of the passenger were traveling in 3rd class, 20.7 in the second class and 24.2 in the first class

# %%
# Descriptive Statistics
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <span style="font-size: 24px;"> <b>Sex</b>
#
# <span style="font-size: 20px;"> <b>Conclusions:</b>
# - There are 577 male and 314 female
# - Hence male percentage is 64.8% and female percentage is 35.2%

# %%
# Descriptive Statistics
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# Data Vis
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='count'>

# %%
# missing value
df['Sex'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <span style="font-size: 24px;"> <b>SibSp</b>
#
# <span style="font-size: 20px;"> <b>Conclusions:</b>
# - Most of the people are solo traveling or with one wife, sister, brother etc
# - There are 5 families which have 5 members and 7 families with 7 members
# - But largely 68.2% are solo traveling with second largest begin with one family member 23.5%

# %%
# Descriptive Statistics
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
# Data Vis
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['SibSp'].value_counts().plot(kind='pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='count'>

# %%
# missing value
df['SibSp'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <span style="font-size: 24px;"> <b>Parch</b>
#
# <span style="font-size: 20px;"> <b>Conclusions:</b>
# - Most of the people are solo traveling, percentage is 76.1%
# - Then most of the families have 1 or 2 child or parent: percentage for 1: 13.2%, percentage for 2: 9.0%
# - Other families with 3,4,5 and 6 Parch are just 15
# - Parch and SibSp cols can be merged to form a new col call family_size
# - Can create a new col called is_alone

# %%
# Descriptive Statistics
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
# Data Vis
df['Parch'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
df['Parch'].value_counts().plot(kind='pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Parch'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <span style="font-size: 24px;"> <b>Embarked</b>
#
# <span style="font-size: 20px;"> <b>Conclusions:</b>
# - Since the ship was started from S that why 72.4% of people onboard the ship from here

# %%
# Descriptive Statistics
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Data Vis
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].isnull().sum()
# Out:
# np.int64(2)

# %% [markdown]
# > If we want to do univariate analysis on the mixed columns, then we have to do feature engineering right now they are not in the stage to do the feature engineering

# %% [markdown]
# <span style="font-size: 24px; color: #91c100ff"> <b><b>Step 3: Steps of doing Bivariate Analysis</b></b>
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# - As there are 11 column, if we are gonna do bivariate analysis on all the column then it would be 11*10 which is gonna take too much time
#
# > Hence we are only gonna take main columns in this case: survived, sex and age

# %%
# Now we are gonna do bivariate analysis on the survived with all the other columns

# %% [markdown]
# <span style="font-size: 18px;"> <b>Survived and Pclass</b>
#
# <span style="font-size: 18px;"> <b>Summary:</b>
# - P1 is very safe there is 62% chance a passenger gonna survived whereas Pclass 3 is dangerous class there is 75% chance a passenger gonna die

# %%
# survived and Pclass => both categorical hence gonna apply 3rd rule written above.

pd.crosstab(df['Survived'], df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
sns.countplot(df, x='Pclass', hue='Survived', palette='Set2')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# As we cannot conclude anything useful only from the number, so we are gonna use percentage to see understand relation and hidden pattern

# %%
pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(df, x='Pclass', y='Survived',)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# <span style="font-size: 18px;"> <b>Survived and Sex</b>
#
# <span style="font-size: 18px;"> <b>Summary:</b>
# - Female are more safe as there is only 25% chance a female passenger gonna die and there is 81% chance a male gonna die

# %%
# survived and Sex => both categorical hence gonna apply 3rd rule written above.

pd.crosstab(df['Survived'], df['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
sns.countplot(df, x='Sex', hue='Survived', palette='Set2')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# As we cannot conclude anything useful only from the number, so we are gonna use percentage to see understand relation and hidden pattern

pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
sns.barplot(df, x='Sex', y='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.heatmap(pd.crosstab(df['Survived'], df['Sex'], normalize='columns')*100)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# <span style="font-size: 18px;"> <b>Survived and Embarked</b>
#
# <span style="font-size: 18px;"> <b>Summary:</b>
# - The Q and S look similar to each other but the C has 55% of people survived which is above average.
# - This may be happen because of 2 things: in the C city maybe more female passenger onboard or the more Pclass 1 passenger onboard the ship (we need to verify which is true)

# %%
# survived and Embarked => both categorical hence gonna apply 3rd rule written above.

pd.crosstab(df['Embarked'], df['Survived'])
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %%
sns.countplot(df, x='Embarked', hue='Survived', palette='Set2')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
# As we cannot conclude anything useful only from the number, so we are gonna use percentage to see understand relation and hidden pattern

pd.crosstab(df['Survived'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
sns.barplot(df, x='Embarked', y='Survived',)
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %% [markdown]
# <span style="font-size: 18px;"> <b>Embarked and Sex</b>
#
# <span style="font-size: 18px;"> <b>Summary:</b>
# - In the S city there are more male onboarding the ship but the in the C and S city male are almost equal hence the C city survived more than average because of Sex is not hold TRUE (we ned to test with Pclass to verify now)

# %%
# Embarked and Sex => both categorical hence gonna apply 3rd rule written above.

pd.crosstab(df['Sex'], df['Embarked'])
# Out:
# Embarked   C   Q    S
# Sex
# female    73  36  203
# male      95  41  441

# %%
sns.countplot(df, x='Sex', hue='Embarked', palette='Set2')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# As we cannot conclude anything useful only from the number, so we are gonna use percentage to see understand relation and hidden pattern

pd.crosstab(df['Sex'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
sns.histplot(
    data=df,
    x="Embarked",
    hue="Sex",
    multiple="fill"
)
# Out:
# <Axes: xlabel='Embarked', ylabel='Count'>

# %% [markdown]
# <span style="font-size: 18px;"> <b>Embarked and Pclass</b>
#
# <span style="font-size: 18px;"> <b>Summary:</b>
# - From the C city, 50% onboard travels are of Pclass 1 that why Survival rate of Embarked from City C is more than City Q and S.
# - Why Q and S city have lees survival rate because City Q has 93% Pclass 3 travelers whereas City S have only 31% of female and 54% of Pclass 3 travelers.

# %%
# Embarked and Pclass => both categorical hence gonna apply 3rd rule written above.

pd.crosstab(df['Pclass'], df['Embarked'])
# Out:
# Embarked   C   Q    S
# Pclass
# 1         85   2  127
# 2         17   3  164
# 3         66  72  353

# %%
sns.countplot(df, x='Pclass', hue='Embarked', palette='Set2')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# As we cannot conclude anything useful only from the number, so we are gonna use percentage to see understand relation and hidden pattern

pd.crosstab(df['Pclass'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
sns.histplot(
    data=df,
    x="Embarked",
    hue="Pclass",
    multiple="fill"
)
# Out:
# <Axes: xlabel='Embarked', ylabel='Count'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# > As SisSp and Parch are family member and fare is grouped fare so that why first we apply feature engineering and then do the analysis on them

# %% [markdown]
# <span style="font-size: 22px; color: #f14400ff "> <b> Bivariate Analysis on the Numerical and Categorical column</b>

# %% [markdown]
# <span style="font-size: 18px;"> <b>Survived and Age</b>
#
# <span style="font-size: 18px;"> <b>Summary:</b>
# - Children have higher chances of survival whereas adult have less.
# - Middle age people are generally rich, so more of them travelling in Pclass 1 and that why have chances of survival.
# - Old age people are weak that why they died have more chances of dying.

# %%
df[df['Survived'] == 1]['Age'].plot(kind='kde', label = 'Survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde', label = 'No survived')

plt.legend()
plt.show()

# %%
df[df['Pclass'] == 1]['Age'].mean()
# Out:
# np.float64(38.233440860215055)

# %%
df[df['Survived'] == 1]['Age'].plot(kind='hist', label = 'Survived')
df[df['Survived'] == 0]['Age'].plot(kind='hist', label = 'No survived')

plt.legend()
plt.show()

# %% [markdown]
# <span style="font-size: 18px;"> <b>Age and Pclass</b>
#
# <span style="font-size: 18px;"> <b>Summary:</b>
# - In pclass 3 peak is around between 18 to 25
# - In pclass 2 peak is around between 26 to 32
# - In pclass 1 peak is around between 32 to 45
# - This can be explain as people grow older they generally become more rich
#
# - PClass 1 < Pclass 2 < Pclass 3, number of children, Pclass have less number of children with them in comparison to Pclass 2 and Pclass 3

# %%
df[df['Pclass'] == 1]['Age'].plot(kind='kde', label = 'Pclass 1')
df[df['Pclass'] == 2]['Age'].plot(kind='kde', label = 'Pclass 2')
df[df['Pclass'] == 3]['Age'].plot(kind='kde', label = 'Pclass 3')

plt.legend()
plt.show()

# %% [markdown]
# <span style="font-size: 24px; color: #91c100ff"> <b><b>Step 4: Feature Engineering</b></b>

# %% [markdown]
# 1- Fare is grouped fare, we have to create a column for individual fare.

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df['SibSp'] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# > As this family should have 8+2+1 = 11 members but have 8 only (SisSp, Parch and himslef) hence data is not complete
# >> Remaining data is in test.csv

# %%
test_df = pd.read_csv('test_titanic_dataset.csv')
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
merge_data = pd.concat([df, test_df])

# %%
merge_data.shape
# Out:
# (1309, 12)

# %% [markdown]
# > Now, data is completed you can extract exact family members count, using which individual fare can be easily calculated

# %%
merge_data[merge_data['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
merge_data['individual_cost'] = merge_data['Fare'] / (merge_data['SibSp'] + merge_data['Parch'] + 1)

# %%
df = merge_data
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  individual_cost
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %% [markdown]
# <span style="font-size: 18px;"> <b>Individual fare feature has been extracted and have to analyze it

# %%
df['individual_cost'].plot(kind='box') # there are many outliers
# Out:
# <Axes: >

# %%
df[['Fare', 'individual_cost']].describe()
# Out:
#               Fare  individual_cost
# count  1308.000000      1308.000000
# mean     33.295479        20.518215
# std      51.758668        35.774337
# min       0.000000         0.000000
# 25%       7.895800         7.452767
# 50%      14.454200         8.512483
# 75%      31.275000        24.237500
# max     512.329200       512.329200

# %%
df[df['individual_cost'] > 512]
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 258          259       1.0       1        Ward, Miss. Anna  female  35.0
# 737          738       1.0       1  Lesurer, Mr. Gustave J    male  35.0
#
#      SibSp  Parch    Ticket      Fare Cabin Embarked  individual_cost
# 258      0      0  PC 17755  512.3292   NaN        C         512.3292
# 737      0      0  PC 17755  512.3292  B101        C         512.3292

# %% [markdown]
# #### Our method to calculate the individual cost is wrong because unmarried couple there also traveling or friends in general are traveling hence this method fails

# %% [markdown]
# <span style="font-size: 20px;"> <b>So correct way to by extracting the Ticket number of the passenger who are traveling on that same ticket number and then dividing the number of people traveling of that with the fare.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  individual_cost
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
df = df.drop('individual_cost', axis=1)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# counting number of passenger per ticket number
df['Ticket_Count'] = df.groupby('Ticket')['Ticket'].transform('count')
df['Ticket_Count']
# Out:
# 0      1
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 413    1
# 414    3
# 415    1
# 416    1
# 417    3
# Name: Ticket_Count, Length: 1309, dtype: int64

# %%
# Calculate individual fare
df['Individual_Fare'] = df['Fare'] / df['Ticket_Count']

df['Individual_Fare']
# Out:
# 0       7.250000
# 1      35.641650
# 2       7.925000
# 3      26.550000
# 4       8.050000
#          ...
# 413     8.050000
# 414    36.300000
# 415     7.250000
# 416     8.050000
# 417     7.452767
# Name: Individual_Fare, Length: 1309, dtype: float64

# %%
df['Individual_Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[['Fare', 'Individual_Fare']].describe()
# Out:
#               Fare  Individual_Fare
# count  1308.000000      1308.000000
# mean     33.295479        14.757627
# std      51.758668        13.555638
# min       0.000000         0.000000
# 25%       7.895800         7.550000
# 50%      14.454200         8.050000
# 75%      31.275000        15.008325
# max     512.329200       128.082300

# %%
# seeing number of people paying more than 15
df[df['Individual_Fare'] > 15]['Ticket'].nunique()
# Out:
# 192

# %%
df[df['Individual_Fare'] > 30]['Ticket'].nunique()
# Out:
# 74

# %%
df[df['Individual_Fare'] > 15]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2       1.0       1
# 3              4       1.0       1
# 6              7       0.0       1
# 9             10       1.0       2
# 11            12       1.0       1
# ..           ...       ...     ...
# 403         1295       NaN       1
# 404         1296       NaN       1
# 407         1299       NaN       1
# 411         1303       NaN       1
# 414         1306       NaN       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Individual_Fare'].hist(bins=40)
# Out:
# <Axes: >

# %%
df['Individual_Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# <center> <b>Feature Engineering 2- Make a fare categories column

# %% [markdown]
# <span style="font-size: 18px;"> <b>Create fare categories for better visualization

# %%
df['Fare_Category'] = pd.qcut(df['Individual_Fare'], q=4, labels=['Low', 'Medium', 'High', 'Very High'])

df['Fare_Category']
# Out:
# 0            Low
# 1      Very High
# 2         Medium
# 3      Very High
# 4         Medium
#          ...
# 413       Medium
# 414    Very High
# 415          Low
# 416       Medium
# 417          Low
# Name: Fare_Category, Length: 1309, dtype: category
# Categories (4, object): ['Low' < 'Medium' < 'High' < 'Very High']

# %% [markdown]
# <span style="font-size: 18px;"> <b>Survived and Fare_Category</b>
#
# <span style="font-size: 18px;"> <b>Summary:</b>
# - Very High category passenger survived 63%
# - High category passenger survived 39%
# - While Low and medium category passenger survived 26% and 25% respectively.

# %%
pd.crosstab(df['Survived'],df['Fare_Category'],normalize='columns')*100
# Out:
# Fare_Category        Low     Medium       High  Very High
# Survived
# 0.0            73.160173  74.889868  60.648148   36.40553
# 1.0            26.839827  25.110132  39.351852   63.59447

# %%
(pd.crosstab(df['Survived'],df['Fare_Category'],normalize='columns')*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# <center> <b>Feature Engineering 3- Surname Column

# %%
df['Surname'] = df['Name'].str.split(',').str.get(0)

df['Surname']
# Out:
# 0             Braund
# 1            Cumings
# 2          Heikkinen
# 3           Futrelle
# 4              Allen
#            ...
# 413          Spector
# 414    Oliva y Ocana
# 415          Saether
# 416             Ware
# 417            Peter
# Name: Surname, Length: 1309, dtype: object

# %% [markdown]
# <center> <b>Feature Engineering 4- Title Column

# %%
df['Title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split('.').str.get(0)

df['Title']
# Out:
# 0          Mr
# 1         Mrs
# 2        Miss
# 3         Mrs
# 4          Mr
#         ...
# 413        Mr
# 414      Dona
# 415        Mr
# 416        Mr
# 417    Master
# Name: Title, Length: 1309, dtype: object

# %%
df['Title'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Major             2
# Mlle              2
# Ms                2
# Mme               1
# Don               1
# Sir               1
# Lady              1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: count, dtype: int64

# %%
# Group titles by social status and characteristics
title_mapping = {
    # Keep common titles
    'Mr': 'Mr',
    'Miss': 'Miss',
    'Mrs': 'Mrs',
    'Master': 'Master',
    
    # French variants - merge with English equivalents
    'Mlle': 'Miss',  # Mademoiselle = Miss
    'Ms': 'Miss',
    'Mme': 'Mrs',    # Madame = Mrs
    
    # Nobility/Royalty - high social status
    'Lady': 'Royalty',
    'Sir': 'Royalty',
    'the Countess': 'Royalty',
    'Dona': 'Royalty',
    'Don': 'Royalty',
    'Jonkheer': 'Royalty',
    
    # Military/Professional officers
    'Col': 'Officer',
    'Major': 'Officer',
    'Capt': 'Officer',
    
    # Professional/Religious
    'Dr': 'Professional',
    'Rev': 'Professional'
}

df['Title'] = df['Title'].map(title_mapping)
df['Title']
# Out:
# 0           Mr
# 1          Mrs
# 2         Miss
# 3          Mrs
# 4           Mr
#         ...
# 413         Mr
# 414    Royalty
# 415         Mr
# 416         Mr
# 417     Master
# Name: Title, Length: 1309, dtype: object

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr              757
# Miss            264
# Mrs             198
# Master           61
# Professional     16
# Officer           7
# Royalty           6
# Name: count, dtype: int64

# %%
# Check survival rates for each grouped title
df.groupby('Title')['Survived'].agg(['mean', 'count'])
# Out:
#                   mean  count
# Title
# Master        0.575000     40
# Miss          0.702703    185
# Mr            0.156673    517
# Mrs           0.793651    126
# Officer       0.400000      5
# Professional  0.230769     13
# Royalty       0.600000      5

# %%
pd.crosstab(df['Survived'],df['Title'],normalize='columns')*100
# Out:
# Title     Master      Miss         Mr        Mrs  Officer  Professional  \
# Survived
# 0.0         42.5  29.72973  84.332689  20.634921     60.0     76.923077
# 1.0         57.5  70.27027  15.667311  79.365079     40.0     23.076923
#
# Title     Royalty
# Survived
# 0.0          40.0
# 1.0          60.0

# %%
(pd.crosstab(df['Survived'],df['Title'],normalize='columns')*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      843
# female    466
# Name: count, dtype: int64

# %% [markdown]
# <center> <b>Feature Engineering 5- Cabin

# %%
df['Cabin'].isnull().sum() # 1014 of the cabin is missing
# Out:
# np.int64(1014)

# %%
df['Cabin'].isnull().sum()/ len(df['Cabin']) * 100 # 77%of the cabin is missing
# Out:
# np.float64(77.46371275783041)

# %%
df['Cabin'].value_counts().head(20)
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F4                 4
# C78                4
# D                  4
# F2                 4
# B96 B98            4
# C22 C26            4
# A34                3
# E34                3
# C101               3
# B51 B53 B55        3
# E101               3
# B58 B60            3
# D26                2
# D10 D12            2
# E33                2
# C93                2
# Name: count, dtype: int64

# %%
# Extract deck letter from cabin
df['Deck'] = df['Cabin'].str[0]
df['Deck']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 413    NaN
# 414      C
# 415    NaN
# 416    NaN
# 417    NaN
# Name: Deck, Length: 1309, dtype: object

# %%
# Fill missing values with 'U' for Unknown
df['Deck'] = df['Deck'].fillna('U')
df['Deck']
# Out:
# 0      U
# 1      C
# 2      U
# 3      C
# 4      U
#       ..
# 413    U
# 414    C
# 415    U
# 416    U
# 417    U
# Name: Deck, Length: 1309, dtype: object

# %%
# Check survival rates by deck
df.groupby('Deck')['Survived'].mean().sort_values(ascending=False)
# Out:
# Deck
# D    0.757576
# E    0.750000
# B    0.744681
# F    0.615385
# C    0.593220
# G    0.500000
# A    0.466667
# U    0.299854
# T    0.000000
# Name: Survived, dtype: float64

# %%
pd.crosstab(df['Deck'], df['Pclass'])
# Out:
# Pclass   1    2    3
# Deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# T        1    0    0
# U       67  254  693

# %%
pd.crosstab(df['Survived'],df['Deck'],normalize='columns')*100
# Out:
# Deck              A          B          C          D     E          F     G  \
# Survived
# 0.0       53.333333  25.531915  40.677966  24.242424  25.0  38.461538  50.0
# 1.0       46.666667  74.468085  59.322034  75.757576  75.0  61.538462  50.0
#
# Deck          T          U
# Survived
# 0.0       100.0  70.014556
# 1.0         0.0  29.985444

# %%
(pd.crosstab(df['Survived'],df['Deck'],normalize='columns')*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
(pd.crosstab(df['Deck'],df['Survived'],normalize='index')*100).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Deck'>

# %%
# Create "Has Cabin" Binary Feature

# Binary indicator for cabin availability
df['Has_Cabin'] = df['Cabin'].notna().astype(int)
df['Has_Cabin']
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Has_Cabin, Length: 1309, dtype: int64

# %%
pd.crosstab(df['Survived'],df['Has_Cabin'],normalize='columns')*100
# Out:
# Has_Cabin          0          1
# Survived
# 0.0        70.014556  33.333333
# 1.0        29.985444  66.666667

# %%
(pd.crosstab(df['Survived'],df['Has_Cabin'],normalize='columns')*100).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# <span style="font-size: 24px; color: #91c100ff"> <b><b>Step 5: Multivariate Analysis</b></b>

# %%
df.corr(numeric_only=True)
# Out:
#                  PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId         1.000000 -0.005007 -0.038354  0.028814 -0.055224
# Survived           -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# Pclass             -0.038354 -0.338481  1.000000 -0.408106  0.060832
# Age                 0.028814 -0.077221 -0.408106  1.000000 -0.243699
# SibSp              -0.055224 -0.035322  0.060832 -0.243699  1.000000
# Parch               0.008942  0.081629  0.018322 -0.150917  0.373587
# Fare                0.031428  0.257307 -0.558629  0.178740  0.160238
# Ticket_Count       -0.010350  0.064962 -0.078554 -0.185284  0.679444
# Individual_Fare     0.021579  0.288337 -0.770976  0.361767 -0.050984
# Has_Cabin          -0.000208  0.316912 -0.713857  0.289740 -0.009064
#
#                     Parch      Fare  Ticket_Count  Individual_Fare  Has_Cabin
# PassengerId      0.008942  0.031428     -0.010350         0.021579  -0.000208
# ...

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId       -0.005007
# Survived           1.000000
# Pclass            -0.338481
# Age               -0.077221
# SibSp             -0.035322
# Parch              0.081629
# Fare               0.257307
# Ticket_Count       0.064962
# Individual_Fare    0.288337
# Has_Cabin          0.316912
# Name: Survived, dtype: float64

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[330], line 1
# ----> 1 sns.pairplot(df)
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\axisgrid.py:2149, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2147 diag_kws.setdefault("legend", False)
#    2148 if diag_kind == "hist":
# -> 2149     grid.map_diag(histplot, **diag_kws)
#    2150 elif diag_kind == "kde":
#    2151     diag_kws.setdefault("fill", True)
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\axisgrid.py:1513, in PairGrid.map_diag(self, func, **kwargs)
#    1511     plot_kwargs.setdefault("hue_order", self._hue_order)
#    1512     plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1513     func(x=vector, **plot_kwargs)
#    1514     ax.legend_ = None
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
sns.pairplot(df)
