# %% [markdown]
# # <center> <b>Smartprix Dataset Cleaning

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('smartprix_mobiles.csv')

# %%
df.head()
# Out:
#                Product_Name   Price  Rating  Spec_Score  has_dual_sim  has_3g  \
# 0  Samsung Galaxy S25 Ultra  108460    4.15          93             1       1
# 1     Samsung Galaxy S25 FE   59999    4.70          86             1       1
# 2      OnePlus Nord CE 5 5G   24998    4.10          83             1       1
# 3           Realme Narzo 90   16999    4.40          72             1       1
# 4             Vivo T3 Ultra   22799    4.10          82             1       1
#
#    has_4g  has_5g  has_nfc  has_ir_blaster  ... rear_camera_mp  \
# 0       1       1        1               0  ...          200.0
# 1       1       1        1               0  ...           50.0
# 2       1       1        0               1  ...           50.0
# 3       1       1        0               0  ...           50.0
# 4       1       1        0               0  ...           50.0
#
#   rear_camera_secondary_mp  rear_camera_tertiary_mp  rear_camera_count  \
# 0                     12.0                      0.0                  4
# 1                     12.0                      8.0                  3
# 2                      8.0                     16.0                  2
# 3                      2.0                     50.0                  2
# 4                      8.0                     50.0                  2
#
#    card_supported  operating_system  \
# 0               0       Android v15
# 1               0       Android v16
# 2               1       Android v15
# 3               1       Android v15
# 4               1       Android v14
#
#                                         Product_Link  \
# 0  https://www.smartprix.com/mobiles/samsung-gala...
# 1  https://www.smartprix.com/mobiles/samsung-gala...
# 2  https://www.smartprix.com/mobiles/oneplus-nord...
# 3  https://www.smartprix.com/mobiles/realme-narzo...
# 4  https://www.smartprix.com/mobiles/vivo-t3-ultr...
#
#                                            Image_URL  \
# 0  https://cdn1.smartprix.com/rx-i3jZEfawx-w280-h...
# 1  https://cdn1.smartprix.com/rx-igNNWnxPy-w280-h...
# 2  https://cdn1.smartprix.com/rx-i3qMJS8fr-w280-h...
# 3  https://cdn1.smartprix.com/rx-iuYfvkRUc-w280-h...
# 4  https://cdn1.smartprix.com/rx-iKhtBU6Ja-w280-h...
#
#                                       Specifications  device_type
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC ...   smartphone
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC ...   smartphone
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster...   smartphone
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi | Dimensity...   smartphone
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi | Dimensity...   smartphone
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Product_Name', 'Price', 'Rating', 'Spec_Score', 'has_dual_sim',
#        'has_3g', 'has_4g', 'has_5g', 'has_nfc', 'has_ir_blaster',
#        'processor_name', 'cores', 'cpu_speed_ghz', 'ram_gb', 'rom_gb',
#        'battery_capacity_mah', 'fast_charging_available',
#        'fast_charging_speed_w', 'display_size_inches', 'resolution_width',
#        'resolution_height', 'display_frequency_hz', 'front_camera_mp',
#        'front_camera_secondary_mp', 'rear_camera_mp',
#        'rear_camera_secondary_mp', 'rear_camera_tertiary_mp',
#        'rear_camera_count', 'card_supported', 'operating_system',
#        'Product_Link', 'Image_URL', 'Specifications', 'device_type'],
#       dtype='object')

# %% [markdown]
# <span style="font-size: 18px;"> <b>Adding the brand_name column in the df

# %%
brand_name = df['Product_Name'].str.split(' ').str.get(0)
brand_name
# Out:
# 0        Samsung
# 1        Samsung
# 2        OnePlus
# 3         Realme
# 4           Vivo
#           ...
# 1015        Vivo
# 1016        itel
# 1017    Motorola
# 1018        Poco
# 1019        itel
# Name: Product_Name, Length: 1020, dtype: object

# %%
df.insert(1, 'brand_name', brand_name)

# %%
df['brand_name'] =  df['brand_name'].str.lower().str.strip()

# %%
df.columns
# Out:
# Index(['Product_Name', 'brand_name', 'Price', 'Rating', 'Spec_Score',
#        'has_dual_sim', 'has_3g', 'has_4g', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'cores', 'cpu_speed_ghz', 'ram_gb',
#        'rom_gb', 'battery_capacity_mah', 'fast_charging_available',
#        'fast_charging_speed_w', 'display_size_inches', 'resolution_width',
#        'resolution_height', 'display_frequency_hz', 'front_camera_mp',
#        'front_camera_secondary_mp', 'rear_camera_mp',
#        'rear_camera_secondary_mp', 'rear_camera_tertiary_mp',
#        'rear_camera_count', 'card_supported', 'operating_system',
#        'Product_Link', 'Image_URL', 'Specifications', 'device_type'],
#       dtype='object')

# %%
# Show all columns
pd.set_option('display.max_columns', None)

# Show all rows
pd.set_option('display.max_rows', None)

# Optional: Show full content of each cell (prevent "..." in text)
pd.set_option('display.max_colwidth', None)

# %%
df['processor_name'].isnull().sum()
# Out:
# np.int64(52)

# %%
df['processor_name'].value_counts() # Octa core, NO Wifi and
# Out:
# processor_name
# Dimensity 6300              120
# Dimensity 7300               28
# Snapdragon 4 Gen2            24
# Snapdragon 7 Gen3            22
# Snapdragon 7s Gen3           18
# Snapdragon 8s Gen3           18
# Dimensity 6100 Plus          18
# Snapdragon 695               17
# Exynos 1380                  17
# Snapdragon 8 Elite           15
# Dimensity 7400               15
# Dimensity 7050               14
# Snapdragon 7s Gen2           14
# Snapdragon 8 Gen3            13
# Snapdragon 7 Gen4            13
# Dimensity 7300 Ultimate      12
# Snapdragon 6 Gen1            12
# Snapdragon 8s Gen4           10
# Dimensity 7300 Energy        10
# Snapdragon 6s Gen3           10
# Exynos 1330                  10
# Dimensity 8350               10
# Apple A19 Pro                10
# Dimensity 6400                9
# Exynos 2400                   9
# Unisoc T7250                  9
# Snapdragon 7s Gen 2           9
# Snapdragon 8 Gen2             9
# Bionic A18                    9
# Helio G85                     8
# Dimensity 7020                8
# Dimensity 6080                8
# Snapdragon 8 Elite Gen 5      7
# Exynos 1480                   7
# Snapdragon 8Elite             7
# Dimensity 8200                7
# Bionic A18 Pro                7
# Dimensity 9500                7
# Helio                         7
# Dimensity 6020                7
# Snapdragon 7 Gen1             7
# Snapdragon 680                7
# Snapdragon 870                6
# Snapdragon 7+ Gen3            6
# Snapdragon 8 Gen1             6
# Snapdragon 8 Gen 2            6
# Tensor G4                     6
# Dimensity 7025 Ultra          6
# Dimensity 7400 Ultra          6
# Unisoc T606                   5
# Snapdragon 8+ Gen1            5
# Dimensity 9300 Plus           5
# Snapdragon 4s Gen2            5
# Dimensity 9200 Plus           5
# Dimensity 6400 Max            5
# Dimensity 9400                5
# Unisoc T612                   5
# Unisoc T760                   5
# Snapdragon 6 Gen4             5
# Helio G36                     5
# Dimensity 1080                5
# Dimensity 9400e               4
# Bionic A15                    4
# Dimensity 7300 Pro            4
# Tensor G5                     4
# Helio G99                     4
# Dimensity 7300 Ultra          4
# Helio G35                     4
# Unisoc T765                   4
# Dimensity 7300 E              4
# Unisoc T615                   4
# Dimensity 8450                4
# Dimensity 7025                4
# Dimensity 7200                4
# Helio G88                     3
# Helio  G96                    3
# Exynos 1280                   3
# Dimensity  8100               3
# Dimensity 7300 Plus           3
# Snapdragon 7s Gen 3           3
# Exynos 1580                   3
# Dimensity 8400-MAX            3
# Snapdragon 6 Gen3             3
# Bionic A16                    3
# Dimensity 8350 Extreme        3
# Dimensity 7360 Turbo          3
# Dimensity 8350 Apex           3
# Unisoc 6531F                  3
# Octa Core                     3
# Snapdragon 888                3
# Dimensity 700 5G              3
# Snapdragon  732G              3
# Dimensity 8350 Ultra          3
# Snapdragon 7 Gen 4            3
# Unisoc T107                   3
# Dimensity 7200 Pro            3
# Dimensity 7060                3
# Snapdragon 778G Plus          3
# Snapdragon 8 Gen 3            3
# Dimensity 7300X               3
# Dimensity 1300                3
# Unisoc T603                   3
# Dimensity 8100 Max            3
# Dimensity 7200 Ultra          3
# Snapdragon 778G               2
# Snapdragon 4 Gen2 AE          2
# Snapdragon 8 Gen5             2
# Dimensity 8400 Ultra          2
# Snapdragon  662               2
# Exynos 2100                   2
# Snapdragon 4 Gen 2 AE         2
# Exynos 2400e                  2
# Apple A19                     2
# Dimensity 7030                2
# Unisoc 6533G                  2
# Dimensity 7400X               2
# Dimensity 7350 Pro 5G         2
# Snapdragon  8+ Gen1           2
# No Wifi                       2
# Snapdragon  8 Gen1            2
# Snapdragon  888               2
# Unisoc T127                   2
# Snapdragon 6s 4G Gen1         2
# Unisoc T8200                  2
# Unisoc UMS9230E               2
# Dimensity 8350 Ultimate       2
# Tensor                        2
# Dimensity  810 5G             2
# Dimensity 8020                2
# Snapdragon 4 Gen1             2
# Dimensity 8300 Ultra          2
# Snapdragon  695               2
# Snapdragon 4 Gen 1            2
# Snapdragon  680               2
# Dimensity 800U                2
# Exynos 2500                   2
# Snapdragon 636                2
# Snapdragon 435                2
# Helio G50                     2
# Helio G81                     1
# Snapdragon 6s Gen4            1
# Unisoc T7225                  1
# Snapdragon 710                1
# Dimensity 9300                1
# Google Tensor G2              1
# Tensor G2                     1
# Dimensity 8200 Ultimate       1
# Google  Tensor G2             1
# Exynos 2200                   1
# Dimensity 9000 Plus           1
# Snapdragon 665                1
# Spreadtrum                    1
# Dimensity 9000                1
# MTK MT6739                    1
# Snapdragon 888+               1
# Google  Tensor                1
# Snapdragon 778G+              1
# Snapdragon 7 Gen1 AE          1
# Snapdragon 855+               1
# MTK6739                       1
# Helio G81 Ultra               1
# Helio G96                     1
# Snapdragon 845                1
# Bionic A17 Pro                1
# Qualcomm Snapdragon 625       1
# Snapdragon 732G               1
# A13 Bionic                    1
# Unisoc 9863A                  1
# Exynos 850                    1
# Helio  G85                    1
# Dimensity 930                 1
# Dimensity  900                1
# Helio 6739                    1
# Snapdragon 782G               1
# Dimensity 900                 1
# Exynos 9825                   1
# Exynos 9611                   1
# Dimensity 700                 1
# Snapdragon 865                1
# Tiger T612                    1
# Helio G91                     1
# Tiger T616                    1
# Helio  G99                    1
# Helio G95                     1
# Snapdragon 765G               1
# Snapdragon  778G              1
# Dimensity  920 5G             1
# Helio  G95                    1
# Snapdragon 720G               1
# Helio  G90T                   1
# Unisoc T7100                  1
# UNISOC T7100                  1
# Helio MT6737                  1
# AMD                           1
# Snapdragon 6s Gen1 4G         1
# Name: count, dtype: int64

# %%
df['cores'].isnull().sum()
# Out:
# np.int64(56)

# %%
df[(df['processor_name'] == 'Octa Core') | (df['processor_name'] == 'No Wifi')]
# Out:
#            Product_Name brand_name  Price  Rating  Spec_Score  has_dual_sim  \
# 494  Motorola Moto A300   motorola   1199    4.05          14             1
# 738   Lava Bold N1 Lite       lava   5999    4.45          57             1
# 840             Lava O3       lava   5799    4.65          55             1
# 859             Lava O3       lava   5949    4.15          57             1
# 948    Snexian Bold 40K    snexian   1149    4.25          12             1
#
#      has_3g  has_4g  has_5g  has_nfc  has_ir_blaster processor_name  \
# 494       0       0       0        0               0        No Wifi
# 738       1       1       0        0               0      Octa Core
# 840       1       1       0        0               0      Octa Core
# 859       1       1       0        0               0      Octa Core
# 948       0       0       0        0               0        No Wifi
#
#          cores  cpu_speed_ghz  ram_gb  rom_gb  battery_capacity_mah  \
# 494        NaN         0.0015   0.004   0.031                  1000
# 738  Octa Core            NaN   3.000  64.000                  5000
# 840  Octa Core            NaN   3.000  64.000                  5000
# 859  Octa Core            NaN   4.000  64.000                  5000
# 948        NaN         0.0010   0.031   0.031                  2500
#
#      fast_charging_available  fast_charging_speed_w  display_size_inches  \
# 494                        0                    0.0                 2.00
# 738                        1                   10.0                 6.75
# 840                        1                   10.0                 6.75
# 859                        1                   10.0                 6.75
# 948                        0                    0.0                 2.80
#
#      resolution_width  resolution_height  display_frequency_hz  \
# 494             320.0              240.0                   NaN
# 738             720.0             1600.0                   NaN
# 840            1600.0              720.0                   NaN
# 859            1600.0              720.0                   NaN
# 948             240.0              320.0                   NaN
#
#      front_camera_mp  front_camera_secondary_mp  rear_camera_mp  \
# 494              NaN                        0.0             3.0
# 738              5.0                        0.0            13.0
# 840              5.0                        0.0            13.0
# 859              5.0                        0.0            13.0
# 948              NaN                        0.0             0.0
#
#      rear_camera_secondary_mp  rear_camera_tertiary_mp  rear_camera_count  \
# 494                       0.0                      0.0                  1
# 738                       0.0                      0.0                  1
# 840                       5.0                      0.0                  2
# 859                       5.0                      0.0                  2
# 948                       0.0                      0.0                  0
#
#      card_supported operating_system  \
# 494               1              NaN
# 738               1      Android v15
# 840               1      Android v14
# 859               1      Android v14
# 948               1      Symbian v30
#
#                                                             Product_Link  \
# 494    https://www.smartprix.com/mobiles/motorola-moto-a300-ppd18l5ntwlr
# 738     https://www.smartprix.com/mobiles/lava-bold-n1-lite-ppd1ypn0c7uo
# 840  https://www.smartprix.com/mobiles/lava-o3-3gb-ram-64gb-ppd1pw13pcxm
# 859               https://www.smartprix.com/mobiles/lava-o3-ppd1itxldve1
# 948      https://www.smartprix.com/mobiles/snexian-bold-40k-ppd102odkpp9
#
#                                                                        Image_URL  \
# 494    https://cdn1.smartprix.com/rx-iYgNNVOrY-w280-h280/motorola-moto-a300.webp
# 738     https://cdn1.smartprix.com/rx-i5eNmLs9X-w280-h280/lava-bold-n1-lite.webp
# 840  https://cdn1.smartprix.com/rx-iggBFt3JS-w280-h280/lava-o3-3gb-ram-64gb.webp
# 859               https://cdn1.smartprix.com/rx-iggBFt3JS-w280-h280/lava-o3.webp
# 948      https://cdn1.smartprix.com/rx-i4rK3ewft-w280-h280/snexian-bold-40k.webp
#
#                                                                                                                                                                                                                                                                 Specifications  \
# 494                                                                                              Dual Sim | No Wifi | 1.5 MHz Processor | 4 MB RAM, 32 MB inbuilt | 1000 mAh Battery | 2 inches, 320 x 240 px Display | 1.3 MP Rear Camera | Memory Card Supported, upto 64 GB
# 738                 Dual Sim, 3G, 4G, VoLTE, Wi-Fi | Octa Core Processor | 3 GB RAM, 64 GB inbuilt | 5000 mAh Battery with 10W Fast Charging | 6.75 inches, 720 x 1600 px Display with Water Drop Notch | 13 MP Rear & 5 MP Front Camera | Memory Card Supported | Android v15
# 840  Dual Sim, 3G, 4G, VoLTE, Wi-Fi | Octa Core Processor | 3 GB RAM, 64 GB inbuilt | 5000 mAh Battery with 10W Fast Charging | 6.75 inches, 1600 x 720 px Display with Water Drop Notch | 13 MP Dual Rear & 5 MP Front Camera | Memory Card (Hybrid), upto 1 TB | Android v14
# 859  Dual Sim, 3G, 4G, VoLTE, Wi-Fi | Octa Core Processor | 4 GB RAM, 64 GB inbuilt | 5000 mAh Battery with 10W Fast Charging | 6.75 inches, 1600 x 720 px Display with Water Drop Notch | 13 MP Dual Rear & 5 MP Front Camera | Memory Card (Hybrid), upto 1 TB | Android v14
# 948                                                                                                                       Dual Sim | No Wifi | 1 MHz Processor | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery | 2.8 inches, 240 x 320 px Display | No Rear Camera | Symbian v30
#
#        device_type
# 494  feature_phone
# 738     smartphone
# 840     smartphone
# 859     smartphone
# 948  feature_phone

# %%
df[df['processor_name'].isnull()]
# Out:
#                        Product_Name brand_name  Price  Rating  Spec_Score  \
# 209                 Google Pixel 8A     google  39999    4.65          76
# 353               Google Pixel 8 5G     google  38999    4.50          75
# 404         Jio JioPhone Prima 2 4G        jio   2799    4.35          24
# 437                Jio Bharat J1 4G        jio   1799    4.35          23
# 445          itel Super Guru 4G Max       itel   2399    4.10          15
# 461              Google Pixel 8 Pro     google  79999    4.70          79
# 527   Samsung Guru Music 2 Dual Sim    samsung    777    4.50          11
# 540                Jio Bharat V4 4G        jio    789    4.40          22
# 558               Samsung Metro 313    samsung    982    4.50          14
# 562              Motorola Moto A100   motorola    930    4.05           9
# 663                     Foneme Flip     foneme   1600    4.20           8
# 665               iKall Z10 4G 2025      ikall   6449    4.00          61
# 676                     iKall I7 4G      ikall   1549    4.35          32
# 678                  Lava Action 4G       lava   1799    4.45          17
# 684          BlackZone WINX 4G Plus  blackzone   3299    4.25          42
# 686                   Jio Bharat V3        jio    799    4.75          22
# 711            Nokia 130 Music 2023      nokia   1849    4.20          13
# 714           Jio Bharat K1 Karbonn        jio    890    4.40          21
# 715         Nokia 105 Dual Sim 2023      nokia    984    4.75          10
# 718                    Nokia 106 4G      nokia   2199    4.20          16
# 768                   Jio Bharat B2        jio   1399    4.65          15
# 822                        Gamma W5      gamma   1849    4.45          16
# 824                     MTR M16 Pro        mtr   4600    4.30          29
# 828                      HMD 102 4G        hmd   1879    4.40          12
# 829                      HMD 101 4G        hmd   1899    4.75          12
# 832                   Philips E2102    philips   1234    4.70           7
# 835              Motorola Moto A200   motorola   1149    4.05           9
# 875              Motorola Moto A10G   motorola    993    4.10          13
# 876          Nokia 105 Classic 2023      nokia   1049    4.20           7
# 883                   Jio Bharat V2        jio    990    4.50          22
# 886                  Nokia 105 2023      nokia   1199    4.70          10
# 941                     GFive A51-C      gfive    799    4.15          14
# 942                     Mixx M1 312       mixx    628    4.30          16
# 943                         MTR M15        mtr   4600    4.10          28
# 944                     iKall I4 4G      ikall   1599    4.30          16
# 945                  Philips E2101C    philips   1075    4.40           7
# 949                Snexian Rock R21    snexian    699    4.05          15
# 950                 Snexian Guru 30    snexian    899    4.00          15
# 952                   Lava A2 Smart       lava   1079    4.15          11
# 959           Lava Hero Shakti 2025       lava    909    4.50          17
# 961                Snexian Bravo 4G    snexian   1599    4.00          14
# 966              Lava A7 Torch Plus       lava   1444    4.30          15
# 968                      Amaq Q1 4G       amaq   2789    4.25          19
# 970            iKall K99 Pro Rugged      ikall   1349    4.10          15
# 974         Micromax X1i Smart Plus   micromax    999    4.30          12
# 989            Hotline Classic Zeus    hotline    499    4.60           7
# 990                      GFive A7-C      gfive    549    4.75           8
# 995                         HMD 105        hmd    984    4.70          10
# 997                         HMD 110        hmd   1164    4.60          12
# 1001             Motorola Moto A10V   motorola    993    4.00          11
# 1002             Motorola Moto A50V   motorola   1111    4.75          13
# 1019                    itel it5330       itel   1663    4.45          14
#
#       has_dual_sim  has_3g  has_4g  has_5g  has_nfc  has_ir_blaster  \
# 209              1       1       1       1        1               0
# 353              1       1       1       1        1               0
# 404              0       0       1       0        0               0
# 437              0       1       1       0        0               0
# 445              1       1       1       0        0               0
# 461              1       1       1       1        1               0
# 527              1       0       0       0        0               0
# 540              0       1       1       0        0               0
# 558              1       0       0       0        0               0
# 562              0       0       0       0        0               0
# 663              1       0       0       0        0               0
# 665              1       1       1       0        0               0
# 676              1       1       1       0        0               0
# 678              1       1       1       0        0               0
# 684              1       1       1       0        0               0
# 686              0       1       1       0        0               0
# 711              1       0       0       0        0               0
# 714              0       1       1       0        0               0
# 715              1       0       0       0        0               0
# 718              1       1       1       0        0               0
# 768              0       0       1       0        0               0
# 822              1       0       1       0        0               0
# 824              1       1       1       0        0               0
# 828              1       0       1       0        0               0
# 829              1       0       1       0        0               0
# 832              0       0       0       0        0               0
# 835              1       0       0       0        0               0
# 875              1       1       0       0        0               0
# 876              0       0       0       0        0               0
# 883              0       1       1       0        0               0
# 886              0       0       0       0        0               0
# 941              1       0       0       0        0               0
# 942              1       0       1       0        0               0
# 943              1       1       1       0        0               0
# 944              1       0       1       0        0               0
# 945              0       0       0       0        0               0
# 949              1       0       0       0        0               0
# 950              0       0       0       0        0               0
# 952              1       0       0       0        0               0
# 959              1       0       0       0        0               0
# 961              1       0       1       0        0               0
# 966              1       0       0       0        0               0
# 968              1       1       1       0        0               0
# 970              0       0       0       0        0               0
# 974              1       0       0       0        0               0
# 989              1       0       0       0        0               0
# 990              1       0       0       0        0               0
# 995              1       0       0       0        0               0
# 997              1       0       0       0        0               0
# 1001             1       0       0       0        0               0
# 1002             1       0       0       0        0               0
# 1019             1       0       0       0        0               0
#
#      processor_name        cores  cpu_speed_ghz  ram_gb   rom_gb  \
# 209             NaN          NaN        3.00000   8.000  128.000
# 353             NaN    Nine Core        3.00000   8.000  128.000
# 404             NaN          NaN            NaN   0.500    4.000
# 437             NaN          NaN            NaN   0.500    4.000
# 445             NaN          NaN            NaN   0.062      NaN
# 461             NaN    Nine Core        3.00000  12.000  128.000
# 527             NaN  Single Core        0.20800     NaN      NaN
# 540             NaN          NaN            NaN   0.500    4.000
# 558             NaN  Single Core        0.20800   0.010    0.002
# 562             NaN          NaN        0.00100   0.004    0.035
# 663             NaN          NaN        0.25600   0.031    0.031
# 665             NaN    Octa Core        2.00000   4.000   64.000
# 676             NaN          NaN        0.51200   2.000   16.000
# 678             NaN          NaN            NaN     NaN      NaN
# 684             NaN    Quad Core        1.00000   3.000   16.000
# 686             NaN          NaN            NaN   0.500    4.000
# 711             NaN          NaN            NaN   0.004    0.004
# 714             NaN          NaN            NaN   0.500    4.000
# 715             NaN          NaN            NaN   0.004    0.004
# 718             NaN          NaN            NaN   0.004      NaN
# 768             NaN          NaN        0.00100   0.035    0.035
# 822             NaN  Single Core        0.00120   0.031    0.031
# 824             NaN          NaN        0.51200   3.000    0.031
# 828             NaN          NaN            NaN   0.023    0.016
# 829             NaN          NaN            NaN     NaN      NaN
# 832             NaN          NaN            NaN   0.004    0.004
# 835             NaN          NaN            NaN   0.055    0.035
# 875             NaN          NaN        0.00150   0.004    0.031
# 876             NaN          NaN            NaN   0.004    0.004
# 883             NaN          NaN            NaN   0.500    4.000
# 886             NaN          NaN            NaN   0.004    0.004
# 941             NaN  Single Core        0.00120   0.031    0.016
# 942             NaN          NaN        0.00500     NaN   32.000
# 943             NaN          NaN        0.51200   3.000    0.031
# 944             NaN          NaN        0.00130   0.031    0.031
# 945             NaN          NaN            NaN   0.031    0.031
# 949             NaN          NaN        0.00100   0.031    0.031
# 950             NaN          NaN            NaN   0.031    0.031
# 952             NaN  Single Core        0.00150   0.004    0.031
# 959             NaN          NaN        0.00150   0.004   32.000
# 961             NaN          NaN        0.00177   0.031    0.031
# 966             NaN          NaN            NaN   0.031    0.031
# 968             NaN          NaN            NaN   0.500      NaN
# 970             NaN          NaN            NaN   0.031    0.031
# 974             NaN  Single Core        0.00120   0.031    0.031
# 989             NaN          NaN        0.00130   0.031    0.031
# 990             NaN          NaN        0.00130   0.031    0.031
# 995             NaN          NaN            NaN   0.004    0.004
# 663              3.0                       0.0                      0.0
# 665             20.0                       0.0                      0.0
# 676              3.0                       0.0                      0.0
# 678              3.0                       0.0                      0.0
# 684              5.0                       0.0                      0.0
# 686              3.0                       0.0                      0.0
# 711              0.0                       0.0                      0.0
# 714              3.0                       0.0                      0.0
# 715              0.0                       0.0                      0.0
# 718              0.0                       0.0                      0.0
# 768              3.0                       0.0                      0.0
# 822              3.0                       0.0                      0.0
# 824              5.0                       0.0                      0.0
# 828              NaN                       0.0                      0.0
# 829              0.0                       0.0                      0.0
# 832              8.0                       0.0                      0.0
# 835              0.0                       0.0                      0.0
# 875              0.0                       0.0                      0.0
# 876              0.0                       0.0                      0.0
# 883              3.0                       0.0                      0.0
# 886              0.0                       0.0                      0.0
# 941              3.0                       0.0                      0.0
# 942              2.0                       0.0                      0.0
# 943              5.0                       0.0                      0.0
# 944              3.0                       0.0                      0.0
# 945              0.0                       0.0                      0.0
# 949              3.0                       0.0                      0.0
# 950              3.0                       0.0                      0.0
# 952              NaN                       0.0                      0.0
# 959              0.0                       0.0                      0.0
# 961              3.0                       0.0                      0.0
# 966              3.0                       0.0                      0.0
# 968              6.0                       0.0                      0.0
# 970              3.0                       0.0                      0.0
# 974              8.0                       0.0                      0.0
# 989              3.0                       0.0                      0.0
# 990              3.0                       0.0                      0.0
# 995              0.0                       0.0                      0.0
# 997              NaN                       0.0                      0.0
# 1001             0.0                       0.0                      0.0
# 1002             3.0                       0.0                      0.0
# 1019             3.0                       0.0                      0.0
#
#       rear_camera_count  card_supported operating_system  \
# 209                   2               0      Android v14
# 353                   2               1      Android v14
# 404                   1               1         iOS v2.3
# 437                   1               1              NaN
# 445                   1               1              NaN
# 461                   3               1      Android v14
# 527                   0               1              NaN
# 540                   1               1              NaN
# 558                   1               1              NaN
# 562                   0               1              NaN
# 663                   1               1              NaN
# 665                   1               1      Android v14
# 676                   1               1              NaN
# 678                   1               1              NaN
# 684                   1               1      Android v11
# 686                   1               1              NaN
# 711                   0               1              NaN
# 714                   1               1              NaN
# 715                   0               1              NaN
# 718                   0               1              NaN
# 768                   1               1              NaN
# 822                   1               1              NaN
# 824                   1               1      Android v13
# 828                   0               1              NaN
# 829                   0               1              NaN
# 832                   1               1              NaN
# 835                   0               1              NaN
# 875                   0               1              NaN
# 876                   0               1              NaN
# 883                   1               1              NaN
# 886                   0               1              NaN
# 941                   1               1          Symbian
# 942                   1               1              NaN
# 943                   1               1      Android v13
# 944                   1               1       Symbian v9
# 945                   0               1              NaN
# 949                   1               1          Symbian
# 950                   1               1      Symbian v30
# 952                   0               1              NaN
# 959                   0               1              NaN
# 961                   1               1              NaN
# 966                   1               1              NaN
# 968                   1               1              NaN
# 970                   1               1              NaN
# 974                   1               1              NaN
# 989                   1               1              NaN
# 990                   1               1              NaN
# 995                   0               1              NaN
# 997                   0               1              NaN
# 1001                  0               1              NaN
# 1002                  1               1              NaN
# 1019                  1               1              NaN
#
#                                                                       Product_Link  \
# 209                 https://www.smartprix.com/mobiles/google-pixel-8a-ppd12mhj2qa8
dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Tensor G3, Nine-Cores, 3 GHz Processor | 8 GB RAM, 128 GB inbuilt | 4492 mAh Battery with Fast Charging | 6.1 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole | 64 MP + 13 MP Dual Rear & 13 MP Front Camera | Memory Card Not Supported | Android v14
# 353               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Tensor G3, Nine Core, 3 GHz Processor | 8 GB RAM, 128 GB inbuilt | 4575 mAh Battery with 30W Fast Charging | 6.2 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole | 50 MP + 12 MP Dual Rear & 10.5 MP Front Camera | Android v14 | No FM Radio
# 404                                                                                            Single Sim, 4G, VoLTE, Wi-Fi | 512 MB RAM, 4 GB inbuilt | 2000 mAh Battery | 2.4 inches, 240 x 320 px Display | 0.3 MP Rear & 0.3 MP Front Camera | Memory Card Supported, upto 128 GB | KaiOS v2.5.3 | Bluetooth
# 437                                                                                                                             Single Sim, 3G, 4G, VoLTE | 512 MB RAM, 4 GB inbuilt | 2500 mAh Battery | 2.8 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 445                                                                                                                                                             Dual Sim, 3G, 4G, VoLTE | 64 MB RAM | 2000 mAh Battery | 3 inches Display | 0.3 MP Rear Camera | Memory Card Supported | No FM Radio | Bluetooth
# 461   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Tensor G3, Nine Cores, 3 GHz Processor | 12 GB RAM, 128 GB inbuilt | 5050 mAh Battery with 30W Fast Charging | 6.7 inches, 1344 x 2992 px, 120 Hz Display with Punch Hole | 50 MP + 48 MP + 48 MP Triple Rear & 10.5 MP Front Camera | Android v14 | No FM Radio
# 527                                                                                                                                                  Dual Sim | No Wifi | Single Core, 208 MHz Processor | 800 mAh Battery | 2 inches, 128 x 160 px Display | No Rear Camera | Memory Card Supported, upto 16 GB
# 540                                                                                                                  Single Sim, 3G, 4G, VoLTE | No Wifi | 512 MB RAM, 4 GB inbuilt | 1000 mAh Battery | 1.77 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 558                                                                                                                       Dual Sim | Single Core, 208 MHz Processor | 10 MB RAM, 2 MB inbuilt | 1000 mAh Battery | 2 inches, 320 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 16 GB | v30
# 562                                                                                                                                    Single Sim | Unisoc, 1 MHz Processor | 4 MB RAM, 36 MB inbuilt | 800 mAh Battery | 1.44 inches, 240 x 320 px Display | No Rear Camera | Memory Card Supported, upto 32 MB
# 663                                                                                                                                       Dual Sim | 256 MHz Processor | 32 MB RAM, 32 MB inbuilt | 1050 mAh Battery | 2 inches, 120 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported | No FM Radio
# 665                                                                                          Dual Sim, 3G, 4G, VoLTE, Wi-Fi | Octa Core, 2 GHz Processor | 4 GB RAM, 64 GB inbuilt | 4000 mAh Battery | 6.53 inches, 720 x 1600 px Display | 20 MP Rear & 8 MP Front Camera | Memory Card (Hybrid) | Android v14
# 676                                                                                                                         Dual Sim, 3G, 4G, Wi-Fi | 512 MHz Processor | 2 GB RAM, 16 GB inbuilt | 2000 mAh Battery | 2.4 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported | Bluetooth
# 678                                                                                                                                                                       Dual Sim, 3G, 4G, VoLTE | 1000 mAh Battery | 1.8 inches, 240 x 260 px Display | 0.3 MP Rear Camera | Memory Card Supported | Bluetooth
# 684                                                                                Dual Sim, 3G, 4G, VoLTE, Wi-Fi | Quad Core, 1 GHz Processor | 3 GB RAM, 16 GB inbuilt | 3000 mAh Battery | 2.8 inches, 480 x 640 px Display | 5 MP Rear & 2 MP Front Camera | Memory Card Supported, upto 64 GB | Android v11
# 686                                                                                                                  Single Sim, 3G, 4G, VoLTE | No Wifi | 512 MB RAM, 4 GB inbuilt | 1000 mAh Battery | 1.77 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 711                                                                                                                                                 Dual Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1450 mAh Battery | 2.4 inches, 240 x 320 px Display | No Rear Camera | Memory Card Supported, upto 32 GB | v30
# 714                                                                                                                        Single Sim, 3G, 4G, VoLTE | No Wifi | ASR | 512 MB RAM, 4 GB inbuilt | 1000 mAh Battery | 1.77 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB
# 715                                                                                                                                                                   Dual Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 1.8 inches, 120 x 160 px Display | No Rear Camera | Memory Card Supported
# 718                                                                                                                                          Dual Sim, 3G, 4G, VoLTE | No Wifi | 4 MB RAM | 1450 mAh Battery | 1.8 inches, 120 x 160 px Display | No Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 768                                                                                                               Single Sim, 4G, VoLTE | 1 MHz Processor | 36 MB RAM, 36 MB inbuilt | 2000 mAh Battery | 2.4 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 822                                                                                            Dual Sim, 4G, VoLTE | Single Core, 1.2 MHz Processor | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery with Fast Charging | 2.4 inches, 120 x 360 px Display | 0.3 MP Rear Camera | Memory Card Supported | Bluetooth
# 824                                                                                                              Dual Sim, 3G, 4G, Wi-Fi | Helio, 512 MHz Processor | 3 GB RAM, 32 MB inbuilt | 2000 mAh Battery | 4 inches, 480 x 640 px Display with Punch Hole | 5 MP Rear Camera | Android v13.0 | Bluetooth
# 828                                                                                                                                              Dual Sim, 4G | Unisoc 8910 FF-S | 24 MB RAM, 16 MB inbuilt | 1000 mAh Battery | 2 inches Display | QVGA Rear Camera | Memory Card Supported, upto 32 GB | S30+​
# 829                                                                                                                                                               Dual Sim, 4G | Unisoc 8910 FF-S | 1000 mAh Battery | 2 inches Display | No Rear Camera | Memory Card Supported, upto 32 GB | S30+​ | Bluetooth
# 832                                                                                                                                                                               Unisoc SC6531E | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 1.77 inches Display | 0.08 MP Rear Camera | Memory Card Supported
# 835                                                                                                                                                               Dual Sim | 56 MB RAM, 36 MB inbuilt | 800 mAh Battery | 1.77 inches, 128 x 160 px Display | No Rear Camera | Memory Card Supported, upto 64 GB
# 875                                                                                                                             Dual Sim, 3G | 1.5 MHz Processor | 4 MB RAM, 32 MB inbuilt | 800 mAh Battery | 1.8 inches, 160 x 128 px Display | No Rear Camera | Memory Card Supported, upto 64 GB | Bluetooth
# 876                                                                                                                                                                                            Single Sim | 4 MB RAM, 4 MB inbuilt | 800 mAh Battery | 1.77 inches, 128 x 160 px Display | No Rear Camera | S30+
# 883                                                                                                                  Single Sim, 3G, 4G, VoLTE | No Wifi | 512 MB RAM, 4 GB inbuilt | 1000 mAh Battery | 1.77 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 886                                                                                                                                                                 Single Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 1.8 inches, 120 x 160 px Display | No Rear Camera | Memory Card Supported
# 941                                                                                                                 Dual Sim | Single Core, 1.2 MHz Processor | 32 MB RAM, 16 MB inbuilt | 3000 mAh Battery | 1.8 inches, 128 x 160 px Display | 0.3 MP Rear Camera | Memory Card (Hybrid), upto 16 GB | Symbian
# 942                                                                                                                                                                                      Dual Sim, 4G | 5 MHz Processor | 32 GB inbuilt | 1000 mAh Battery | 1.8 inches Display | 2 MP Rear Camera | No FM Radio
# 943                                                                                                                              Dual Sim, 3G, 4G, Wi-Fi | Helio, 512 MHz Processor | 3 GB RAM, 32 MB inbuilt | 2000 mAh Battery | 3 inches, 480 x 640 px Display | 5 MP Rear Camera | Android v13.0 | Bluetooth
# 944                                                                                                                    Dual Sim, 4G | 1.3 MHz Processor | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery | 2.4 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 32 MB | Symbian v9.1
# 945                                                                                                                                                                                       32 MB RAM, 32 MB inbuilt | 1000 mAh Battery | 1.77 inches Display | No Rear Camera | Memory Card Supported, upto 32 GB
# 949                                                                                                                Dual Sim | 1 MHz Processor | 32 MB RAM, 32 MB inbuilt | 3000 mAh Battery | 1.8 inches, 240 x 320 px Display | 0.3 MP Rear & 0.3 MP Front Camera | Memory Card Supported, upto 32 GB | Symbian
# 950                                                                                                                                 Triple Sim | No Wifi | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery | 2.4 inches, 320 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 16 GB | Symbian v30
# 952                                                                                                            Dual Sim | Single Core, 1.5 MHz Processor | 4 MB RAM, 32 MB inbuilt | 1200 mAh Battery | 2.4 inches, 120 x 240 px Display | Digital Rear Camera | Memory Card Supported, upto 32 GB | No FM Radio
# 959                                                                                                                                                          Dual Sim | 1.5 MHz Processor | 4 MB RAM, 32 GB inbuilt | 800 mAh Battery | 1.8 inches, 160 x 128 px Display | No Rear Camera | Memory Card (Hybrid)
# 961                                                                                                                                  Dual Sim, 4G, VoLTE | 1.77 MHz Processor | 32 MB RAM, 32 MB inbuilt | 3000 mAh Battery | 2.8 inches, 320 x 240 px Display | 1.3 MP Rear Camera | Memory Card (Hybrid) | v30
# 966                                                                                                                                               Dual Sim | 32 MB RAM, 32 MB inbuilt | 2575 mAh Battery | 2.4 inches, 320 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 968                                                                                                                                                                   Dual Sim, 3G, 4G | 512 MB RAM | 3500 mAh Battery | 2.8 inches Display | 0.6 MP Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 970                                                                                                                                               Quad Sim | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery | 2.4 inches, 128 x 160 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 64 GB | Bluetooth
# 974                                                                                                                                     Dual Sim | Single Core, 1.2 MHz Processor | 32 MB RAM, 32 MB inbuilt | 1750 mAh Battery | 2.4 inches, 320 x 240 px Display | 0.08 MP Rear Camera | Memory Card Supported
# 989                                                                                                                                                                          Dual Sim | 1.3 MHz Processor | 32 MB RAM, 32 MB inbuilt | 1000 mAh Battery | 1.77 inches, 128 x 160 px Display | 1.3 MP Rear Camera
# 990                                                                                                                                                        Dual Sim | 1.3 MHz Processor | 32 MB RAM, 32 MB inbuilt | 1000 mAh Battery | 1.8 inches, 320 x 480 px Display | 0.3 MP Rear Camera | v. | No FM Radio
# 995                                                                                                                                                                   Dual Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 1.8 inches, 120 x 160 px Display | No Rear Camera | Memory Card Supported
# 997                                                                                                                                                                   Dual Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 2 inches, 120 x 160 px Display | Memory Card Supported, upto 32 GB | RTOS
# 1001                                                                                                                                                     Dual Sim | 4 MB RAM, 4 MB inbuilt | 800 mAh Battery | 1.8 inches, 160 x 128 px Display | No Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 1002                                                                                                                                                Dual Sim | 4 MB RAM, 4 MB inbuilt | 1750 mAh Battery | 1.8 inches, 160 x 128 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 1019                                                                                                                                              Dual Sim | 32 MB RAM, 32 MB inbuilt | 1900 mAh Battery | 2.8 inches, 320 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
#
#         device_type
# 209      smartphone
# 353      smartphone
# 404   feature_phone
# 437   feature_phone
# 445   feature_phone
# 461      smartphone
# 527   feature_phone
# 540   feature_phone
# 558   feature_phone
# 562   feature_phone
# 663   feature_phone
# 665      smartphone
# 676   feature_phone
# 678   feature_phone
# 684   feature_phone
# 686   feature_phone
# 711   feature_phone
# 714   feature_phone
# 715   feature_phone
# 718   feature_phone
# 768   feature_phone
# 822   feature_phone
# 824      smartphone
# 828   feature_phone
# 829   feature_phone
# 832   feature_phone
# 835   feature_phone
# 875   feature_phone
# 876   feature_phone
# 883   feature_phone
# 886   feature_phone
# 941   feature_phone
# 942   feature_phone
# 943   feature_phone
# 944   feature_phone
# 945   feature_phone
# 949   feature_phone
# 950   feature_phone
# 952   feature_phone
# 959   feature_phone
# 961   feature_phone
# 966   feature_phone
# 968   feature_phone
# 970   feature_phone
# 974   feature_phone
# 989   feature_phone
# 990   feature_phone
# 995   feature_phone
# 997   feature_phone
# 1001  feature_phone
# 1002  feature_phone
# 1019  feature_phone

# %%
df[df['processor_name'].isnull()]
# Out:
#                        Product_Name brand_name  Price  Rating  Spec_Score  \
# 437              0       1       1       0        0               0
# 445              1       1       1       0        0               0
# 461              1       1       1       1        1               0
# 527              1       0       0       0        0               0
# 540              0       1       1       0        0               0
# 558              1       0       0       0        0               0
# 562              0       0       0       0        0               0
# 663              1       0       0       0        0               0
# 665              1       1       1       0        0               0
# 676              1       1       1       0        0               0
# 678              1       1       1       0        0               0
# 684              1       1       1       0        0               0
# 686              0       1       1       0        0               0
# 711              1       0       0       0        0               0
# 714              0       1       1       0        0               0
# 715              1       0       0       0        0               0
# 718              1       1       1       0        0               0
# 768              0       0       1       0        0               0
# 822              1       0       1       0        0               0
# 824              1       1       1       0        0               0
# 828              1       0       1       0        0               0
# 829              1       0       1       0        0               0
# 832              0       0       0       0        0               0
# 835              1       0       0       0        0               0
# 875              1       1       0       0        0               0
# 876              0       0       0       0        0               0
# 883              0       1       1       0        0               0
# 886              0       0       0       0        0               0
# 941              1       0       0       0        0               0
# 942              1       0       1       0        0               0
# 943              1       1       1       0        0               0
# 944              1       0       1       0        0               0
# 945              0       0       0       0        0               0
# 949              1       0       0       0        0               0
# 950              0       0       0       0        0               0
# 952              1       0       0       0        0               0
# 959              1       0       0       0        0               0
# 961              1       0       1       0        0               0
# 966              1       0       0       0        0               0
# 968              1       1       1       0        0               0
# 970              0       0       0       0        0               0
# 974              1       0       0       0        0               0
# 989              1       0       0       0        0               0
# 990              1       0       0       0        0               0
# 995              1       0       0       0        0               0
# 997              1       0       0       0        0               0
# 1001             1       0       0       0        0               0
# 1002             1       0       0       0        0               0
# 1019             1       0       0       0        0               0
#
#      processor_name        cores  cpu_speed_ghz  ram_gb   rom_gb  \
# 209             NaN          NaN        3.00000   8.000  128.000
# 353             NaN    Nine Core        3.00000   8.000  128.000
# 404             NaN          NaN            NaN   0.500    4.000
# 437             NaN          NaN            NaN   0.500    4.000
# 445             NaN          NaN            NaN   0.062      NaN
# 461             NaN    Nine Core        3.00000  12.000  128.000
# 527             NaN  Single Core        0.20800     NaN      NaN
# 540             NaN          NaN            NaN   0.500    4.000
# 558             NaN  Single Core        0.20800   0.010    0.002
# 562             NaN          NaN        0.00100   0.004    0.035
# 663             NaN          NaN        0.25600   0.031    0.031
# 665             NaN    Octa Core        2.00000   4.000   64.000
# 676             NaN          NaN        0.51200   2.000   16.000
# 678             NaN          NaN            NaN     NaN      NaN
# 684             NaN    Quad Core        1.00000   3.000   16.000
# 686             NaN          NaN            NaN   0.500    4.000
# 711             NaN          NaN            NaN   0.004    0.004
# 714             NaN          NaN            NaN   0.500    4.000
# 715             NaN          NaN            NaN   0.004    0.004
# 718             NaN          NaN            NaN   0.004      NaN
# 768             NaN          NaN        0.00100   0.035    0.035
# 822             NaN  Single Core        0.00120   0.031    0.031
# 824             NaN          NaN        0.51200   3.000    0.031
# 828             NaN          NaN            NaN   0.023    0.016
# 829             NaN          NaN            NaN     NaN      NaN
# 832             NaN          NaN            NaN   0.004    0.004
# 835             NaN          NaN            NaN   0.055    0.035
# 875             NaN          NaN        0.00150   0.004    0.031
# 876             NaN          NaN            NaN   0.004    0.004
# 828                   0               1              NaN
# 829                   0               1              NaN
# 832                   1               1              NaN
# 835                   0               1              NaN
# 875                   0               1              NaN
# 876                   0               1              NaN
# 883                   1               1              NaN
# 886                   0               1              NaN
# 941                   1               1          Symbian
# 942                   1               1              NaN
# 943                   1               1      Android v13
# 944                   1               1       Symbian v9
# 945                   0               1              NaN
# 949                   1               1          Symbian
# 950                   1               1      Symbian v30
# 952                   0               1              NaN
# 959                   0               1              NaN
# 961                   1               1              NaN
# 966                   1               1              NaN
# 968                   1               1              NaN
# 970                   1               1              NaN
# 974                   1               1              NaN
# 989                   1               1              NaN
# 990                   1               1              NaN
# 995                   0               1              NaN
# 997                   0               1              NaN
# 1001                  0               1              NaN
# 1002                  1               1              NaN
# 1019                  1               1              NaN
#
#                                                                       Product_Link  \
# 209                 https://www.smartprix.com/mobiles/google-pixel-8a-ppd12mhj2qa8
# 353                  https://www.smartprix.com/mobiles/google-pixel-8-ppd1yco2q574
# 404         https://www.smartprix.com/mobiles/jio-jiophone-prima-2-4g-ppd119j2utsd
# 437                https://www.smartprix.com/mobiles/jio-bharat-j1-4g-ppd14lhe1cxq
# 445          https://www.smartprix.com/mobiles/itel-super-guru-4g-max-ppd14juicqe2
# 461              https://www.smartprix.com/mobiles/google-pixel-8-pro-ppd1zsafbw6z
# 527   https://www.smartprix.com/mobiles/samsung-guru-music-2-dual-sim-p1101jjovdk3
# 540                   https://www.smartprix.com/mobiles/jio-bharat-v4-ppd1oq8ucbe2
# 558               https://www.smartprix.com/mobiles/samsung-metro-313-p1101kdcaij5
# 562              https://www.smartprix.com/mobiles/motorola-moto-a100-ppd13iyi146w
# 663                     https://www.smartprix.com/mobiles/foneme-flip-ppd1j5del0d5
# 665               https://www.smartprix.com/mobiles/ikall-z10-4g-2025-ppd1rsaf2ftx
# 676                     https://www.smartprix.com/mobiles/ikall-i7-4g-ppd1xd5w4mnv
# 678                  https://www.smartprix.com/mobiles/lava-action-4g-ppd1mzwuv6yf
# 684          https://www.smartprix.com/mobiles/blackzone-winx-4g-plus-ppd1ggheagu3
# 686                   https://www.smartprix.com/mobiles/jio-bharat-v3-ppd1gsosjjgo
# 711            https://www.smartprix.com/mobiles/nokia-130-music-2023-ppd1yethn9id
# 714           https://www.smartprix.com/mobiles/jio-bharat-k1-karbonn-ppd1t2krxqv3
# 715         https://www.smartprix.com/mobiles/nokia-105-dual-sim-2023-ppd1dn6nv10g
# 718                    https://www.smartprix.com/mobiles/nokia-106-4g-ppd1qod42hja
# 768                   https://www.smartprix.com/mobiles/jio-bharat-b2-ppd1cgvwh8ck
# 822                        https://www.smartprix.com/mobiles/gamma-w5-ppd1m2xhi4ue
# 824                     https://www.smartprix.com/mobiles/mtr-m16-pro-ppd1g9h6ae7f
# 828                      https://www.smartprix.com/mobiles/hmd-102-4g-ppd1ekeupkc7
# 829                      https://www.smartprix.com/mobiles/hmd-101-4g-ppd1t11nv2r0
# 832                   https://www.smartprix.com/mobiles/philips-e2102-ppd1zwy78dbc
# 961       https://cdn1.smartprix.com/rx-iV9byDjcP-w280-h280/snexian-bravo-4g.webp
# 966     https://cdn1.smartprix.com/rx-ieYGlWjDU-w280-h280/lava-a7-torch-plus.webp
# 968             https://cdn1.smartprix.com/rx-ijwh5fx0T-w280-h280/amaq-q1-4g.webp
# 970   https://cdn1.smartprix.com/rx-ilOI2Kfoc-w280-h280/ikall-k99-pro-rugged.webp
# 974   https://cdn1.smartprix.com/rx-iLj25yKWZ-w280-h280/micromax-x1i-smart-p.webp
# 989   https://cdn1.smartprix.com/rx-iFUA8wQgk-w280-h280/hotline-classic-zeus.webp
# 990             https://cdn1.smartprix.com/rx-iaIScfduK-w280-h280/gfive-a7-c.webp
# 995                https://cdn1.smartprix.com/rx-ioTkqVxfI-w280-h280/hmd-105.webp
# 997                https://cdn1.smartprix.com/rx-iVGhBfjIQ-w280-h280/hmd-110.webp
# 1001    https://cdn1.smartprix.com/rx-ilnwLoBbF-w280-h280/motorola-moto-a10v.webp
# 1002    https://cdn1.smartprix.com/rx-ibQalcYet-w280-h280/motorola-moto-a50v.webp
# 1019           https://cdn1.smartprix.com/rx-icuqZTvUd-w280-h280/itel-it5330.webp
#
#                                                                                                                                                                                                                                                                                                   Specifications  \
# 209      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Tensor G3, Nine-Cores, 3 GHz Processor | 8 GB RAM, 128 GB inbuilt | 4492 mAh Battery with Fast Charging | 6.1 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole | 64 MP + 13 MP Dual Rear & 13 MP Front Camera | Memory Card Not Supported | Android v14
# 353               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Tensor G3, Nine Core, 3 GHz Processor | 8 GB RAM, 128 GB inbuilt | 4575 mAh Battery with 30W Fast Charging | 6.2 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole | 50 MP + 12 MP Dual Rear & 10.5 MP Front Camera | Android v14 | No FM Radio
# 404                                                                                            Single Sim, 4G, VoLTE, Wi-Fi | 512 MB RAM, 4 GB inbuilt | 2000 mAh Battery | 2.4 inches, 240 x 320 px Display | 0.3 MP Rear & 0.3 MP Front Camera | Memory Card Supported, upto 128 GB | KaiOS v2.5.3 | Bluetooth
# 437                                                                                                                             Single Sim, 3G, 4G, VoLTE | 512 MB RAM, 4 GB inbuilt | 2500 mAh Battery | 2.8 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 445                                                                                                                                                             Dual Sim, 3G, 4G, VoLTE | 64 MB RAM | 2000 mAh Battery | 3 inches Display | 0.3 MP Rear Camera | Memory Card Supported | No FM Radio | Bluetooth
# 461   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Tensor G3, Nine Cores, 3 GHz Processor | 12 GB RAM, 128 GB inbuilt | 5050 mAh Battery with 30W Fast Charging | 6.7 inches, 1344 x 2992 px, 120 Hz Display with Punch Hole | 50 MP + 48 MP + 48 MP Triple Rear & 10.5 MP Front Camera | Android v14 | No FM Radio
# 527                                                                                                                                                  Dual Sim | No Wifi | Single Core, 208 MHz Processor | 800 mAh Battery | 2 inches, 128 x 160 px Display | No Rear Camera | Memory Card Supported, upto 16 GB
# 540                                                                                                                  Single Sim, 3G, 4G, VoLTE | No Wifi | 512 MB RAM, 4 GB inbuilt | 1000 mAh Battery | 1.77 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 558                                                                                                                       Dual Sim | Single Core, 208 MHz Processor | 10 MB RAM, 2 MB inbuilt | 1000 mAh Battery | 2 inches, 320 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 16 GB | v30
# 562                                                                                                                                    Single Sim | Unisoc, 1 MHz Processor | 4 MB RAM, 36 MB inbuilt | 800 mAh Battery | 1.44 inches, 240 x 320 px Display | No Rear Camera | Memory Card Supported, upto 32 MB
# 663                                                                                                                                       Dual Sim | 256 MHz Processor | 32 MB RAM, 32 MB inbuilt | 1050 mAh Battery | 2 inches, 120 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported | No FM Radio
# 665                                                                                          Dual Sim, 3G, 4G, VoLTE, Wi-Fi | Octa Core, 2 GHz Processor | 4 GB RAM, 64 GB inbuilt | 4000 mAh Battery | 6.53 inches, 720 x 1600 px Display | 20 MP Rear & 8 MP Front Camera | Memory Card (Hybrid) | Android v14
# 676                                                                                                                         Dual Sim, 3G, 4G, Wi-Fi | 512 MHz Processor | 2 GB RAM, 16 GB inbuilt | 2000 mAh Battery | 2.4 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported | Bluetooth
# 678                                                                                                                                                                       Dual Sim, 3G, 4G, VoLTE | 1000 mAh Battery | 1.8 inches, 240 x 260 px Display | 0.3 MP Rear Camera | Memory Card Supported | Bluetooth
# 684                                                                                Dual Sim, 3G, 4G, VoLTE, Wi-Fi | Quad Core, 1 GHz Processor | 3 GB RAM, 16 GB inbuilt | 3000 mAh Battery | 2.8 inches, 480 x 640 px Display | 5 MP Rear & 2 MP Front Camera | Memory Card Supported, upto 64 GB | Android v11
# 686                                                                                                                  Single Sim, 3G, 4G, VoLTE | No Wifi | 512 MB RAM, 4 GB inbuilt | 1000 mAh Battery | 1.77 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 711                                                                                                                                                 Dual Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1450 mAh Battery | 2.4 inches, 240 x 320 px Display | No Rear Camera | Memory Card Supported, upto 32 GB | v30
# 714                                                                                                                        Single Sim, 3G, 4G, VoLTE | No Wifi | ASR | 512 MB RAM, 4 GB inbuilt | 1000 mAh Battery | 1.77 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB
# 715                                                                                                                                                                   Dual Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 1.8 inches, 120 x 160 px Display | No Rear Camera | Memory Card Supported
# 718                                                                                                                                          Dual Sim, 3G, 4G, VoLTE | No Wifi | 4 MB RAM | 1450 mAh Battery | 1.8 inches, 120 x 160 px Display | No Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 768                                                                                                               Single Sim, 4G, VoLTE | 1 MHz Processor | 36 MB RAM, 36 MB inbuilt | 2000 mAh Battery | 2.4 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 822                                                                                            Dual Sim, 4G, VoLTE | Single Core, 1.2 MHz Processor | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery with Fast Charging | 2.4 inches, 120 x 360 px Display | 0.3 MP Rear Camera | Memory Card Supported | Bluetooth
# 824                                                                                                              Dual Sim, 3G, 4G, Wi-Fi | Helio, 512 MHz Processor | 3 GB RAM, 32 MB inbuilt | 2000 mAh Battery | 4 inches, 480 x 640 px Display with Punch Hole | 5 MP Rear Camera | Android v13.0 | Bluetooth
# 828                                                                                                                                              Dual Sim, 4G | Unisoc 8910 FF-S | 24 MB RAM, 16 MB inbuilt | 1000 mAh Battery | 2 inches Display | QVGA Rear Camera | Memory Card Supported, upto 32 GB | S30+​
# 829                                                                                                                                                               Dual Sim, 4G | Unisoc 8910 FF-S | 1000 mAh Battery | 2 inches Display | No Rear Camera | Memory Card Supported, upto 32 GB | S30+​ | Bluetooth
# 832                                                                                                                                                                               Unisoc SC6531E | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 1.77 inches Display | 0.08 MP Rear Camera | Memory Card Supported
# 835                                                                                                                                                               Dual Sim | 56 MB RAM, 36 MB inbuilt | 800 mAh Battery | 1.77 inches, 128 x 160 px Display | No Rear Camera | Memory Card Supported, upto 64 GB
# 875                                                                                                                             Dual Sim, 3G | 1.5 MHz Processor | 4 MB RAM, 32 MB inbuilt | 800 mAh Battery | 1.8 inches, 160 x 128 px Display | No Rear Camera | Memory Card Supported, upto 64 GB | Bluetooth
# 876                                                                                                                                                                                            Single Sim | 4 MB RAM, 4 MB inbuilt | 800 mAh Battery | 1.77 inches, 128 x 160 px Display | No Rear Camera | S30+
# 883                                                                                                                  Single Sim, 3G, 4G, VoLTE | No Wifi | 512 MB RAM, 4 GB inbuilt | 1000 mAh Battery | 1.77 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 128 GB | Bluetooth
# 886                                                                                                                                                                 Single Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 1.8 inches, 120 x 160 px Display | No Rear Camera | Memory Card Supported
# 941                                                                                                                 Dual Sim | Single Core, 1.2 MHz Processor | 32 MB RAM, 16 MB inbuilt | 3000 mAh Battery | 1.8 inches, 128 x 160 px Display | 0.3 MP Rear Camera | Memory Card (Hybrid), upto 16 GB | Symbian
# 942                                                                                                                                                                                      Dual Sim, 4G | 5 MHz Processor | 32 GB inbuilt | 1000 mAh Battery | 1.8 inches Display | 2 MP Rear Camera | No FM Radio
# 943                                                                                                                              Dual Sim, 3G, 4G, Wi-Fi | Helio, 512 MHz Processor | 3 GB RAM, 32 MB inbuilt | 2000 mAh Battery | 3 inches, 480 x 640 px Display | 5 MP Rear Camera | Android v13.0 | Bluetooth
# 944                                                                                                                    Dual Sim, 4G | 1.3 MHz Processor | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery | 2.4 inches, 240 x 320 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 32 MB | Symbian v9.1
# 945                                                                                                                                                                                       32 MB RAM, 32 MB inbuilt | 1000 mAh Battery | 1.77 inches Display | No Rear Camera | Memory Card Supported, upto 32 GB
# 949                                                                                                                Dual Sim | 1 MHz Processor | 32 MB RAM, 32 MB inbuilt | 3000 mAh Battery | 1.8 inches, 240 x 320 px Display | 0.3 MP Rear & 0.3 MP Front Camera | Memory Card Supported, upto 32 GB | Symbian
# 950                                                                                                                                 Triple Sim | No Wifi | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery | 2.4 inches, 320 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 16 GB | Symbian v30
# 952                                                                                                            Dual Sim | Single Core, 1.5 MHz Processor | 4 MB RAM, 32 MB inbuilt | 1200 mAh Battery | 2.4 inches, 120 x 240 px Display | Digital Rear Camera | Memory Card Supported, upto 32 GB | No FM Radio
# 959                                                                                                                                                          Dual Sim | 1.5 MHz Processor | 4 MB RAM, 32 GB inbuilt | 800 mAh Battery | 1.8 inches, 160 x 128 px Display | No Rear Camera | Memory Card (Hybrid)
# 961                                                                                                                                  Dual Sim, 4G, VoLTE | 1.77 MHz Processor | 32 MB RAM, 32 MB inbuilt | 3000 mAh Battery | 2.8 inches, 320 x 240 px Display | 1.3 MP Rear Camera | Memory Card (Hybrid) | v30
# 966                                                                                                                                               Dual Sim | 32 MB RAM, 32 MB inbuilt | 2575 mAh Battery | 2.4 inches, 320 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 968                                                                                                                                                                   Dual Sim, 3G, 4G | 512 MB RAM | 3500 mAh Battery | 2.8 inches Display | 0.6 MP Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 970                                                                                                                                               Quad Sim | 32 MB RAM, 32 MB inbuilt | 2500 mAh Battery | 2.4 inches, 128 x 160 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 64 GB | Bluetooth
# 974                                                                                                                                     Dual Sim | Single Core, 1.2 MHz Processor | 32 MB RAM, 32 MB inbuilt | 1750 mAh Battery | 2.4 inches, 320 x 240 px Display | 0.08 MP Rear Camera | Memory Card Supported
# 989                                                                                                                                                                          Dual Sim | 1.3 MHz Processor | 32 MB RAM, 32 MB inbuilt | 1000 mAh Battery | 1.77 inches, 128 x 160 px Display | 1.3 MP Rear Camera
# 990                                                                                                                                                        Dual Sim | 1.3 MHz Processor | 32 MB RAM, 32 MB inbuilt | 1000 mAh Battery | 1.8 inches, 320 x 480 px Display | 0.3 MP Rear Camera | v. | No FM Radio
# 995                                                                                                                                                                   Dual Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 1.8 inches, 120 x 160 px Display | No Rear Camera | Memory Card Supported
# 997                                                                                                                                                                   Dual Sim | No Wifi | 4 MB RAM, 4 MB inbuilt | 1000 mAh Battery | 2 inches, 120 x 160 px Display | Memory Card Supported, upto 32 GB | RTOS
# 1001                                                                                                                                                     Dual Sim | 4 MB RAM, 4 MB inbuilt | 800 mAh Battery | 1.8 inches, 160 x 128 px Display | No Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 1002                                                                                                                                                Dual Sim | 4 MB RAM, 4 MB inbuilt | 1750 mAh Battery | 1.8 inches, 160 x 128 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
# 1019                                                                                                                                              Dual Sim | 32 MB RAM, 32 MB inbuilt | 1900 mAh Battery | 2.8 inches, 320 x 240 px Display | 0.3 MP Rear Camera | Memory Card Supported, upto 32 GB | Bluetooth
#
#         device_type
# 209      smartphone
# 353      smartphone
# 404   feature_phone
# 437   feature_phone
# 445   feature_phone
# 461      smartphone
# 527   feature_phone
# 540   feature_phone
# 558   feature_phone
# 562   feature_phone
# 663   feature_phone
# 665      smartphone
# 676   feature_phone
# 678   feature_phone
# 684   feature_phone
# 686   feature_phone
# 711   feature_phone
# 714   feature_phone
# 715   feature_phone
# 718   feature_phone
# 768   feature_phone
# 822   feature_phone
# 824      smartphone
# 828   feature_phone
# 829   feature_phone
# 832   feature_phone
# 835   feature_phone
# 875   feature_phone
# 876   feature_phone
# 883   feature_phone
# 886   feature_phone
# 941   feature_phone
# 942   feature_phone
# 943   feature_phone
# 944   feature_phone
# 945   feature_phone
# 949   feature_phone
# 950   feature_phone
# 952   feature_phone
# 959   feature_phone
# 961   feature_phone
# 966   feature_phone
# 968   feature_phone
# 970   feature_phone
# 974   feature_phone
# 989   feature_phone
# 990   feature_phone
# 995   feature_phone
# 997   feature_phone
# 1001  feature_phone
# 1002  feature_phone
# 1019  feature_phone

# %%
import re

def extract_processor_comprehensive(spec_text):
    """
    Comprehensive processor extraction searching entire Specifications text.
    Uses advanced regex patterns to identify processor brands/models anywhere in the spec.
    """
    if pd.isna(spec_text):
        return None
    
    spec_text = str(spec_text)
    
    # Comprehensive processor patterns - ordered by specificity (most specific first)
    patterns = [
        # Google Tensor
        (r'Tensor\s+G\d+', lambda m: m.group(0)),
        
        # Qualcomm Snapdragon (all variants)
        (r'Snapdragon\s+\d+\s*(?:Elite|Plus|Ultra)', lambda m: m.group(0)),
        (r'Snapdragon\s+\d+[a-z]\s+Gen\s*\d+', lambda m: m.group(0)),
        (r'Snapdragon\s+\d+\s+Gen\s*\d+', lambda m: m.group(0)),
        (r'Snapdragon\s+\d+', lambda m: m.group(0)),
        
        # MediaTek Dimensity
        (r'Dimensity\s+\d+(?:\s+(?:Plus|Ultra|Energy|Ultimate))?', lambda m: m.group(0)),
        
        # MediaTek Helio  
        (r'Helio\s+[A-Z]\d+(?:\s+(?:Plus|Ultra))?', lambda m: m.group(0)),
        
        # Samsung Exynos
        (r'Exynos\s+\d+', lambda m: m.group(0)),
        
        # Unisoc (all variants - very specific patterns first)
        (r'Unisoc\s+\d+\s+FF[\-\s]*[A-Z]', lambda m: m.group(0).replace(' ', ' ').strip()),  # "8910 FF-S"
        (r'Unisoc\s+SC\d+[A-Z]+', lambda m: m.group(0)),  # "SC6531E"
        (r'Unisoc\s+T\d+[A-Z]?', lambda m: m.group(0)),  # "T7250"
        (r'Unisoc\s+[A-Z]?\d+[\w\-]*(?=\s|,|$)', lambda m: m.group(0)),  # Other Unisoc variants
        (r'\bUnisoc\b(?=\s*,|\s+\d|\s*$)', lambda m: 'Unisoc'),  # Just "Unisoc" alone
        
        # Apple (various formats)
        (r'Bionic\s+A\d+(?:\s+Pro)?', lambda m: m.group(0)),
        (r'Apple\s+A\d+(?:\s+Pro)?', lambda m: m.group(0)),
        (r'A\d+\s+Bionic', lambda m: m.group(0)),
        
        # Huawei Kirin
        (r'Kirin\s+\d+', lambda m: m.group(0)),
        
        # General MediaTek
        (r'MediaTek\s+\w+\d+', lambda m: m.group(0)),
    ]
    
    # Try each pattern
    for pattern, formatter in patterns:
        match = re.search(pattern, spec_text, re.IGNORECASE)
        if match:
            processor = formatter(match)
            # Normalize spacing
            processor = re.sub(r'\s+', ' ', processor).strip()
            return processor
    
    return None


print("="*80)
print("STEP 1: Filling NULL processor names from Specifications")
print("="*80)

null_count_before = df['processor_name'].isna().sum()
filled_from_spec = 0

for idx in df[df['processor_name'].isna()].index:
    spec = df.loc[idx, 'Specifications']
    extracted = extract_processor_comprehensive(spec)
    
    if extracted:
        print(f"  ✓ {df.loc[idx, 'Product_Name'][:60]:<60} → {extracted}")
        df.loc[idx, 'processor_name'] = extracted
        filled_from_spec += 1

print(f"\n✓ Filled {filled_from_spec} null values")
print(f"✗ Remaining nulls: {df['processor_name'].isna().sum()} (likely basic phones without processor info)")


print("\n" + "="*80)
print("STEP 2: Fixing WRONG processor names (Octa Core, No Wifi, etc.)")
print("="*80)

wrong_values = ['Octa Core', 'No Wifi', 'Quad Core', 'Single Core', 'Dual Core', 'Hexa Core']
fixed_count = 0

for wrong_val in wrong_values:
    wrong_indices = df[df['processor_name'] == wrong_val].index
    
    if len(wrong_indices) > 0:
        print(f"\nFixing '{wrong_val}' ({len(wrong_indices)} cases):")
        
        for idx in wrong_indices:
            spec = df.loc[idx, 'Specifications']
            extracted = extract_processor_comprehensive(spec)
            
            if extracted:
                print(f"  ✓ {df.loc[idx, 'Product_Name'][:50]:<50} '{wrong_val}' → '{extracted}'")
                df.loc[idx, 'processor_name'] = extracted
                fixed_count += 1
            else:
                print(f"  ✗ {df.loc[idx, 'Product_Name'][:50]:<50} No valid processor found → set to NULL")
                df.loc[idx, 'processor_name'] = None


print("\n" + "="*80)
print("FINAL SUMMARY")
print("="*80)
print(f"Initial null count: {null_count_before}")
print(f"Filled from Specifications: {filled_from_spec}")
print(f"Fixed wrong values: {fixed_count}")
print(f"Final null count: {df['processor_name'].isna().sum()}")

print(f"\n✓ Top 15 processor names after cleaning:")
print(df['processor_name'].value_counts().head(15))
# Out:
# ================================================================================
# STEP 1: Filling NULL processor names from Specifications
# ================================================================================
#   ✓ Google Pixel 8A                                              → Tensor G3
#   ✓ Google Pixel 8 5G                                            → Tensor G3
#   ✓ Google Pixel 8 Pro                                           → Tensor G3
#   ✓ Motorola Moto A100                                           → Unisoc
#   ✓ HMD 102 4G                                                   → Unisoc 8910 FF-S
#   ✓ HMD 101 4G                                                   → Unisoc 8910 FF-S
#   ✓ Philips E2102                                                → Unisoc SC6531E
#
# ✓ Filled 7 null values
# ✗ Remaining nulls: 45 (likely basic phones without processor info)
#
# ================================================================================
# STEP 2: Fixing WRONG processor names (Octa Core, No Wifi, etc.)
# ================================================================================
#
# Fixing 'Octa Core' (3 cases):
#   ✗ Lava Bold N1 Lite                                  No valid processor found → set to NULL
#   ✗ Lava O3                                            No valid processor found → set to NULL
#   ✗ Lava O3                                            No valid processor found → set to NULL
#
# Fixing 'No Wifi' (2 cases):
#   ✗ Motorola Moto A300                                 No valid processor found → set to NULL
#   ✗ Snexian Bold 40K                                   No valid processor found → set to NULL
#
# ================================================================================
# FINAL SUMMARY
# ================================================================================
# Initial null count: 52
# Filled from Specifications: 7
# Fixed wrong values: 0
# Final null count: 50
#
# ✓ Top 15 processor names after cleaning:
# processor_name
# Dimensity 6300         120
# Dimensity 7300          28
# Snapdragon 4 Gen2       24
# Snapdragon 7 Gen3       22
# Snapdragon 7s Gen3      18
# Snapdragon 8s Gen3      18
# Dimensity 6100 Plus     18
# Snapdragon 695          17
# Exynos 1380             17
# Snapdragon 8 Elite      15
# Dimensity 7400          15
# Dimensity 7050          14
# Snapdragon 7s Gen2      14
# Snapdragon 8 Gen3       13
# Snapdragon 7 Gen4       13
# Name: count, dtype: int64

# %%
df['processor_name'].isnull().sum()
# Out:
# np.int64(50)

# %%
df['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 6300              120
# Dimensity 7300               28
# Snapdragon 4 Gen2            24
# Snapdragon 7 Gen3            22
# Snapdragon 7s Gen3           18
# Snapdragon 8s Gen3           18
# Dimensity 6100 Plus          18
# Snapdragon 695               17
# Exynos 1380                  17
# Snapdragon 8 Elite           15
# Dimensity 7400               15
# Dimensity 7050               14
# Snapdragon 7s Gen2           14
# Snapdragon 8 Gen3            13
# Snapdragon 7 Gen4            13
# Dimensity 7300 Ultimate      12
# Snapdragon 6 Gen1            12
# Snapdragon 8s Gen4           10
# Snapdragon 6s Gen3           10
# Dimensity 7300 Energy        10
# Apple A19 Pro                10
# Dimensity 8350               10
# Exynos 1330                  10
# Dimensity 6400                9
# Snapdragon 7s Gen 2           9
# Snapdragon 8 Gen2             9
# Bionic A18                    9
# Unisoc T7250                  9
# Exynos 2400                   9
# Dimensity 6080                8
# Dimensity 7020                8
# Helio G85                     8
# Snapdragon 8 Elite Gen 5      7
# Exynos 1480                   7
# Snapdragon 8Elite             7
# Dimensity 9500                7
# Bionic A18 Pro                7
# Snapdragon 7 Gen1             7
# Dimensity 8200                7
# Snapdragon 680                7
# Helio                         7
# Dimensity 6020                7
# Snapdragon 8 Gen1             6
# Snapdragon 7+ Gen3            6
# Snapdragon 870                6
# Snapdragon 8 Gen 2            6
# Dimensity 7025 Ultra          6
# Dimensity 7400 Ultra          6
# Tensor G4                     6
# Unisoc T606                   5
# Dimensity 1080                5
# Snapdragon 8+ Gen1            5
# Unisoc T612                   5
# Unisoc T760                   5
# Dimensity 9300 Plus           5
# Dimensity 9400                5
# Helio G36                     5
# Snapdragon 4s Gen2            5
# Dimensity 9200 Plus           5
# Dimensity 6400 Max            5
# Snapdragon 6 Gen4             5
# Dimensity 7025                4
# Helio G99                     4
# Tensor G5                     4
# Dimensity 9400e               4
# Dimensity 8450                4
# Bionic A15                    4
# Dimensity 7300 Ultra          4
# Dimensity 7300 Pro            4
# Unisoc T765                   4
# Helio G35                     4
# Dimensity 7300 E              4
# Unisoc T615                   4
# Dimensity 7200                4
# Dimensity  8100               3
# Unisoc T603                   3
# Exynos 1280                   3
# Unisoc T107                   3
# Snapdragon 8 Gen 3            3
# Dimensity 700 5G              3
# Dimensity 8400-MAX            3
# Snapdragon 6 Gen3             3
# Snapdragon 7s Gen 3           3
# Exynos 1580                   3
# Dimensity 7300 Plus           3
# Snapdragon 7 Gen 4            3
# Dimensity 8350 Ultra          3
# Bionic A16                    3
# Dimensity 8350 Extreme        3
# Dimensity 7360 Turbo          3
# Dimensity 8350 Apex           3
# Helio G88                     3
# Snapdragon 888                3
# Dimensity 1300                3
# Unisoc 6531F                  3
# Tensor G3                     3
# Snapdragon 778G Plus          3
# Helio  G96                    3
# Dimensity 7060                3
# Dimensity 7200 Pro            3
# Snapdragon  732G              3
# Dimensity 8100 Max            3
# Dimensity 7200 Ultra          3
# Dimensity 7300X               3
# Snapdragon  695               2
# Snapdragon  680               2
# Unisoc 8910 FF-S              2
# Snapdragon 4 Gen2 AE          2
# Snapdragon 4 Gen 2 AE         2
# Exynos 2400e                  2
# Dimensity 8400 Ultra          2
# Apple A19                     2
# Tensor                        2
# Exynos 2100                   2
# Snapdragon 8 Gen5             2
# Dimensity 7030                2
# Snapdragon  8 Gen1            2
# Dimensity 8020                2
# Dimensity 7400X               2
# Snapdragon 4 Gen 1            2
# Unisoc 6533G                  2
# Snapdragon  888               2
# Dimensity 7350 Pro 5G         2
# Snapdragon 6s 4G Gen1         2
# Unisoc T127                   2
# Unisoc T8200                  2
# Unisoc UMS9230E               2
# Dimensity 8300 Ultra          2
# Dimensity 8350 Ultimate       2
# Snapdragon  8+ Gen1           2
# Helio G50                     2
# Snapdragon 4 Gen1             2
# Snapdragon 778G               2
# Dimensity 800U                2
# Exynos 2500                   2
# Snapdragon 435                2
# Snapdragon  662               2
# Dimensity  810 5G             2
# Snapdragon 636                2
# Snapdragon 6s Gen4            1
# Helio G81                     1
# Snapdragon 665                1
# Google Tensor G2              1
# Spreadtrum                    1
# Dimensity 9300                1
# Helio G81 Ultra               1
# MTK6739                       1
# Dimensity 8200 Ultimate       1
# Snapdragon 7 Gen1 AE          1
# Google  Tensor G2             1
# Exynos 2200                   1
# Snapdragon 855+               1
# Dimensity 9000                1
# Unisoc T7225                  1
# Snapdragon 710                1
# MTK MT6739                    1
# Snapdragon 888+               1
# Google  Tensor                1
# Snapdragon 778G+              1
# Dimensity 9000 Plus           1
# Tensor G2                     1
# Snapdragon 845                1
# Helio G96                     1
# Dimensity  900                1
# Snapdragon 782G               1
# Bionic A17 Pro                1
# Snapdragon 732G               1
# A13 Bionic                    1
# Qualcomm Snapdragon 625       1
# Exynos 850                    1
# Unisoc 9863A                  1
# Helio  G85                    1
# Dimensity 930                 1
# Helio 6739                    1
# Unisoc                        1
# Snapdragon 865                1
# Dimensity 700                 1
# Unisoc SC6531E                1
# Exynos 9825                   1
# Dimensity 900                 1
# Exynos 9611                   1
# Tiger T612                    1
# Helio G91                     1
# Tiger T616                    1
# Helio  G99                    1
# Helio G95                     1
# Snapdragon 765G               1
# Snapdragon  778G              1
# Dimensity  920 5G             1
# Helio  G95                    1
# Snapdragon 720G               1
# Helio  G90T                   1
# Unisoc T7100                  1
# UNISOC T7100                  1
# Helio MT6737                  1
# AMD                           1
# Snapdragon 6s Gen1 4G         1
# Name: count, dtype: int64

# %% [markdown]
# <span style="font-size: 18px;"> <b>Extracting Processor Brand

# %%
import re


def extract_processor_brand(processor_name):
    """
    Extract processor brand from processor name.
    Handles various formats including prefixes like 'Google', 'Qualcomm', etc.
    """
    if pd.isna(processor_name):
        return None
    
    processor_name = str(processor_name).strip()
    
    # Brand patterns - ordered by specificity
    brand_patterns = [
        # Google Tensor (with or without "Google" prefix)
        (r'Google\s+Tensor|^Tensor', 'Tensor'),
        
        # Qualcomm Snapdragon (with or without "Qualcomm" prefix)
        (r'Qualcomm\s+Snapdragon|^Snapdragon', 'Snapdragon'),
        
        # MediaTek variants
        (r'^Dimensity', 'Dimensity'),
        (r'^Helio', 'Helio'),
        (r'^MTK|^MediaTek', 'MediaTek'),
        
        # Samsung
        (r'^Exynos', 'Exynos'),
        
        # Unisoc (including old Spreadtrum and Tiger series)
        (r'^Unisoc|^Spreadtrum|^Tiger', 'Unisoc'),
        
        # Apple (various formats)
        (r'^Bionic|^Apple|^A\d+\s+Bionic', 'Apple'),
        
        # Others
        (r'^Kirin', 'Kirin'),
        (r'^AMD', 'AMD'),
    ]
    
    for pattern, brand in brand_patterns:
        if re.match(pattern, processor_name, re.IGNORECASE):
            return brand
    
    # If no pattern matches and it's a wrong value, return None
    if processor_name.lower() in ['no wifi', 'octa core', 'quad core', 'single core', 'dual core', 'hexa core']:
        return None
    
    return None

# Create processor_brand column
df['processor_brand'] = df['processor_name'].apply(extract_processor_brand)

# Get position of processor_name and insert processor_brand right after it
proc_name_idx = df.columns.get_loc('processor_name')
cols = df.columns.tolist()
cols.remove('processor_brand')
cols.insert(proc_name_idx + 1, 'processor_brand')
df = df[cols]

print("✓ Created processor_brand column next to processor_name")
print(f"\nColumn order: {df.columns[proc_name_idx:proc_name_idx+3].tolist()}")

print("\n" + "="*80)
print("Processor brand distribution:")
print("="*80)
print(df['processor_brand'].value_counts())

print(f"\n✓ Null processor_brand count: {df['processor_brand'].isna().sum()}")
# Out:
# ✓ Created processor_brand column next to processor_name
#
# Column order: ['processor_name', 'processor_brand', 'cores']
#
# ================================================================================
# Processor brand distribution:
# ================================================================================
# processor_brand
# Dimensity     407
# Snapdragon    338
# Unisoc         60
# Exynos         59
# Helio          47
# Apple          37
# Tensor         19
# MediaTek        2
# AMD             1
# Name: count, dtype: int64
#
# ✓ Null processor_brand count: 50

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# Dimensity     407
# Snapdragon    338
# Unisoc         60
# Exynos         59
# Helio          47
# Apple          37
# Tensor         19
# MediaTek        2
# AMD             1
# Name: count, dtype: int64

# %% [markdown]
# <span style="font-size: 18px;"> <b> Cores column

# %%
df['cores'].isnull().sum() # most of the phone are feature phones that why cores missing
# Out:
# np.int64(56)

# %%
df['cores'].value_counts()
# Out:
# cores
# Octa Core      899
# Hexa Core       37
# Single Core     13
# Deca Core       11
# Nine Core        2
# Quad Core        2
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Product_Name', 'brand_name', 'Price', 'Rating', 'Spec_Score',
#        'has_dual_sim', 'has_3g', 'has_4g', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'processor_brand', 'cores',
#        'cpu_speed_ghz', 'ram_gb', 'rom_gb', 'battery_capacity_mah',
#        'fast_charging_available', 'fast_charging_speed_w',
#        'display_size_inches', 'resolution_width', 'resolution_height',
#        'display_frequency_hz', 'front_camera_mp', 'front_camera_secondary_mp',
#        'rear_camera_mp', 'rear_camera_secondary_mp', 'rear_camera_tertiary_mp',
#        'rear_camera_count', 'card_supported', 'operating_system',
#        'Product_Link', 'Image_URL', 'Specifications', 'device_type'],
#       dtype='object')

# %%
null_value_series = df[df['cores'].isnull()]

# %%
null_value_series[null_value_series['Specifications'].str.contains('Nine-Cores')]
# Out:
#         Product_Name brand_name  Price  Rating  Spec_Score  has_dual_sim  \
# 209  Google Pixel 8A     google  39999    4.65          76             1
#
#      has_3g  has_4g  has_5g  has_nfc  has_ir_blaster processor_name  \
# 209       1       1       1        1               0      Tensor G3
#
#     processor_brand cores  cpu_speed_ghz  ram_gb  rom_gb  \
# 209          Tensor   NaN            3.0     8.0   128.0
#
#      battery_capacity_mah  fast_charging_available  fast_charging_speed_w  \
# 209                  4492                        1                    NaN
#
#      display_size_inches  resolution_width  resolution_height  \
# 209                  6.1            1080.0             2400.0
#
#      display_frequency_hz  front_camera_mp  front_camera_secondary_mp  \
# 209                 120.0             13.0                        0.0
#
#      rear_camera_mp  rear_camera_secondary_mp  rear_camera_tertiary_mp  \
# 209            64.0                      13.0                     13.0
#
#      rear_camera_count  card_supported operating_system  \
# 209                  2               0      Android v14
#
#                                                        Product_Link  \
# 209  https://www.smartprix.com/mobiles/google-pixel-8a-ppd12mhj2qa8
#
#                                                                   Image_URL  \
# 209  https://cdn1.smartprix.com/rx-ia0GcyTg0-w280-h280/google-pixel-8a.webp
#
#                                                                                                                                                                                                                                                                                               Specifications  \
# 209  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Tensor G3, Nine-Cores, 3 GHz Processor | 8 GB RAM, 128 GB inbuilt | 4492 mAh Battery with Fast Charging | 6.1 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole | 64 MP + 13 MP Dual Rear & 13 MP Front Camera | Memory Card Not Supported | Android v14
#
#     device_type
# 209  smartphone

# %%
df.loc[209,'cores'] = 'Nine Core'

# %%
df['cores'].value_counts()
# Out:
# cores
# Octa Core      899
# Hexa Core       37
# Single Core     13
# Deca Core       11
# Nine Core        3
# Quad Core        2
# Name: count, dtype: int64

# %% [markdown]
# <span style="font-size: 18px;"> <b>Processor Speed

# %%
df['cpu_speed_ghz'].isnull().sum()
# Out:
# np.int64(77)

# %%
df['cpu_speed_ghz'].value_counts() # only take three digit after the decimal
# Out:
# cpu_speed_ghz
# 2.40000    209
# 2.50000    119
# 2.20000    109
# 3.20000     43
# 2.60000     42
# 3.00000     34
# 2.00000     34
# 2.80000     33
# 2.30000     31
# 3.35000     28
# 1.80000     25
# 2.63000     22
# 3.30000     15
# 3.25000     15
# 3.10000     14
# 4.47000     13
# 4.04000      9
# 4.32000      9
# 2.85000      9
# 0.00130      8
# 2.70000      8
# 4.05000      7
# 4.60000      7
# 4.21000      7
# 2.84000      6
# 2.90000      6
# 1.60000      6
# 2.05000      6
# 3.36000      5
# 3.63000      5
# 0.51200      5
# 3.78000      5
# 1.00000      4
# 0.00150      4
# 0.00100      4
# 3.22000      4
# 3.40000      4
# 3.46000      3
# 0.00120      3
# 3.39000      3
# 3.84000      2
# 3.11000      2
# 2.10000      2
# 1.40000      2
# 0.20800      2
# 3.05000      1
# 2.96000      1
# 0.25600      1
# 1.70000      1
# 2.73000      1
# 2.65000      1
# 1.82000      1
# 0.00500      1
# 1.25000      1
# 0.00177      1
# Name: count, dtype: int64

# %%
df['cpu_speed_ghz'] = df['cpu_speed_ghz'].round(3)

# %%
df['cpu_speed_ghz'].isnull().sum() # cpu clock is not given that why values are empty
# Out:
# np.int64(77)

# %% [markdown]
# <span style="font-size: 18px;"> <b>Dealing with RAM and ROM

# %%
df.columns
# Out:
# Index(['Product_Name', 'brand_name', 'Price', 'Rating', 'Spec_Score',
#        'has_dual_sim', 'has_3g', 'has_4g', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'processor_brand', 'cores',
#        'cpu_speed_ghz', 'ram_gb', 'rom_gb', 'battery_capacity_mah',
#        'fast_charging_available', 'fast_charging_speed_w',
#        'display_size_inches', 'resolution_width', 'resolution_height',
#        'display_frequency_hz', 'front_camera_mp', 'front_camera_secondary_mp',
#        'rear_camera_mp', 'rear_camera_secondary_mp', 'rear_camera_tertiary_mp',
#        'rear_camera_count', 'card_supported', 'operating_system',
#        'Product_Link', 'Image_URL', 'Specifications', 'device_type'],
#       dtype='object')

# %%
df['ram_gb'].isnull().sum()
# Out:
# np.int64(7)

# %%
df['ram_gb'].value_counts()
# Out:
# ram_gb
# 8.000     418
# 12.000    189
# 6.000     150
# 4.000     142
# 16.000     36
# 3.000      18
# 0.004      16
# 0.031      15
# 0.500       7
# 2.000       5
# 0.062       4
# 0.008       4
# 0.125       2
# 32.000      1
# 18.000      1
# 24.000      1
# 0.010       1
# 0.035       1
# 0.023       1
# 0.055       1
# Name: count, dtype: int64

# %%
df.loc[128, 'ram_gb'] = 8
df.loc[322, 'ram_gb'] = 8
df.loc[844, 'ram_gb'] = 8 # filling ram in the apple phone

# %%
df[df['ram_gb'].isnull()]
# Out:
#                       Product_Name brand_name  Price  Rating  Spec_Score  \
# 527  Samsung Guru Music 2 Dual Sim    samsung    777    4.50          11
# 678                 Lava Action 4G       lava   1799    4.45          17
# 829                     HMD 101 4G        hmd   1899    4.75          12
# 942                    Mixx M1 312       mixx    628    4.30          16
#
#      has_dual_sim  has_3g  has_4g  has_5g  has_nfc  has_ir_blaster  \
# 527             1       0       0       0        0               0
# 678             1       1       1       0        0               0
# 829             1       0       1       0        0               0
# 942             1       0       1       0        0               0
#
#        processor_name processor_brand        cores  cpu_speed_ghz  ram_gb  \
# 527               NaN            None  Single Core          0.208     NaN
# 678               NaN            None          NaN            NaN     NaN
# 829  Unisoc 8910 FF-S          Unisoc          NaN            NaN     NaN
# 942               NaN            None          NaN          0.005     NaN
#
#      rom_gb  battery_capacity_mah  fast_charging_available  \
# 527     NaN                   800                        0
# 678     NaN                  1000                        0
# 829     NaN                  1000                        0
# 942    32.0                  1000                        0
#
#      fast_charging_speed_w  display_size_inches  resolution_width  \
# 527                    0.0                  2.0             128.0
# 678                    0.0                  1.8             240.0
# 829                    0.0                  2.0               NaN
# 942                    0.0                  1.8               NaN
#
#      resolution_height  display_frequency_hz  front_camera_mp  \
# 527              160.0                   NaN              NaN
# 678              260.0                   NaN              NaN
# 829                NaN                   NaN              NaN
# 942                NaN                   NaN              NaN
#
#      front_camera_secondary_mp  rear_camera_mp  rear_camera_secondary_mp  \
# 527                        0.0             0.0                       0.0
# 678                        0.0             3.0                       0.0
# 829                        0.0             0.0                       0.0
# 942                        0.0             2.0                       0.0
#
#      rear_camera_tertiary_mp  rear_camera_count  card_supported  \
# 527                      0.0                  0               1
# 678                      0.0                  1               1
# 829                      0.0                  0               1
# 942                      0.0                  1               1
#
#     operating_system  \
# 527              NaN
# 678              NaN
# 829              NaN
# 942              NaN
#
#                                                                      Product_Link  \
# 527  https://www.smartprix.com/mobiles/samsung-guru-music-2-dual-sim-p1101jjovdk3
# 678                 https://www.smartprix.com/mobiles/lava-action-4g-ppd1mzwuv6yf
# 829                     https://www.smartprix.com/mobiles/hmd-101-4g-ppd1t11nv2r0
# 942                    https://www.smartprix.com/mobiles/mixx-m1-312-ppd1s49jh1q7
#
#                                                                        Image_URL  \
# 527  https://cdn1.smartprix.com/rx-iprrtYYqo-w280-h280/samsung-guru-music-2.webp
# 678        https://cdn1.smartprix.com/rx-iYY7Ls8Yv-w280-h280/lava-action-4g.webp
# 829            https://cdn1.smartprix.com/rx-inTtxKZX0-w280-h280/hmd-101-4g.webp
# 942           https://cdn1.smartprix.com/rx-izzysWtrU-w280-h280/mixx-m1-312.webp
#
#                                                                                                                                                   Specifications  \
# 527  Dual Sim | No Wifi | Single Core, 208 MHz Processor | 800 mAh Battery | 2 inches, 128 x 160 px Display | No Rear Camera | Memory Card Supported, upto 16 GB
# 678                       Dual Sim, 3G, 4G, VoLTE | 1000 mAh Battery | 1.8 inches, 240 x 260 px Display | 0.3 MP Rear Camera | Memory Card Supported | Bluetooth
# 829               Dual Sim, 4G | Unisoc 8910 FF-S | 1000 mAh Battery | 2 inches Display | No Rear Camera | Memory Card Supported, upto 32 GB | S30+​ | Bluetooth
# 942                                      Dual Sim, 4G | 5 MHz Processor | 32 GB inbuilt | 1000 mAh Battery | 1.8 inches Display | 2 MP Rear Camera | No FM Radio
#
#        device_type
# 527  feature_phone
# 678  feature_phone
# 829  feature_phone
# 942  feature_phone

# %%
df['ram_gb'].isnull().sum()
# Out:
# np.int64(4)

# %%
df['rom_gb'].isnull().sum()
# Out:
# np.int64(6)

# %%
df['rom_gb'].value_counts()
# Out:
# rom_gb
# 128.000     450
# 256.000     320
# 512.000      89
# 64.000       80
# 0.031        19
# 0.004        11
# 1000.000     10
# 32.000        7
# 4.000         6
# 16.000        6
# 0.016         3
# 0.035         3
# 0.125         3
# 0.062         2
# 0.008         2
# 2000.000      1
# 3.000         1
# 0.002         1
# Name: count, dtype: int64

# %% [markdown]
# <span style="font-size: 18px;"> <b>Dealing with Battery and fast charging

# %%
df.columns
# Out:
# Index(['Product_Name', 'brand_name', 'Price', 'Rating', 'Spec_Score',
#        'has_dual_sim', 'has_3g', 'has_4g', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'processor_brand', 'cores',
#        'cpu_speed_ghz', 'ram_gb', 'rom_gb', 'battery_capacity_mah',
#        'fast_charging_available', 'fast_charging_speed_w',
#        'display_size_inches', 'resolution_width', 'resolution_height',
#        'display_frequency_hz', 'front_camera_mp', 'front_camera_secondary_mp',
#        'rear_camera_mp', 'rear_camera_secondary_mp', 'rear_camera_tertiary_mp',
#        'rear_camera_count', 'card_supported', 'operating_system',
#        'Product_Link', 'Image_URL', 'Specifications', 'device_type'],
#       dtype='object')

# %%
df['battery_capacity_mah'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['battery_capacity_mah'].value_counts()
# Out:
# battery_capacity_mah
# 5000    374
# 6000    114
# 5500     71
# 7000     67
# 6500     29
# 4500     23
# 4000     19
# 1000     19
# 5200     18
# 5160     14
# 5100     14
# 2000     12
# 4400     11
# 4700     10
# 4600     10
# 800       8
# 2500      8
# 5800      8
# 7300      8
# 5700      7
# 1450      7
# 3000      7
# 5110      6
# 5600      6
# 4900      6
# 6200      5
# 5020      4
# 4800      4
# 6300      4
# 5030      4
# 3582      4
# 3900      4
# 4832      4
# 6800      3
# 6040      3
# 7100      3
# 6400      3
# 4100      3
# 4300      3
# 3700      3
# 4674      3
# 4005      3
# 3561      3
# 3149      3
# 4685      3
# 3988      3
# 6550      2
# 7400      2
# 7025      2
# 3692      2
# 5850      2
# 7550      2
# 3349      2
# 3279      2
# 4200      2
# 1750      2
# 4520      2
# 5010      2
# 4805      2
# 4830      2
# 5060      2
# 5400      2
# 5003      2
# 3240      1
# 6510      1
# 6720      1
# 4383      1
# 7500      1
# 5240      1
# 5050      1
# 4020      1
# 5910      1
# 4410      1
# 1950      1
# 4385      1
# 4575      1
# 4610      1
# 6600      1
# 4492      1
# 4970      1
# 4870      1
# 5750      1
# 4310      1
# 5630      1
# 4355      1
# 1050      1
# 4820      1
# 4325      1
# 5015      1
# 4650      1
# 4441      1
# 4720      1
# 3110      1
# 5080      1
# 4980      1
# 3300      1
# 4250      1
# 1200      1
# 2575      1
# 3500      1
# 1900      1
# Name: count, dtype: int64

# %%
df['fast_charging_available'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['fast_charging_available'].value_counts()
# Out:
# fast_charging_available
# 1    941
# 0     79
# Name: count, dtype: int64

# %%
df['fast_charging_speed_w'].isnull().sum()
# Out:
# np.int64(53)

# %%
temp_df = df[df['fast_charging_available'] == 1]

# %%
temp_df['fast_charging_speed_w'].isnull().sum()
# Out:
# np.int64(53)

# %%
temp_df['fast_charging_speed_w'].value_counts() # zeros are only in the non fast charging phones
# Out:
# fast_charging_speed_w
# 45.0     137
# 80.0     125
# 25.0     104
# 33.0      92
# 18.0      73
# 90.0      53
# 15.0      52
# 44.0      44
# 67.0      37
# 120.0     34
# 100.0     25
# 10.0      22
# 30.0      19
# 68.0      15
# 60.0      10
# 66.0       8
# 65.0       8
# 50.0       7
# 20.0       6
# 70.0       3
# 37.0       2
# 27.0       2
# 125.0      2
# 35.0       2
# 150.0      2
# 75.0       2
# 23.0       1
# 5.0        1
# Name: count, dtype: int64

# %%
# checking for null values in fast charging speed then checking value count in fast charging speed
df[df['fast_charging_speed_w'].isnull()].head()
# Out:
#                Product_Name brand_name   Price  Rating  Spec_Score  \
# 14          Apple iPhone 17      apple   82900    4.60          79
# 25          Apple iPhone 16      apple   64590    4.75          85
# 46  Apple iPhone 17 Pro Max      apple  149900    4.25          82
# 49          Apple iPhone 15      apple   54790    4.65          81
# 72      Apple iPhone 16 Pro      apple  103990    4.25          87
#
#     has_dual_sim  has_3g  has_4g  has_5g  has_nfc  has_ir_blaster  \
# 14             1       1       1       1        1               0
# 25             1       1       1       1        1               0
# 46             1       1       1       1        1               0
# 49             1       1       1       1        1               0
# 72             1       1       1       1        1               0
#
#     processor_name processor_brand      cores  cpu_speed_ghz  ram_gb  rom_gb  \
# 14       Apple A19           Apple  Hexa Core            NaN     8.0   256.0
# 25      Bionic A18           Apple  Hexa Core           4.04     8.0   128.0
# 46   Apple A19 Pro           Apple  Hexa Core            NaN    12.0   256.0
# 49      Bionic A16           Apple  Hexa Core           3.46     6.0   128.0
# 72  Bionic A18 Pro           Apple  Hexa Core           4.05     8.0   128.0
#
#     battery_capacity_mah  fast_charging_available  fast_charging_speed_w  \
# 14                  3692                        1                    NaN
# 25                  3561                        1                    NaN
# 46                  4832                        1                    NaN
# 49                  3349                        1                    NaN
# 72                  3582                        1                    NaN
#
#     display_size_inches  resolution_width  resolution_height  \
# 14                  6.3            1206.0             2622.0
# 25                  6.1            1179.0             2556.0
# 46                  6.9            1320.0             2868.0
# 49                  6.1            1179.0             2556.0
# 72                  6.3            1206.0             2622.0
#
#     display_frequency_hz  front_camera_mp  front_camera_secondary_mp  \
# 14                 120.0             18.0                        0.0
# 25                   NaN             12.0                        0.0
# 46                 120.0             18.0                        0.0
# 49                   NaN             12.0                        0.0
# 72                 120.0             12.0                        0.0
#
#     rear_camera_mp  rear_camera_secondary_mp  rear_camera_tertiary_mp  \
# 14            48.0                      48.0                     18.0
# 25            48.0                      12.0                     12.0
# 46            48.0                      48.0                     48.0
# 49            48.0                      12.0                     12.0
# 72            48.0                      48.0                     12.0
#
#     rear_camera_count  card_supported operating_system  \
# 14                  2               0          iOS v26
# 25                  2               0          iOS v18
# 46                  3               0          iOS v26
# 49                  2               0          iOS v17
# 72                  3               0          iOS v18
#
#                                                               Product_Link  \
# 14          https://www.smartprix.com/mobiles/apple-iphone-17-ppd1sq07ludi
# 25          https://www.smartprix.com/mobiles/apple-iphone-16-ppd1rbi06dkt
# 46  https://www.smartprix.com/mobiles/apple-iphone-17-pro-max-ppd1mutp9pmm
# 49          https://www.smartprix.com/mobiles/apple-iphone-15-ppd1i7vu80cl
# 72      https://www.smartprix.com/mobiles/apple-iphone-16-pro-ppd19v91cy8p
#
#                                                                      Image_URL  \
# 14      https://cdn1.smartprix.com/rx-ibdkLUIMc-w280-h280/apple-iphone-17.webp
# 25      https://cdn1.smartprix.com/rx-i2e85bq8q-w280-h280/apple-iphone-16.webp
# 46  https://cdn1.smartprix.com/rx-ipwKK83hK-w280-h280/apple-iphone-17-pro.webp
# 49      https://cdn1.smartprix.com/rx-iWLT056zS-w280-h280/apple-iphone-15.webp
# 72  https://cdn1.smartprix.com/rx-i2up0xlk8-w280-h280/apple-iphone-16-pro.webp
#
#                                                                                                                                                                                                                                                                                                               Specifications  \
# 14                              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Apple A19, Hexa Core Processor | 8 GB RAM, 256 GB inbuilt | 3692 mAh Battery with Fast Charging | 6.3 inches, 1206 x 2622 px, 120 Hz Display with Small Notch | 48 MP + 48 MP Dual Rear & 18 MP Front Camera | Memory Card Not Supported | iOS v26
# 25                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Bionic A18, Hexa Core, 4.04 GHz Processor | 8 GB RAM, 128 GB inbuilt | 3561 mAh Battery with Fast Charging | 6.1 inches, 1179 x 2556 px Display with Dynamic Island Display | 48 MP + 12 MP Dual Rear & 12 MP Front Camera | Memory Card Not Supported | iOS v18
# 46            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Apple A19 Pro, Hexa Core Processor | 12 GB RAM, 256 GB inbuilt | 4832 mAh Battery with Fast Charging | 6.9 inches, 1320 x 2868 px, 120 Hz Display with Dynamic Island | 48 MP + 48 MP + 48 MP Triple Rear & 18 MP Front Camera | Memory Card Not Supported | iOS v26
# 49                        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Bionic A16, Hexa Core, 3.46 GHz Processor | 6 GB RAM, 128 GB inbuilt | 3349 mAh Battery with Fast Charging | 6.1 inches, 1179 x 2556 px Display with Dynamic Island | 48 MP + 12 MP Dual Rear & 12 MP Front Camera | Memory Card Not Supported | iOS v17
# 72  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC | Bionic A18 Pro, Hexa Core, 4.05 GHz Processor | 8 GB RAM, 128 GB inbuilt | 3582 mAh Battery with Fast Charging | 6.3 inches, 1206 x 2622 px, 120 Hz Display with Dynamic Island | 48 MP + 48 MP + 12 MP Triple Rear & 12 MP Front Camera | Memory Card Not Supported | iOS v18
#
#    device_type
# 14  smartphone
# 25  smartphone
# 46  smartphone
# 49  smartphone
# 72  smartphone

# %%
df['fast_charging_speed_w'].value_counts()
# Out:
# fast_charging_speed_w
# 45.0     137
# 80.0     125
# 25.0     104
# 33.0      92
# 0.0       79
# 18.0      73
# 90.0      53
# 15.0      52
# 44.0      44
# 67.0      37
# 120.0     34
# 100.0     25
# 10.0      22
# 30.0      19
# 68.0      15
# 60.0      10
# 66.0       8
# 65.0       8
# 50.0       7
# 20.0       6
# 70.0       3
# 37.0       2
# 27.0       2
# 125.0      2
# 35.0       2
# 150.0      2
# 75.0       2
# 23.0       1
# 5.0        1
# Name: count, dtype: int64

# %%
df[df['fast_charging_available'] == 0]['fast_charging_speed_w']
# Out:
# 171     0.0
# 344     0.0
# 372     0.0
# 390     0.0
# 391     0.0
# 404     0.0
# 437     0.0
# 445     0.0
# 448     0.0
# 493     0.0
# 494     0.0
# 500     0.0
# 517     0.0
# 527     0.0
# 540     0.0
# 558     0.0
# 561     0.0
# 562     0.0
# 610     0.0
# 637     0.0
# 663     0.0
# 664     0.0
# 665     0.0
# 676     0.0
# 678     0.0
# 680     0.0
# 684     0.0
# 686     0.0
# 695     0.0
# 711     0.0
# 714     0.0
# 715     0.0
# 718     0.0
# 735     0.0
# 736     0.0
# 737     0.0
# 758     0.0
# 768     0.0
# 824     0.0
# 825     0.0
# 827     0.0
# 828     0.0
# 829     0.0
# 832     0.0
# 835     0.0
# 857     0.0
# 875     0.0
# 876     0.0
# 883     0.0
# 886     0.0
# 900     0.0
# 930     0.0
# 939     0.0
# 940     0.0
# 941     0.0
# 942     0.0
# 943     0.0
# 944     0.0
# 945     0.0
# 946     0.0
# 948     0.0
# 949     0.0
# 950     0.0
# 952     0.0
# 959     0.0
# 961     0.0
# 962     0.0
# 966     0.0
# 967     0.0
# 968     0.0
# 970     0.0
# 974     0.0
# 989     0.0
# 990     0.0
# 995     0.0
# 997     0.0
# 1001    0.0
# 1002    0.0
# 1019    0.0
# Name: fast_charging_speed_w, dtype: float64

# %%
df['fast_charging_speed_w'].value_counts()
# Out:
# fast_charging_speed_w
# 45.0     137
# 80.0     125
# 25.0     104
# 33.0      92
# 0.0       79
# 18.0      73
# 90.0      53
# 15.0      52
# 44.0      44
# 67.0      37
# 120.0     34
# 100.0     25
# 10.0      22
# 30.0      19
# 68.0      15
# 60.0      10
# 66.0       8
# 65.0       8
# 50.0       7
# 20.0       6
# 70.0       3
# 37.0       2
# 27.0       2
# 125.0      2
# 35.0       2
# 150.0      2
# 75.0       2
# 23.0       1
# 5.0        1
# Name: count, dtype: int64

# %%
df['fast_charging_speed_w'].value_counts()
# Out:
# fast_charging_speed_w
# 45.0     137
# 80.0     125
# 25.0     104
# 33.0      92
# 0.0       79
# 18.0      73
# 90.0      53
# 15.0      52
# 44.0      44
# 67.0      37
# 120.0     34
# 100.0     25
# 10.0      22
# 30.0      19
# 68.0      15
# 60.0      10
# 66.0       8
# 65.0       8
# 50.0       7
# 20.0       6
# 70.0       3
# 37.0       2
# 27.0       2
# 125.0      2
# 35.0       2
# 150.0      2
# 75.0       2
# 23.0       1
# 5.0        1
# Name: count, dtype: int64

# %% [markdown]
# <span style="font-size: 18px;"> <b>Dealing with Display

# %%
df['display_size_inches'].value_counts()
# Out:
# display_size_inches
# 6.67    176
# 6.70    145
# 6.78     88
# 6.77     57
# 6.74     46
# 6.80     38
# 6.72     37
# 6.90     29
# 6.50     28
# 6.56     26
# 6.75     24
# 6.60     23
# 6.83     21
# 6.55     20
# 6.10     17
# 6.30     17
# 6.88     15
# 2.40     15
# 6.79     13
# 1.80     13
# 6.59     12
# 1.77     11
# 6.57     11
# 2.80     10
# 6.20      9
# 6.43      8
# 6.68      8
# 6.40      8
# 6.58      7
# 2.00      7
# 6.71      7
# 7.60      6
# 6.45      5
# 6.31      5
# 3.00      4
# 6.82      4
# 8.00      4
# 6.53      4
# 6.81      3
# 8.03      3
# 6.44      3
# 4.50      3
# 6.85      2
# 5.00      2
# 6.36      2
# 6.32      2
# 6.62      2
# 3.75      2
# 6.52      2
# 7.82      2
# 6.73      2
# 7.85      1
# 3.20      1
# 6.96      1
# 6.14      1
# 6.18      1
# 6.47      1
# 1.44      1
# 5.50      1
# 6.38      1
# 4.00      1
# 6.26      1
# 5.99      1
# Name: count, dtype: int64

# %%
df['display_size_inches'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['resolution_height'].isnull().sum()
# Out:
# np.int64(9)

# %%
df['resolution_height'].value_counts()
# Out:
# resolution_height
# 2400.0    168
# 1600.0     92
# 2340.0     88
# 2800.0     74
# 2392.0     59
# 2412.0     53
# 2712.0     39
# 1604.0     37
# 1612.0     30
# 2408.0     26
# 320.0      22
# 2640.0     19
# 2460.0     19
# 2780.0     19
# 3120.0     13
# 2772.0     13
# 1650.0     12
# 160.0      11
# 1640.0     11
# 2436.0     11
# 1570.0     10
# 2760.0     10
# 720.0      10
# 240.0       9
# 2622.0      9
# 2372.0      8
# 1608.0      8
# 2720.0      7
# 2868.0      7
# 3168.0      6
# 128.0       6
# 2532.0      6
# 2556.0      5
# 1920.0      5
# 2992.0      5
# 960.0       5
# 2796.0      5
# 3216.0      4
# 2160.0      4
# 3200.0      4
# 2424.0      3
# 2750.0      3
# 3136.0      3
# 640.0       3
# 1080.0      3
# 2184.0      3
# 2736.0      3
# 2856.0      2
# 2280.0      2
# 2480.0      2
# 2670.0      2
# 2440.0      2
# 1280.0      2
# 2652.0      2
# 3088.0      2
# 2520.0      2
# 2376.0      2
# 2406.0      2
# 2664.0      2
# 2176.0      2
# 2700.0      1
# 3080.0      1
# 2296.0      1
# 2246.0      1
# 2152.0      1
# 260.0       1
# 2778.0      1
# 1792.0      1
# 2076.0      1
# 360.0       1
# 3040.0      1
# 2208.0      1
# 854.0       1
# 216.0       1
# 480.0       1
# Name: count, dtype: int64

# %%
df['display_frequency_hz'].value_counts()
# Out:
# display_frequency_hz
# 120.0    655
# 90.0     131
# 144.0     77
# 165.0      6
# Name: count, dtype: int64

# %%
df['display_frequency_hz'].isnull().sum()
# Out:
# np.int64(151)

# %%
# as display rate is usually 60hz so fill the null value with 60hz

df['display_frequency_hz'].fillna(60, inplace=True)
# Out:
# C:\Users\Lappy\AppData\Local\Temp\ipykernel_3328\1093879435.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['display_frequency_hz'].fillna(60, inplace=True)

# %%
df['display_frequency_hz'].value_counts()
# Out:
# display_frequency_hz
# 120.0    655
# 60.0     151
# 90.0     131
# 144.0     77
# 165.0      6
# Name: count, dtype: int64

# %%
df['display_frequency_hz'] = df['display_frequency_hz'].astype(int)

# %% [markdown]
# <span style="font-size: 18px;"> <b>Dealing with camera

# %%
df.columns
# Out:
# Index(['Product_Name', 'brand_name', 'Price', 'Rating', 'Spec_Score',
#        'has_dual_sim', 'has_3g', 'has_4g', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'processor_brand', 'cores',
#        'cpu_speed_ghz', 'ram_gb', 'rom_gb', 'battery_capacity_mah',
#        'fast_charging_available', 'fast_charging_speed_w',
#        'display_size_inches', 'resolution_width', 'resolution_height',
#        'display_frequency_hz', 'front_camera_mp', 'front_camera_secondary_mp',
#        'rear_camera_mp', 'rear_camera_secondary_mp', 'rear_camera_tertiary_mp',
#        'rear_camera_count', 'card_supported', 'operating_system',
#        'Product_Link', 'Image_URL', 'Specifications', 'device_type'],
#       dtype='object')

# %%
df['front_camera_mp'].value_counts()
# Out:
# front_camera_mp
# 16.0     190
# 8.0      177
# 32.0     158
# 50.0     119
# 5.0       87
# 13.0      80
# 12.0      62
# 20.0      29
# 10.0      15
# 18.0      12
# 64.0       5
# 42.0       5
# 10.5       4
# 200.0      3
# 0.3        3
# 40.0       2
# 11.1       2
# 10.8       2
# 48.0       2
# 2.0        1
# Name: count, dtype: int64

# %%
df[(df['front_camera_mp'].isnull() ) & (df['device_type'] == 'smartphone' )] # these are cheap and unique smart phone with no front camera
# Out:
#        Product_Name brand_name  Price  Rating  Spec_Score  has_dual_sim  \
# 390    Peace Mini 4      peace   4749     4.4          40             1
# 610    Peace Mini 5      peace   4199     4.5          37             1
# 824     MTR M16 Pro        mtr   4600     4.3          29             1
# 825  Peace Honor 10      peace   5599     4.7          38             1
# 987  Tecno POP 9 4G      tecno   6499     4.5          55             1
#
#      has_3g  has_4g  has_5g  has_nfc  has_ir_blaster processor_name  \
# 390       1       1       0        0               0          Helio
# 610       1       1       0        0               0          Helio
# 824       1       1       0        0               0            NaN
# 825       1       1       0        0               0          Helio
# 987       1       1       0        0               1      Helio G50
#
#     processor_brand        cores  cpu_speed_ghz  ram_gb  rom_gb  \
# 390           Helio  Single Core          0.001    32.0   3.000
# 610           Helio  Single Core          0.001     3.0  32.000
# 824            None          NaN          0.512     3.0   0.031
# 825           Helio  Single Core          0.001     3.0  32.000
# 987           Helio    Octa Core            NaN     3.0  64.000
#
#      battery_capacity_mah  fast_charging_available  fast_charging_speed_w  \
# 390                  2000                        0                    0.0
# 610                  2000                        0                    0.0
# 824                  2000                        0                    0.0
# 825                  3000                        0                    0.0
# 987                  5000                        1                    NaN
#
#      display_size_inches  resolution_width  resolution_height  \
# 390                 3.75             412.0              960.0
# 610                 3.75             412.0              960.0
# 824                 4.00             480.0              640.0
# 825                 4.50             412.0              960.0
# 987                 6.67             720.0             1600.0
#
#      display_frequency_hz  front_camera_mp  front_camera_secondary_mp  \
# 390                    60              NaN                        0.0
# 610                    60              NaN                        0.0
# 824                    60              NaN                        0.0
# 825                    60              NaN                        0.0
# 987                    90              NaN                        0.0
#
#      rear_camera_mp  rear_camera_secondary_mp  rear_camera_tertiary_mp  \
# 390             8.0                       0.0                      0.0
# 610             8.0                       0.0                      0.0
# 824             5.0                       0.0                      0.0
# 825             8.0                       0.0                      0.0
# 987            13.0                       0.0                      0.0
#
#      rear_camera_count  card_supported operating_system  \
# 390                  1               1          Android
# 610                  1               1      Android v12
# 824                  1               1      Android v13
# 825                  1               1      Android v14
# 987                  1               1      Android v14
#
#                                                       Product_Link  \
# 390    https://www.smartprix.com/mobiles/peace-mini-4-ppd1zddn5yz3
# 610    https://www.smartprix.com/mobiles/peace-mini-5-ppd1yzsadpfy
# 824     https://www.smartprix.com/mobiles/mtr-m16-pro-ppd1g9h6ae7f
# 825  https://www.smartprix.com/mobiles/peace-honor-10-ppd1l9erzgwr
# 987     https://www.smartprix.com/mobiles/tecno-pop-9-ppd1tfiks3ma
#
#                                                                  Image_URL  \
# 390    https://cdn1.smartprix.com/rx-irb7AUZLq-w280-h280/peace-mini-4.webp
# 610    https://cdn1.smartprix.com/rx-iPwXL6hBd-w280-h280/peace-mini-5.webp
# 824     https://cdn1.smartprix.com/rx-inFc4cuJN-w280-h280/mtr-m16-pro.webp
# 825  https://cdn1.smartprix.com/rx-iT7VGKt7u-w280-h280/peace-honor-10.webp
# 987  https://cdn1.smartprix.com/rx-ijgDd1Q30-w280-h280/tecno-pop-9-4g.webp
#
#                                                                                                                                                                                                                                                                                 Specifications  \
# 390                                                                                                Dual Sim, 3G, 4G, Wi-Fi | Helio, Single Core, 1.3 MHz Processor | 32 GB RAM, 3 GB inbuilt | 2000 mAh Battery | 3.75 inches, 412 x 960 px Display | 8 MP Rear Camera | Android | No FM Radio
# 610                                                                                            Dual Sim, 3G, 4G, Wi-Fi | Helio, Single Core, 1.3 MHz Processor | 3 GB RAM, 32 GB inbuilt | 2000 mAh Battery | 3.75 inches, 412 x 960 px Display | 8 MP Rear Camera | Android v12 | No FM Radio
# 824                                                                                            Dual Sim, 3G, 4G, Wi-Fi | Helio, 512 MHz Processor | 3 GB RAM, 32 MB inbuilt | 2000 mAh Battery | 4 inches, 480 x 640 px Display with Punch Hole | 5 MP Rear Camera | Android v13.0 | Bluetooth
# 825                                                                                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi | Helio, Single Core, 1.3 MHz Processor | 3 GB RAM, 32 GB inbuilt | 3000 mAh Battery | 4.5 inches, 412 x 960 px Display | 8 MP Rear Camera | Android v14.0 | No FM Radio
# 987  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster | Helio G50, Octa Core Processor | 3 GB RAM, 64 GB inbuilt | 5000 mAh Battery with Fast Charging | 6.67 inches, 720 x 1600 px, 90 Hz Display with Punch Hole | 13 MP Rear & Main Front Camera | Memory Card Supported, upto 1 TB | Android v14
#
#     device_type
# 390  smartphone
# 610  smartphone
# 824  smartphone
# 825  smartphone
# 987  smartphone

# %% [markdown]
# <span style="font-size: 18px;"> <b>Dealing with front secondary camera

# %%
df['front_camera_secondary_mp'].value_counts()
# Out:
# front_camera_secondary_mp
# 0.0     998
# 4.0       6
# 32.0      5
# 10.0      5
# 20.0      3
# 8.0       2
# 2.0       1
# Name: count, dtype: int64

# %%
df['front_camera_secondary_mp'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <span style="font-size: 18px;"> <b>Dealing with Rear camera

# %%
df['rear_camera_count'].value_counts()
# Out:
# rear_camera_count
# 2    467
# 3    378
# 1    119
# 4     32
# 0     24
# Name: count, dtype: int64

# %%
df['rear_camera_count'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['rear_camera_mp'].value_counts()
# Out:
# rear_camera_mp
# 50.0     634
# 64.0      78
# 48.0      62
# 108.0     47
# 13.0      39
# 200.0     31
# 3.0       26
# 32.0      25
# 0.0       20
# 8.0       20
# 12.0      15
# 2.0        6
# 20.0       4
# 5.0        4
# 16.0       2
# 180.0      1
# 40.0       1
# 6.0        1
# Name: count, dtype: int64

# %%
df['rear_camera_mp'].isnull().sum()
# Out:
# np.int64(4)

# %%
df['rear_camera_secondary_mp'].value_counts()
# Out:
# rear_camera_secondary_mp
# 8.00     262
# 2.00     232
# 0.00     143
# 50.00    133
# 12.00     77
# 5.00      59
# 48.00     32
# 13.00     30
# 0.08      24
# 32.00     11
# 16.00     11
# 40.00      2
# 10.80      2
# 10.00      1
# 20.00      1
# Name: count, dtype: int64

# %%
df['rear_camera_secondary_mp'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['rear_camera_tertiary_mp'].value_counts()
# Out:
# rear_camera_tertiary_mp
# 0.0     247
# 2.0     173
# 8.0     165
# 16.0    104
# 50.0     91
# 32.0     67
# 5.0      44
# 10.0     40
# 12.0     33
# 13.0     18
# 48.0     16
# 20.0     14
# 10.5      4
# 18.0      2
# 10.8      2
# Name: count, dtype: int64

# %%
df['rear_camera_tertiary_mp'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <span style="font-size: 18px;"> <b>Dealing with Os and memory card

# %%
df.columns
# Out:
# Index(['Product_Name', 'brand_name', 'Price', 'Rating', 'Spec_Score',
#        'has_dual_sim', 'has_3g', 'has_4g', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'processor_brand', 'cores',
#        'cpu_speed_ghz', 'ram_gb', 'rom_gb', 'battery_capacity_mah',
#        'fast_charging_available', 'fast_charging_speed_w',
#        'display_size_inches', 'resolution_width', 'resolution_height',
#        'display_frequency_hz', 'front_camera_mp', 'front_camera_secondary_mp',
#        'rear_camera_mp', 'rear_camera_secondary_mp', 'rear_camera_tertiary_mp',
#        'rear_camera_count', 'card_supported', 'operating_system',
#        'Product_Link', 'Image_URL', 'Specifications', 'device_type'],
#       dtype='object')

# %%
df['card_supported'].value_counts()
# Out:
# card_supported
# 1    795
# 0    225
# Name: count, dtype: int64

# %%
df['card_supported'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['operating_system'].value_counts()
# Out:
# operating_system
# Android v15     347
# Android v14     312
# Android v13     100
# Android v12      56
# Android v11      34
# Android v16      30
# iOS v18          16
# iOS v26          12
# Android v10      11
# iOS v17           4
# Android v9        3
# iOS v16           3
# Symbian           2
# Symbian v30       2
# Android v8        2
# Android v6.1      2
# iOS v2.3          1
# iOS v15           1
# Android           1
# Android v7.2      1
# Android v6        1
# iOS v13           1
# Symbian v9        1
# Name: count, dtype: int64

# %%
temp_df = df[df['operating_system'] == 'Android v6.1']

# %%
df.loc[temp_df.index, 'operating_system'] = 'Android v6'

# %%
df['operating_system'].value_counts()
# Out:
# operating_system
# Android v15     347
# Android v14     312
# Android v13     100
# Android v12      56
# Android v11      34
# Android v16      30
# iOS v18          16
# iOS v26          12
# Android v10      11
# iOS v17           4
# iOS v16           3
# Android v9        3
# Android v6        3
# Android v8        2
# Symbian v30       2
# Symbian           2
# iOS v15           1
# Android           1
# iOS v2.3          1
# iOS v13           1
# Android v7.2      1
# Symbian v9        1
# Name: count, dtype: int64

# %% [markdown]
# ---
# ---
# ---
# ---

# %%
# Reset row and column display limits
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# Reset cell content width limit
pd.reset_option('display.max_colwidth')

# %%
df.to_csv('smartprix_mobiles_cleaned_final.csv', index=False)
