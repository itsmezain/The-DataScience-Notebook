# %% [markdown]
# # <center> <b> Database Fundamentals

# %% [markdown]
# Until now we have studied:
# Python ➡ Numpy ➡ Pandas ➡ Data Vis ➡ EDA ➡ SQL

# %% [markdown]
# Before starting the SQL we are gonna study:
# 1. About Databases (theory)
#
# > Imp Note: Practice is important for SQL and also we are studying SQL from the pov of Data Analyst, not of SDE

# %% [markdown]
# # <Center> 1- What is Data and Importance of Data

# %% [markdown]
# <h2>Data and Its Importance</h2>
#
# <p>Great topic to start your database journey 👍<br>
# If you deeply understand <strong>Data and its Importance</strong>, databases will make much more sense later.</p>
#
# <p>I’ll give you <strong>complete, structured, exam-ready + practical notes</strong> so nothing important is left out.</p>
#
# <hr>
#
# <h1>📘 1️⃣ What is Data?</h1>
#
# <h2>✅ Definition of Data</h2>
#
# <p><strong>Data is raw, unprocessed facts, figures, or observations about objects, events, or entities.</strong></p>
#
# <p>It can be:</p>
#
# <ul>
# <li>Numbers</li>
# <li>Text</li>
# <li>Images</li>
# <li>Audio</li>
# <li>Video</li>
# <li>Symbols</li>
# <li>Measurements</li>
# <li>Records</li>
# </ul>
#
# <p>👉 In simple words:</p>
#
# <blockquote>
# <strong>Data = Raw facts without context or meaning</strong>
# </blockquote>
#
# <hr>
#
# <h2>✅ Examples of Data</h2>
#
# <ul>
# <li><code>25</code> (just a number)</li>
# <li><code>Ali</code></li>
# <li><code>101</code></li>
# <li><code>12/01/2025</code></li>
# <li><code>85 kg</code></li>
# <li><code>Yes/No</code></li>
# <li>A photo</li>
# <li>A voice recording</li>
# </ul>
#
# <p>Individually, these may not tell a story.</p>
#
# <hr>
#
# <h2>✅ Data vs Information (VERY IMPORTANT)</h2>
#
# <p>Many students confuse this.</p>
#
# <h3>🔹 Data</h3>
#
# <p>Raw facts.</p>
#
# <p>Example:</p>
#
# <pre><code>25, 30, 35
# </code></pre>
#
# <h3>🔹 Information</h3>
#
# <p>Processed data that has meaning.</p>
#
# <p>Example:</p>
#
# <pre><code>Average age of students = 30
# </code></pre>
#
# <p>👉 Formula:</p>
#
# <h1>⭐ Information = Processed Data + Context + Meaning</h1>
#
# <hr>
#
# <h2>✅ Characteristics of Data</h2>
#
# <p>Good data should have:</p>
#
# <h3>1️⃣ Accuracy</h3>
# <p>Correct and error-free<br>
# Example: Correct marks of a student.</p>
#
# <h3>2️⃣ Completeness</h3>
# <p>No missing values<br>
# Example: Student record has name, roll no, marks.</p>
#
# <h3>3️⃣ Consistency</h3>
# <p>Same format across systems<br>
# Example: Date always in DD/MM/YYYY.</p>
#
# <h3>4️⃣ Reliability</h3>
# <p>Trusted source<br>
# Example: Government census data.</p>
#
# <h3>5️⃣ Relevance</h3>
# <p>Useful for the purpose<br>
# Example: Height data is irrelevant for a math test.</p>
#
# <h3>6️⃣ Timeliness</h3>
# <p>Up-to-date<br>
# Example: Current stock price vs old price.</p>
#
# <hr>
#
# <h2>✅ Types of Data</h2>
#
# <h3>🔹 1. Based on Nature</h3>
#
# <h3>📌 Qualitative Data (Categorical)</h3>
#
# <p>Non-numeric data.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Gender</li>
# <li>Color</li>
# <li>Name</li>
# <li>City</li>
# </ul>
#
# <hr>
#
# <h3>📌 Quantitative Data (Numeric)</h3>
#
# <h4>➤ Discrete</h4>
#
# <p>Countable numbers<br>
# Example:</p>
#
# <ul>
# <li>Number of students</li>
# <li>Number of cars</li>
# </ul>
#
# <h4>➤ Continuous</h4>
#
# <p>Measurable numbers<br>
# Example:</p>
#
# <ul>
# <li>Height</li>
# <li>Weight</li>
# <li>Temperature</li>
# </ul>
#
# <hr>
#
# <h3>🔹 2. Based on Source</h3>
#
# <h3>📌 Primary Data</h3>
#
# <p>Collected first-hand.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Surveys</li>
# <li>Interviews</li>
# <li>Experiments</li>
# </ul>
#
# <hr>
#
# <h3>📌 Secondary Data</h3>
#
# <p>Already collected by others.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Research papers</li>
# <li>Government reports</li>
# <li>Websites</li>
# </ul>
#
# <hr>
#
# <h3>🔹 3. Based on Structure</h3>
#
# <h3>📌 Structured Data</h3>
#
# <p>Highly organized<br>
# Stored in tables.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>SQL databases</li>
# <li>Excel sheets</li>
# </ul>
#
# <hr>
#
# <h3>📌 Semi-Structured Data</h3>
#
# <p>Some organization.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>JSON</li>
# <li>XML</li>
# <li>Emails</li>
# </ul>
#
# <hr>
#
# <h3>📌 Unstructured Data</h3>
#
# <p>No fixed format.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Videos</li>
# <li>Images</li>
# <li>Social media posts</li>
# </ul>
#
# <p>👉 80–90% of world data is unstructured.</p>
#
# <hr>
#
# <h2>✅ Forms of Data Representation</h2>
#
# <ul>
# <li>Text</li>
# <li>Numbers</li>
# <li>Images</li>
# <li>Audio</li>
# <li>Video</li>
# <li>Symbols</li>
# <li>Binary (0s and 1s inside computers)</li>
# </ul>
#
# <hr>
#
# <h1>📘 2️⃣ Importance of Data</h1>
#
# <p>This is where real-world value comes in 💡</p>
#
# <hr>
#
# <h2>✅ 1. Decision Making</h2>
#
# <p>Organizations use data to make smart decisions.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Business chooses products based on sales data</li>
# <li>Doctors decide treatment using patient data</li>
# <li>Governments plan policies using population data</li>
# </ul>
#
# <p>👉 <strong>Data-driven decisions are more accurate than guesswork.</strong></p>
#
# <hr>
#
# <h2>✅ 2. Business Growth</h2>
#
# <p>Companies use data to:</p>
#
# <ul>
# <li>Understand customers</li>
# <li>Improve products</li>
# <li>Predict trends</li>
# <li>Increase profit</li>
# </ul>
#
# <p>Example:<br>
# Amazon recommending products using your data.</p>
#
# <hr>
#
# <h2>✅ 3. Scientific Research</h2>
#
# <p>Research depends on data.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Medical studies</li>
# <li>Climate research</li>
# <li>Space exploration</li>
# </ul>
#
# <p>No data = No research.</p>
#
# <hr>
#
# <h2>✅ 4. Planning and Forecasting</h2>
#
# <p>Data helps predict the future.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Weather forecasting</li>
# <li>Stock market analysis</li>
# <li>Demand prediction in business</li>
# </ul>
#
# <hr>
#
# <h2>✅ 5. Performance Measurement</h2>
#
# <p>Data helps measure success.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Student grades</li>
# <li>Employee performance</li>
# <li>Website analytics</li>
# </ul>
#
# <hr>
#
# <h2>✅ 6. Personalization</h2>
#
# <p>Modern apps use data to personalize experience.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>YouTube recommendations</li>
# <li>Netflix suggestions</li>
# <li>Spotify playlists</li>
# </ul>
#
# <hr>
#
# <h2>✅ 7. Automation & AI</h2>
#
# <p>AI and ML run on data.</p>
#
# <p>👉 <strong>No data = No AI</strong></p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Chatbots</li>
# <li>Self-driving cars</li>
# <li>Face recognition</li>
# </ul>
#
# <hr>
#
# <h2>✅ 8. Problem Solving</h2>
#
# <p>Data helps identify problems.</p>
#
# <p>Example:<br>
# Low sales data → Investigate cause.</p>
#
# <hr>
#
# <h2>✅ 9. Competitive Advantage</h2>
#
# <p>Companies with better data win.</p>
#
# <p>Example:<br>
# Google, Amazon, Meta use massive data.</p>
#
# <hr>
#
# <h2>✅ 10. Record Keeping</h2>
#
# <p>Data stores history.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Banking records</li>
# <li>Medical history</li>
# <li>Academic records</li>
# </ul>
#
# <hr>
#
# <h1>📘 Real-Life Importance Examples</h1>
#
# <h3>🏥 Healthcare</h3>
#
# <ul>
# <li>Patient history</li>
# <li>Disease prediction</li>
# <li>Drug research</li>
# </ul>
#
# <hr>
#
# <h3>🏫 Education</h3>
#
# <ul>
# <li>Student performance tracking</li>
# <li>Personalized learning</li>
# </ul>
#
# <hr>
#
# <h3>🏦 Banking</h3>
#
# <ul>
# <li>Fraud detection</li>
# <li>Credit scoring</li>
# </ul>
#
# <hr>
#
# <h3>🛒 E-commerce</h3>
#
# <ul>
# <li>Customer behavior analysis</li>
# <li>Inventory management</li>
# </ul>
#
# <hr>
#
# <h3>🚗 Transportation</h3>
#
# <ul>
# <li>Traffic management</li>
# <li>Route optimization</li>
# </ul>
#
# <hr>
#
# <h1>📘 Data in the Digital Era</h1>
#
# <p>We live in the <strong>Data Age</strong>.</p>
#
# <h3>🔥 Facts:</h3>
#
# <ul>
# <li>Data is called the <strong>"New Oil"</strong></li>
# <li>Big companies rely heavily on data</li>
# <li>Every click generates data</li>
# </ul>
#
# <p>Examples:</p>
#
# <ul>
# <li>Social media activity</li>
# <li>GPS locations</li>
# <li>Online shopping</li>
# </ul>
#
# <hr>
#
# <h1>📘 Why Data Matters for You (as a Data Science Student)</h1>
#
# <p>Since you're into Data Science:</p>
#
# <p>👉 Your entire career depends on data.</p>
#
# <p>You will:</p>
#
# <ul>
# <li>Collect data</li>
# <li>Clean data</li>
# <li>Analyze data</li>
# <li>Model data</li>
# <li>Extract insights</li>
# </ul>
#
# <p>👉 A Data Scientist without data is like a chef without ingredients.</p>
#
# <hr>
#
# <h1>📘 Summary (Exam-Ready Points)</h1>
#
# <p>✅ Data = Raw facts<br>
# ✅ Information = Processed data<br>
# ✅ Types: Qualitative, Quantitative, Structured, Unstructured<br>
# ✅ Good data is accurate, complete, reliable<br>
# ✅ Data helps in decision-making, research, AI, and business<br>
# ✅ Data is the foundation of ML, AI, and analytics<br>
# ✅ Modern world runs on data</p>
#
# <hr>

# %% [markdown]
# # <Center> 2- What are Databases and its application & uses?

# %% [markdown]
# <h2>Introduction to Databases</h2>
#
# <p>Great — now you’re moving to the <strong>core foundation of databases</strong> 👍<br>
# If you master this topic, DBMS, SQL, NoSQL, and Data Science concepts will become much easier.</p>
#
# <p>I’ll give you <strong>complete, structured, exam-ready + practical notes</strong> so nothing important is left out.</p>
#
# <hr>
#
# <h1>📘 2️⃣ What are Databases?</h1>
#
# <hr>
#
# <h2>✅ Definition of a Database</h2>
#
# <p>A <strong>database</strong> is:</p>
#
# <blockquote>
# <strong>An organized collection of related data stored in a structured way so it can be easily accessed, managed, and updated.</strong>
# </blockquote>
#
# <p>👉 Simple meaning:</p>
#
# <p>A database is a <strong>digital storage system for data</strong> where data is stored logically so we can quickly find and use it.</p>
#
# <hr>
#
# <h2>✅ Classic Technical Definition (Exam-Ready)</h2>
#
# <blockquote>
# A database is a collection of interrelated data stored together with minimal redundancy and controlled access to serve multiple applications efficiently.
# </blockquote>
#
# <p>Key ideas in this definition:</p>
#
# <ul>
# <li>Interrelated data</li>
# <li>Minimal redundancy</li>
# <li>Efficient access</li>
# <li>Multi-user support</li>
# </ul>
#
# <hr>
#
# <h2>✅ Real-Life Analogy</h2>
#
# <p>Think of a <strong>library</strong> 📚</p>
#
# <ul>
# <li>Books = Data</li>
# <li>Shelves = Tables</li>
# <li>Catalog system = Database structure</li>
# <li>Librarian = DBMS</li>
# </ul>
#
# <p>Without organization, finding books would be chaos.</p>
#
# <p>👉 Same for databases.</p>
#
# <hr>
#
# <h2>✅ Examples of Databases in Daily Life</h2>
#
# <ul>
# <li>Student records in a university</li>
# <li>Bank customer accounts</li>
# <li>Hospital patient records</li>
# <li>E-commerce product lists</li>
# <li>Social media user profiles</li>
# <li>Mobile contact list</li>
# <li>Railway reservation system</li>
# </ul>
#
# <p>Anywhere data is stored systematically → Database exists.</p>
#
# <hr>
#
# <h1>📘 Key Features of a Database</h1>
#
# <hr>
#
# <h2>✅ 1️⃣ Organized Structure</h2>
#
# <p>Data is stored in a logical format:</p>
#
# <ul>
# <li>Tables</li>
# <li>Rows</li>
# <li>Columns</li>
# <li>Relationships</li>
# </ul>
#
# <p>Example:<br>
# Student Table</p>
#
# <table>
# <tr><th>Roll No</th><th>Name</th><th>Marks</th></tr>
# </table>
#
# <hr>
#
# <h2>✅ 2️⃣ Data Integrity</h2>
#
# <p>Ensures data is:</p>
#
# <ul>
# <li>Accurate</li>
# <li>Consistent</li>
# <li>Valid</li>
# </ul>
#
# <p>Example:<br>
# Age cannot be negative.</p>
#
# <hr>
#
# <h2>✅ 3️⃣ Data Security</h2>
#
# <p>Protects data from:</p>
#
# <ul>
# <li>Unauthorized access</li>
# <li>Data theft</li>
# <li>Data corruption</li>
# </ul>
#
# <p>Example:<br>
# Only bank staff can see customer balance.</p>
#
# <hr>
#
# <h2>✅ 4️⃣ Data Redundancy Control</h2>
#
# <p>Avoids unnecessary duplication.</p>
#
# <p>Bad Example:<br>
# Same student data stored 10 times.</p>
#
# <p>Good Database:<br>
# Stored once and referenced.</p>
#
# <hr>
#
# <h2>✅ 5️⃣ Multi-user Access</h2>
#
# <p>Many users can access simultaneously.</p>
#
# <p>Example:<br>
# ATM + Mobile Banking + Branch system.</p>
#
# <hr>
#
# <h2>✅ 6️⃣ Backup and Recovery</h2>
#
# <p>Database can be restored if:</p>
#
# <ul>
# <li>System crashes</li>
# <li>Data gets deleted</li>
# <li>Power failure happens</li>
# </ul>
#
# <hr>
#
# <h2>✅ 7️⃣ Fast Data Retrieval</h2>
#
# <p>Databases are optimized for quick search.</p>
#
# <p>Example:<br>
# Find a user among millions in milliseconds.</p>
#
# <hr>
#
# <h1>📘 Components of a Database</h1>
#
# <hr>
#
# <h2>✅ 1️⃣ Tables</h2>
#
# <p>Basic unit of storage.</p>
#
# <p>Example:<br>
# Employee Table.</p>
#
# <hr>
#
# <h2>✅ 2️⃣ Records (Rows)</h2>
#
# <p>Each row = one entity.</p>
#
# <p>Example:<br>
# One student’s data.</p>
#
# <hr>
#
# <h2>✅ 3️⃣ Fields (Columns)</h2>
#
# <p>Each column = attribute.</p>
#
# <p>Example:<br>
# Name, Age, Salary.</p>
#
# <hr>
#
# <h2>✅ 4️⃣ Keys</h2>
#
# <p>Used to identify records.</p>
#
# <h3>Primary Key</h3>
#
# <p>Unique identifier.<br>
# Example:<br>
# Roll Number.</p>
#
# <h3>Foreign Key</h3>
#
# <p>Connects two tables.</p>
#
# <hr>
#
# <h2>✅ 5️⃣ Schema</h2>
#
# <p>Blueprint of database structure.</p>
#
# <p>Defines:</p>
#
# <ul>
# <li>Tables</li>
# <li>Columns</li>
# <li>Data types</li>
# <li>Relationships</li>
# </ul>
#
# <hr>
#
# <h1>📘 Types of Databases (Overview)</h1>
#
# <hr>
#
# <h2>✅ 1️⃣ Relational Database (RDBMS)</h2>
#
# <p>Stores data in tables.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>MySQL</li>
# <li>PostgreSQL</li>
# <li>Oracle</li>
# <li>SQL Server</li>
# </ul>
#
# <p>Used for structured data.</p>
#
# <hr>
#
# <h2>✅ 2️⃣ NoSQL Database</h2>
#
# <p>For unstructured/semi-structured data.</p>
#
# <p>Types:</p>
#
# <ul>
# <li>Document DB (MongoDB)</li>
# <li>Key-Value DB (Redis)</li>
# <li>Graph DB (Neo4j)</li>
# <li>Column DB (Cassandra)</li>
# </ul>
#
# <hr>
#
# <h2>✅ 3️⃣ Distributed Database</h2>
#
# <p>Stored across multiple locations.</p>
#
# <p>Example:<br>
# Google systems.</p>
#
# <hr>
#
# <h2>✅ 4️⃣ Cloud Database</h2>
#
# <p>Hosted on cloud.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>AWS RDS</li>
# <li>Google Cloud DB</li>
# <li>Azure SQL</li>
# </ul>
#
# <hr>
#
# <h2>✅ 5️⃣ Object-Oriented Database</h2>
#
# <p>Stores objects instead of tables.</p>
#
# <p>Used in advanced applications.</p>
#
# <hr>
#
# <h1>📘 Applications & Uses of Databases</h1>
#
# <p>This is very important for exams and interviews ⭐</p>
#
# <hr>
#
# <h1>✅ 1️⃣ Banking Systems</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>Account management</li>
# <li>Transactions</li>
# <li>Fraud detection</li>
# <li>ATM systems</li>
# </ul>
#
# <p>Without databases, banks cannot function.</p>
#
# <hr>
#
# <h1>✅ 2️⃣ Healthcare</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>Patient records</li>
# <li>Lab results</li>
# <li>Appointment systems</li>
# <li>Medical history</li>
# </ul>
#
# <hr>
#
# <h1>✅ 3️⃣ Education</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>Student records</li>
# <li>Attendance systems</li>
# <li>Exam results</li>
# <li>Online learning platforms</li>
# </ul>
#
# <hr>
#
# <h1>✅ 4️⃣ E-Commerce</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>Product catalogs</li>
# <li>Customer data</li>
# <li>Order management</li>
# <li>Payment records</li>
# </ul>
#
# <p>Example:<br>
# Amazon, Flipkart.</p>
#
# <hr>
#
# <h1>✅ 5️⃣ Social Media</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>User profiles</li>
# <li>Posts</li>
# <li>Messages</li>
# <li>Friend connections</li>
# </ul>
#
# <p>Example:<br>
# Instagram, Facebook.</p>
#
# <hr>
#
# <h1>✅ 6️⃣ Government</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>Census data</li>
# <li>ID systems</li>
# <li>Tax records</li>
# <li>Voter databases</li>
# </ul>
#
# <hr>
#
# <h1>✅ 7️⃣ Telecommunications</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>Call records</li>
# <li>Billing systems</li>
# <li>Network data</li>
# </ul>
#
# <hr>
#
# <h1>✅ 8️⃣ Transportation</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>Ticket booking</li>
# <li>Flight/train schedules</li>
# <li>GPS tracking</li>
# </ul>
#
# <hr>
#
# <h1>✅ 9️⃣ Business & Enterprises</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>HR systems</li>
# <li>Payroll</li>
# <li>Inventory</li>
# <li>CRM systems</li>
# </ul>
#
# <hr>
#
# <h1>✅ 🔟 Scientific Research</h1>
#
# <p>Uses:</p>
#
# <ul>
# <li>Experimental data</li>
# <li>Simulations</li>
# <li>Research storage</li>
# </ul>
#
# <hr>
#
# <h1>📘 Advantages of Using Databases</h1>
#
# <hr>
#
# <h2>✅ Data Sharing</h2>
#
# <p>Multiple users can use same data.</p>
#
# <hr>
#
# <h2>✅ Reduced Redundancy</h2>
#
# <p>No repeated storage.</p>
#
# <hr>
#
# <h2>✅ Improved Security</h2>
#
# <p>Controlled access.</p>
#
# <hr>
#
# <h2>✅ Better Decision Making</h2>
#
# <p>Data analysis helps planning.</p>
#
# <hr>
#
# <h2>✅ Data Consistency</h2>
#
# <p>Uniform data across system.</p>
#
# <hr>
#
# <h2>✅ Efficient Management</h2>
#
# <p>Easy storage and retrieval.</p>
#
# <hr>
#
# <h1>📘 Limitations of Databases</h1>
#
# <p>(Important for theory questions)</p>
#
# <hr>
#
# <h2>❌ High Cost</h2>
#
# <p>Setup and maintenance expensive.</p>
#
# <hr>
#
# <h2>❌ Complexity</h2>
#
# <p>Requires trained staff.</p>
#
# <hr>
#
# <h2>❌ Security Risks</h2>
#
# <p>If hacked, huge damage.</p>
#
# <hr>
#
# <h2>❌ Backup Needed</h2>
#
# <p>Data loss risk if not backed up.</p>
#
# <hr>
#
# <h1>📘 Database vs File System (Quick Comparison)</h1>
#
# <table>
# <tr><th>File System</th><th>Database</th></tr>
# <tr><td>No relationships</td><td>Supports relationships</td></tr>
# <tr><td>More redundancy</td><td>Less redundancy</td></tr>
# <tr><td>Poor security</td><td>Strong security</td></tr>
# <tr><td>Slow retrieval</td><td>Fast retrieval</td></tr>
# <tr><td>No concurrency</td><td>Multi-user support</td></tr>
# </table>
#
# <hr>
#
# <h1>📘 Summary (Exam-Ready)</h1>
#
# <p>✅ Database = Organized collection of data<br>
# ✅ Features: security, integrity, fast access<br>
# ✅ Components: tables, records, keys<br>
# ✅ Types: RDBMS, NoSQL, Cloud, Distributed<br>
# ✅ Used in banking, healthcare, education, e-commerce<br>
# ✅ Advantages: sharing, security, consistency<br>
# ✅ Databases are backbone of modern IT systems</p>
#
# <hr>

# %% [markdown]
# # <center> 3- Types of Databases? Which you should use.

# %% [markdown]
# <h2>Types of Databases & Which You Should Use</h2>
#
# <p>Great — this is one of the <strong>most important topics in databases</strong> 👍<br>
# If you truly understand <em>types of databases and when to use them</em>, you’ll think like a real data engineer or data scientist.</p>
#
# <p>I’ll give you:</p>
#
# <p>✅ Complete theory<br>
# ✅ Practical understanding<br>
# ✅ Real-world use cases<br>
# ✅ “Which to use” decision rules<br>
# ✅ Exam + interview ready notes</p>
#
# <p>So nothing important is left out.</p>
#
# <hr>
#
# <h1>📘 4️⃣ Types of Databases & Which You Should Use</h1>
#
# <hr>
#
# <h1>✅ What Are “Types of Databases”?</h1>
#
# <p>Different databases are designed for different:</p>
#
# <ul>
# <li>Data formats</li>
# <li>Application needs</li>
# <li>Performance requirements</li>
# <li>Scalability needs</li>
# <li>Query patterns</li>
# </ul>
#
# <p>👉 No single database is best for everything.</p>
#
# <p>That’s why many types exist.</p>
#
# <hr>
#
# <h1>📘 MAIN CLASSIFICATION</h1>
#
# <p>Databases are mainly classified into:</p>
#
# <pre><code>1) Relational (SQL)
# 2) NoSQL
# 3) NewSQL
# 4) Specialized Databases
# </code></pre>
#
# <p>We’ll cover each deeply.</p>
#
# <hr>
#
# <h1>🟦 1️⃣ Relational Databases (SQL Databases)</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>A <strong>Relational Database</strong> stores data in:</p>
#
# <ul>
# <li>Tables (relations)</li>
# <li>Rows (records)</li>
# <li>Columns (fields)</li>
# </ul>
#
# <p>Tables are linked using relationships.</p>
#
# <hr>
#
# <h2>✅ Example Table</h2>
#
# <table>
# <tr><th>ID</th><th>Name</th><th>Age</th></tr>
# </table>
#
# <p>Each row = one record.</p>
#
# <hr>
#
# <h2>✅ Key Concepts</h2>
#
# <ul>
# <li>Primary Key</li>
# <li>Foreign Key</li>
# <li>Joins</li>
# <li>Normalization</li>
# <li>ACID properties</li>
# </ul>
#
# <hr>
#
# <h2>✅ ACID Properties (VERY IMPORTANT)</h2>
#
# <p>Relational DBs guarantee:</p>
#
# <h3>A — Atomicity</h3>
# <p>All or nothing transaction.</p>
#
# <h3>C — Consistency</h3>
# <p>Data remains valid.</p>
#
# <h3>I — Isolation</h3>
# <p>Transactions don’t interfere.</p>
#
# <h3>D — Durability</h3>
# <p>Data stays after crash.</p>
#
# <p>👉 This makes them reliable.</p>
#
# <hr>
#
# <h2>✅ Popular Relational Databases</h2>
#
# <ul>
# <li>MySQL</li>
# <li>PostgreSQL</li>
# <li>Oracle</li>
# <li>SQL Server</li>
# <li>SQLite</li>
# </ul>
#
# <hr>
#
# <h2>✅ Advantages</h2>
#
# <p>✔ Highly structured<br>
# ✔ Strong data integrity<br>
# ✔ Powerful querying (SQL)<br>
# ✔ Reliable transactions<br>
# ✔ Mature technology</p>
#
# <hr>
#
# <h2>❌ Disadvantages</h2>
#
# <p>✖ Hard to scale horizontally<br>
# ✖ Rigid schema<br>
# ✖ Slower for massive data</p>
#
# <hr>
#
# <h2>✅ When to Use (IMPORTANT)</h2>
#
# <p>Use Relational DB when:</p>
#
# <p>✔ Data is structured<br>
# ✔ Relationships matter<br>
# ✔ Transactions must be safe<br>
# ✔ Consistency is critical</p>
#
# <hr>
#
# <h2>✅ Real-World Use</h2>
#
# <ul>
# <li>Banking systems</li>
# <li>ERP systems</li>
# <li>Government records</li>
# <li>E-commerce orders</li>
# <li>Student systems</li>
# </ul>
#
# <hr>
#
# <h1>🟩 2️⃣ NoSQL Databases</h1>
#
# <p>“NoSQL” = Not Only SQL</p>
#
# <p>Designed for:</p>
#
# <ul>
# <li>Big Data</li>
# <li>Flexibility</li>
# <li>High scalability</li>
# <li>Unstructured data</li>
# </ul>
#
# <hr>
#
# <h2>📌 Types of NoSQL Databases</h2>
#
# <hr>
#
# <h1>🔹 A) Document Databases</h1>
#
# <p>Stores data as:</p>
#
# <ul>
# <li>JSON-like documents</li>
# </ul>
#
# <p>Example:</p>
#
# <pre><code>{
#   "name": "Ali",
#   "age": 22
# }
# </code></pre>
#
# <hr>
#
# <h2>Examples</h2>
#
# <ul>
# <li>MongoDB</li>
# <li>CouchDB</li>
# </ul>
#
# <hr>
#
# <h2>Advantages</h2>
#
# <p>✔ Flexible schema<br>
# ✔ Developer-friendly<br>
# ✔ Good for rapid development</p>
#
# <hr>
#
# <h2>When to Use</h2>
#
# <p>✔ Web apps<br>
# ✔ Changing data structure<br>
# ✔ APIs<br>
# ✔ User profiles</p>
#
# <hr>
#
# <h1>🔹 B) Key-Value Databases</h1>
#
# <p>Stores data as:</p>
#
# <pre><code>Key → Value
# </code></pre>
#
# <p>Example:</p>
#
# <pre><code>User123 → {data}
# </code></pre>
#
# <hr>
#
# <h2>Examples</h2>
#
# <ul>
# <li>Redis</li>
# <li>DynamoDB</li>
# </ul>
#
# <hr>
#
# <h2>Advantages</h2>
#
# <p>✔ Extremely fast<br>
# ✔ Simple<br>
# ✔ High performance</p>
#
# <hr>
#
# <h2>When to Use</h2>
#
# <p>✔ Caching<br>
# ✔ Sessions<br>
# ✔ Real-time apps</p>
#
# <hr>
#
# <h1>🔹 C) Column-Family Databases</h1>
#
# <p>Stores data by columns instead of rows.</p>
#
# <hr>
#
# <h2>Examples</h2>
#
# <ul>
# <li>Cassandra</li>
# <li>HBase</li>
# </ul>
#
# <hr>
#
# <h2>Advantages</h2>
#
# <p>✔ Handles huge data<br>
# ✔ High write speed<br>
# ✔ Good for analytics</p>
#
# <hr>
#
# <h2>When to Use</h2>
#
# <p>✔ Big Data<br>
# ✔ IoT<br>
# ✔ Analytics platforms</p>
#
# <hr>
#
# <h1>🔹 D) Graph Databases</h1>
#
# <p>Designed for relationships.</p>
#
# <p>Stores:</p>
#
# <ul>
# <li>Nodes</li>
# <li>Edges</li>
# </ul>
#
# <hr>
#
# <h2>Examples</h2>
#
# <ul>
# <li>Neo4j</li>
# <li>Amazon Neptune</li>
# </ul>
#
# <hr>
#
# <h2>Advantages</h2>
#
# <p>✔ Excellent for relationships<br>
# ✔ Fast graph queries</p>
#
# <hr>
#
# <h2>When to Use</h2>
#
# <p>✔ Social networks<br>
# ✔ Recommendation systems<br>
# ✔ Fraud detection</p>
#
# <hr>
#
# <h1>🟨 3️⃣ NewSQL Databases</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>Modern relational databases that:</p>
#
# <ul>
# <li>Support SQL</li>
# <li>Offer scalability like NoSQL</li>
# <li>Keep ACID guarantees</li>
# </ul>
#
# <hr>
#
# <h2>Examples</h2>
#
# <ul>
# <li>Google Spanner</li>
# <li>CockroachDB</li>
# <li>VoltDB</li>
# </ul>
#
# <hr>
#
# <h2>Advantages</h2>
#
# <p>✔ Best of SQL + NoSQL<br>
# ✔ Scalable<br>
# ✔ Strong consistency</p>
#
# <hr>
#
# <h2>When to Use</h2>
#
# <p>✔ Large-scale enterprise apps<br>
# ✔ Financial systems<br>
# ✔ High-traffic platforms</p>
#
# <hr>
#
# <h1>🟪 4️⃣ Specialized Databases</h1>
#
# <hr>
#
# <h1>🔹 Time-Series Databases</h1>
#
# <p>For time-based data.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>InfluxDB</li>
# <li>TimescaleDB</li>
# </ul>
#
# <p>Use for:<br>
# ✔ Sensors<br>
# ✔ Stock prices<br>
# ✔ Monitoring systems</p>
#
# <hr>
#
# <h1>🔹 Data Warehouse Databases</h1>
#
# <p>For analytics.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Snowflake</li>
# <li>BigQuery</li>
# <li>Redshift</li>
# </ul>
#
# <p>Use for:<br>
# ✔ BI<br>
# ✔ Reporting<br>
# ✔ Analytics</p>
#
# <hr>
#
# <h1>🔹 In-Memory Databases</h1>
#
# <p>Data stored in RAM.</p>
#
# <p>Examples:</p>
#
# <ul>
# <li>Redis</li>
# <li>SAP HANA</li>
# </ul>
#
# <p>Use for:<br>
# ✔ Ultra-fast processing<br>
# ✔ Real-time analytics</p>
#
# <hr>
#
# <h1>📘 Which Database Should You Use? (Decision Guide)</h1>
#
# <hr>
#
# <h2>✅ Use Relational DB if:</h2>
#
# <p>✔ Data is structured<br>
# ✔ Strong consistency needed<br>
# ✔ Complex queries<br>
# ✔ Financial data</p>
#
# <p>👉 Safe default choice.</p>
#
# <hr>
#
# <h2>✅ Use Document DB if:</h2>
#
# <p>✔ Schema changes often<br>
# ✔ JSON data<br>
# ✔ Web/mobile apps</p>
#
# <hr>
#
# <h2>✅ Use Key-Value DB if:</h2>
#
# <p>✔ Need speed<br>
# ✔ Caching<br>
# ✔ Sessions</p>
#
# <hr>
#
# <h2>✅ Use Graph DB if:</h2>
#
# <p>✔ Relationships are core<br>
# ✔ Social networks<br>
# ✔ Recommendations</p>
#
# <hr>
#
# <h2>✅ Use Column DB if:</h2>
#
# <p>✔ Big Data<br>
# ✔ High write volume<br>
# ✔ Analytics</p>
#
# <hr>
#
# <h2>✅ Use Data Warehouse if:</h2>
#
# <p>✔ Business intelligence<br>
# ✔ Large analytics queries</p>
#
# <hr>
#
# <h1>📘 Real-World Examples</h1>
#
# <hr>
#
# <h3>Netflix</h3>
#
# <p>Uses:</p>
#
# <ul>
# <li>Cassandra (Big Data)</li>
# <li>MySQL (transactions)</li>
# </ul>
#
# <hr>
#
# <h3>Amazon</h3>
#
# <p>Uses:</p>
#
# <ul>
# <li>DynamoDB</li>
# <li>Aurora</li>
# <li>Redshift</li>
# </ul>
#
# <hr>
#
# <h3>Facebook</h3>
#
# <p>Uses:</p>
#
# <ul>
# <li>MySQL</li>
# <li>Graph DBs</li>
# <li>RocksDB</li>
# </ul>
#
# <hr>
#
# <h1>📘 SQL vs NoSQL Quick Comparison</h1>
#
# <table>
# <tr><th>SQL</th><th>NoSQL</th></tr>
# <tr><td>Structured</td><td>Flexible</td></tr>
# <tr><td>Fixed schema</td><td>Dynamic schema</td></tr>
# <tr><td>ACID</td><td>Often BASE</td></tr>
# <tr><td>Vertical scaling</td><td>Horizontal scaling</td></tr>
# <tr><td>Strong consistency</td><td>Eventual consistency</td></tr>
# </table>
#
# <hr>
#
# <h1>📘 Beginner Advice (VERY PRACTICAL)</h1>
#
# <p>Since you're learning:</p>
#
# <h2>✅ Start with:</h2>
#
# <p>👉 Relational DB (MySQL/PostgreSQL)</p>
#
# <p>Why?</p>
#
# <ul>
# <li>Foundation for all DB knowledge</li>
# <li>Required in interviews</li>
# <li>SQL is universal</li>
# </ul>
#
# <hr>
#
# <h2>✅ Then learn:</h2>
#
# <p>👉 MongoDB (Document DB)</p>
#
# <p>Why?</p>
#
# <ul>
# <li>Very popular</li>
# <li>Used in modern apps</li>
# </ul>
#
# <hr>
#
# <h2>✅ Later explore:</h2>
#
# <p>👉 Redis, Cassandra, Graph DB</p>
#
# <hr>
#
# <h1>📘 Golden Rule</h1>
#
# <blockquote>
# <strong>Choose database based on problem, not trend.</strong>
# </blockquote>
#
# <hr>
#
# <h1>📘 Summary (Exam-Ready)</h1>
#
# <p>✅ Types: Relational, NoSQL, NewSQL, Specialized<br>
# ✅ NoSQL types: Document, Key-Value, Column, Graph<br>
# ✅ SQL = consistency & structure<br>
# ✅ NoSQL = scalability & flexibility<br>
# ✅ Graph DB = relationships<br>
# ✅ Data warehouse = analytics<br>
# ✅ Start with SQL, then NoSQL</p>
#
# <hr>

# %% [markdown]
# # <center>4- Relational Databases

# %% [markdown]
# <h2>Relational Databases (Complete Notes)</h2>
#
# <p>Great choice 👍<br>
# <strong>Relational Databases (RDBMS)</strong> are the <em>heart of database systems</em> and the most important topic for exams, interviews, and real-world development.</p>
#
# <p>If you master this, SQL and DBMS will feel easy.</p>
#
# <p>I’ll give you:</p>
#
# <p>✅ Complete theory<br>
# ✅ Core concepts deeply explained<br>
# ✅ Practical understanding<br>
# ✅ Exam-ready notes<br>
# ✅ Interview-ready clarity</p>
#
# <p>So nothing important is left out.</p>
#
# <hr>
#
# <h1>📘 Relational Databases (Complete Notes)</h1>
#
# <hr>
#
# <h1>✅ 1️⃣ What is a Relational Database?</h1>
#
# <h2>🔹 Definition</h2>
#
# <p>A <strong>Relational Database</strong> is a type of database that:</p>
#
# <blockquote>
# Stores data in tables (relations) made of rows and columns, and connects these tables using relationships.
# </blockquote>
#
# <hr>
#
# <h2>🔹 Simple Meaning</h2>
#
# <p>Data is stored in <strong>tables</strong>, and tables are connected to each other logically.</p>
#
# <p>👉 Example:</p>
#
# <p>A university database:</p>
#
# <h3>Students Table</h3>
#
# <table>
# <tr><th>student_id</th><th>name</th><th>dept_id</th></tr>
# </table>
#
# <h3>Departments Table</h3>
#
# <table>
# <tr><th>dept_id</th><th>dept_name</th></tr>
# </table>
#
# <p>Here, <code>dept_id</code> connects both tables.</p>
#
# <p>This connection = <strong>relationship</strong>.</p>
#
# <hr>
#
# <h1>✅ 2️⃣ Why is it called "Relational"?</h1>
#
# <p>Because it is based on <strong>relations between tables</strong>.</p>
#
# <p>👉 A “relation” = a table.</p>
#
# <p>The relational model was proposed by:</p>
#
# <p>📌 <strong>Edgar F. Codd (1970)</strong></p>
#
# <hr>
#
# <h1>✅ 3️⃣ Core Structure of Relational Databases</h1>
#
# <hr>
#
# <h2>🔹 Table (Relation)</h2>
#
# <p>A table stores data.</p>
#
# <p>Example: Employee table.</p>
#
# <hr>
#
# <h2>🔹 Row (Tuple/Record)</h2>
#
# <p>One complete entry.</p>
#
# <p>Example:</p>
#
# <pre><code>101 | Ali | 50000
# </code></pre>
#
# <hr>
#
# <h2>🔹 Column (Attribute/Field)</h2>
#
# <p>A data property.</p>
#
# <p>Example:</p>
#
# <ul>
# <li>Name</li>
# <li>Age</li>
# <li>Salary</li>
# </ul>
#
# <hr>
#
# <h2>🔹 Domain</h2>
#
# <p>Set of allowed values in a column.</p>
#
# <p>Example:<br>
# Age → Only numbers 0–120.</p>
#
# <hr>
#
# <h1>✅ 4️⃣ Keys in Relational Databases (VERY IMPORTANT)</h1>
#
# <hr>
#
# <h2>🔑 1. Primary Key</h2>
#
# <p>A column that:</p>
#
# <p>✔ Uniquely identifies each row<br>
# ✔ Cannot be NULL<br>
# ✔ No duplicates allowed</p>
#
# <p>Example:<br>
# Roll Number.</p>
#
# <hr>
#
# <h2>🔑 2. Foreign Key</h2>
#
# <p>A column that links two tables.</p>
#
# <p>Example:<br>
# <code>dept_id</code> in Students table.</p>
#
# <p>👉 Maintains relationships.</p>
#
# <hr>
#
# <h2>🔑 3. Candidate Key</h2>
#
# <p>Possible primary keys.</p>
#
# <p>Example:<br>
# Email or Aadhaar could both uniquely identify a user.</p>
#
# <hr>
#
# <h2>🔑 4. Composite Key</h2>
#
# <p>Primary key made of multiple columns.</p>
#
# <p>Example:<br>
# (student_id + course_id)</p>
#
# <hr>
#
# <h2>🔑 5. Super Key</h2>
#
# <p>Any column(s) that uniquely identify a record.</p>
#
# <hr>
#
# <h1>✅ 5️⃣ Relationships in Relational Databases</h1>
#
# <hr>
#
# <h2>🔹 1: One-to-One (1:1)</h2>
#
# <p>One record in A ↔ One record in B.</p>
#
# <p>Example:<br>
# Person ↔ Passport.</p>
#
# <hr>
#
# <h2>🔹 2: One-to-Many (1:N)</h2>
#
# <p>One record in A → Many in B.</p>
#
# <p>Example:<br>
# One teacher → Many students.</p>
#
# <hr>
#
# <h2>🔹 3: Many-to-Many (M:N)</h2>
#
# <p>Many records in A ↔ Many in B.</p>
#
# <p>Example:<br>
# Students ↔ Courses.</p>
#
# <p>👉 Implemented using a <strong>junction table</strong>.</p>
#
# <hr>
#
# <h1>✅ 6️⃣ Schema</h1>
#
# <p>Schema = Structure/Blueprint of database.</p>
#
# <p>Defines:</p>
#
# <ul>
# <li>Tables</li>
# <li>Columns</li>
# <li>Data types</li>
# <li>Constraints</li>
# <li>Relationships</li>
# </ul>
#
# <p>👉 Schema rarely changes.</p>
#
# <hr>
#
# <h1>✅ 7️⃣ Constraints</h1>
#
# <p>Rules applied to columns.</p>
#
# <hr>
#
# <h2>Common Constraints</h2>
#
# <h3>✔ NOT NULL</h3>
# <p>Value cannot be empty.</p>
#
# <h3>✔ UNIQUE</h3>
# <p>No duplicates allowed.</p>
#
# <h3>✔ PRIMARY KEY</h3>
# <p>Unique + not null.</p>
#
# <h3>✔ FOREIGN KEY</h3>
# <p>Must exist in referenced table.</p>
#
# <h3>✔ CHECK</h3>
# <p>Value must satisfy condition.</p>
#
# <p>Example:<br>
# Age &gt; 18.</p>
#
# <h3>✔ DEFAULT</h3>
# <p>Auto value if none provided.</p>
#
# <hr>
#
# <h1>✅ 8️⃣ ACID Properties (VERY IMPORTANT)</h1>
#
# <p>Relational DBs guarantee ACID.</p>
#
# <hr>
#
# <h2>🔹 A — Atomicity</h2>
#
# <p>Transaction is all-or-nothing.</p>
#
# <p>Example:<br>
# Money transfer succeeds fully or fails fully.</p>
#
# <hr>
#
# <h2>🔹 C — Consistency</h2>
#
# <p>Database remains valid.</p>
#
# <p>Rules always followed.</p>
#
# <hr>
#
# <h2>🔹 I — Isolation</h2>
#
# <p>Transactions don't interfere.</p>
#
# <p>Multiple users can work safely.</p>
#
# <hr>
#
# <h2>🔹 D — Durability</h2>
#
# <p>Once saved, data stays even after crash.</p>
#
# <hr>
#
# <h1>✅ 9️⃣ Normalization</h1>
#
# <p>Process of organizing data to:</p>
#
# <p>✔ Reduce redundancy<br>
# ✔ Improve integrity</p>
#
# <hr>
#
# <h2>🔹 1NF (First Normal Form)</h2>
#
# <p>✔ No repeating groups<br>
# ✔ Atomic values</p>
#
# <hr>
#
# <h2>🔹 2NF</h2>
#
# <p>✔ In 1NF<br>
# ✔ No partial dependency</p>
#
# <hr>
#
# <h2>🔹 3NF</h2>
#
# <p>✔ In 2NF<br>
# ✔ No transitive dependency</p>
#
# <p>👉 Higher normalization = cleaner database.</p>
#
# <hr>
#
# <h1>✅ 🔟 SQL in Relational Databases</h1>
#
# <p>SQL = Structured Query Language.</p>
#
# <p>Used to:</p>
#
# <ul>
# <li>Insert</li>
# <li>Update</li>
# <li>Delete</li>
# <li>Query data</li>
# </ul>
#
# <hr>
#
# <h2>Basic SQL Operations</h2>
#
# <h3>SELECT</h3>
# <p>Retrieve data.</p>
#
# <h3>INSERT</h3>
# <p>Add data.</p>
#
# <h3>UPDATE</h3>
# <p>Modify data.</p>
#
# <h3>DELETE</h3>
# <p>Remove data.</p>
#
# <hr>
#
# <h1>✅ 1️⃣1️⃣ Advantages of Relational Databases</h1>
#
# <p>✔ Strong consistency<br>
# ✔ High reliability<br>
# ✔ Structured data<br>
# ✔ ACID support<br>
# ✔ Powerful queries<br>
# ✔ Mature technology<br>
# ✔ Great security</p>
#
# <hr>
#
# <h1>✅ 1️⃣2️⃣ Disadvantages</h1>
#
# <p>✖ Hard to scale horizontally<br>
# ✖ Fixed schema<br>
# ✖ Complex design<br>
# ✖ Slower for huge unstructured data</p>
#
# <hr>
#
# <h1>✅ 1️⃣3️⃣ Popular Relational Databases</h1>
#
# <ul>
# <li>MySQL</li>
# <li>PostgreSQL</li>
# <li>Oracle DB</li>
# <li>Microsoft SQL Server</li>
# <li>SQLite</li>
# <li>MariaDB</li>
# </ul>
#
# <hr>
#
# <h1>✅ 1️⃣4️⃣ Real-World Applications</h1>
#
# <h2>🏦 Banking</h2>
# <p>Transactions, accounts.</p>
#
# <hr>
#
# <h2>🏫 Education</h2>
# <p>Student records.</p>
#
# <hr>
#
# <h2>🛒 E-commerce</h2>
# <p>Orders, payments.</p>
#
# <hr>
#
# <h2>🏥 Healthcare</h2>
# <p>Patient records.</p>
#
# <hr>
#
# <h2>🏢 Enterprises</h2>
# <p>HR, payroll.</p>
#
# <hr>
#
# <h1>✅ 1️⃣5️⃣ When to Use Relational Databases</h1>
#
# <p>Use when:</p>
#
# <p>✔ Data is structured<br>
# ✔ Relationships matter<br>
# ✔ Transactions must be safe<br>
# ✔ Consistency is critical<br>
# ✔ Complex queries needed</p>
#
# <hr>
#
# <h1>✅ 1️⃣6️⃣ When NOT to Use</h1>
#
# <p>Avoid when:</p>
#
# <p>✖ Data is unstructured<br>
# ✖ Schema changes frequently<br>
# ✖ Need massive scalability<br>
# ✖ Real-time big data systems</p>
#
# <hr>
#
# <h1>✅ 1️⃣7️⃣ Relational vs NoSQL (Quick)</h1>
#
# <table>
# <tr><th>Relational</th><th>NoSQL</th></tr>
# <tr><td>Tables</td><td>Flexible formats</td></tr>
# <tr><td>Fixed schema</td><td>Dynamic schema</td></tr>
# <tr><td>ACID</td><td>Often BASE</td></tr>
# <tr><td>SQL</td><td>No fixed language</td></tr>
# <tr><td>Strong consistency</td><td>Eventual consistency</td></tr>
# </table>
#
# <hr>
#
# <h1>✅ 1️⃣8️⃣ Beginner Practical Advice</h1>
#
# <p>Since you're learning databases:</p>
#
# <h2>Step 1:</h2>
# <p>Learn SQL deeply.</p>
#
# <h2>Step 2:</h2>
# <p>Practice MySQL/PostgreSQL.</p>
#
# <h2>Step 3:</h2>
# <p>Build small projects:</p>
#
# <ul>
# <li>Student DB</li>
# <li>Library system</li>
# <li>E-commerce DB</li>
# </ul>
#
# <hr>
#
# <h1>📘 Final Summary (Exam-Ready)</h1>
#
# <p>✅ Relational DB = Tables + relationships<br>
# ✅ Key elements: rows, columns, keys<br>
# ✅ ACID ensures reliability<br>
# ✅ Normalization removes redundancy<br>
# ✅ SQL is used to manage data<br>
# ✅ Best for structured and transactional data<br>
# ✅ Used in banking, education, e-commerce</p>
#
# <hr>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <CENTER>5- What is DBMS?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2>Database Management System (DBMS)</h2>
#
# <p>Great 👍<br>
# Now you’re entering the <strong>heart of database theory</strong>.</p>
#
# <p>If you fully understand <strong>DBMS and its core functionalities</strong>, you’ll understand how MySQL, PostgreSQL, Oracle, etc. actually work behind the scenes.</p>
#
# <p>I’ll give you:</p>
#
# <p>✅ Complete theory<br>
# ✅ Simple explanations<br>
# ✅ Exam-ready points<br>
# ✅ Interview-ready clarity<br>
# ✅ Structured notes</p>
#
# <p>So nothing important is left out.</p>
#
# <hr>
#
# <h1>📘 6️⃣ What is DBMS?</h1>
#
# <hr>
#
# <h1>✅ Definition of DBMS</h1>
#
# <h2>🔹 Technical Definition (Exam-Ready)</h2>
#
# <blockquote>
# A <strong>Database Management System (DBMS)</strong> is software that allows users to define, create, maintain, and control access to a database.
# </blockquote>
#
# <hr>
#
# <h2>🔹 Simple Meaning</h2>
#
# <p>A DBMS is a <strong>software that helps you store, manage, and retrieve data from databases easily and safely.</strong></p>
#
# <p>👉 Database = Data storage<br>
# 👉 DBMS = Tool to manage that storage</p>
#
# <hr>
#
# <h2>🔹 Real-Life Analogy</h2>
#
# <p>Think of a <strong>library</strong> 📚</p>
#
# <ul>
# <li>Books = Data</li>
# <li>Library = Database</li>
# <li>Librarian = DBMS</li>
# </ul>
#
# <p>The librarian:</p>
#
# <ul>
# <li>Stores books</li>
# <li>Finds books</li>
# <li>Updates records</li>
# <li>Controls who can access</li>
# </ul>
#
# <p>👉 That’s exactly what DBMS does.</p>
#
# <hr>
#
# <h1>✅ Why Do We Need a DBMS?</h1>
#
# <p>Before DBMS, people used file systems.</p>
#
# <p>Problems with file systems:</p>
#
# <p>❌ Data duplication<br>
# ❌ Hard to find data<br>
# ❌ No security<br>
# ❌ No relationships<br>
# ❌ Data inconsistency<br>
# ❌ No multi-user support</p>
#
# <p>👉 DBMS solves all these.</p>
#
# <hr>
#
# <h1>✅ Goals of a DBMS</h1>
#
# <p>A DBMS aims to:</p>
#
# <p>✔ Store data efficiently<br>
# ✔ Retrieve data quickly<br>
# ✔ Protect data<br>
# ✔ Avoid duplication<br>
# ✔ Ensure accuracy<br>
# ✔ Support multiple users<br>
# ✔ Provide backup & recovery</p>
#
# <hr>
#
# <h1>✅ Examples of DBMS Software</h1>
#
# <p>Common DBMS tools:</p>
#
# <ul>
# <li>MySQL</li>
# <li>PostgreSQL</li>
# <li>Oracle Database</li>
# <li>Microsoft SQL Server</li>
# <li>SQLite</li>
# <li>MariaDB</li>
# <li>MongoDB (NoSQL DBMS)</li>
# </ul>
#
# <hr>
#
# <h1>✅ Components of DBMS</h1>
#
# <hr>
#
# <h2>🔹 1️⃣ Hardware</h2>
#
# <p>Physical devices:</p>
#
# <ul>
# <li>Servers</li>
# <li>Storage disks</li>
# <li>Memory</li>
# </ul>
#
# <hr>
#
# <h2>🔹 2️⃣ Software</h2>
#
# <p>The DBMS program itself.</p>
#
# <p>Example:<br>
# MySQL software.</p>
#
# <hr>
#
# <h2>🔹 3️⃣ Data</h2>
#
# <p>Actual stored data.</p>
#
# <hr>
#
# <h2>🔹 4️⃣ Procedures</h2>
#
# <p>Rules for using DBMS.</p>
#
# <p>Example:<br>
# Backup procedures.</p>
#
# <hr>
#
# <h2>🔹 5️⃣ Database Access Language</h2>
#
# <p>Used to interact.</p>
#
# <p>Example:<br>
# SQL.</p>
#
# <hr>
#
# <h2>🔹 6️⃣ Users</h2>
#
# <p>People interacting with DBMS:</p>
#
# <h3>DBA (Database Administrator)</h3>
#
# <p>Manages DB.</p>
#
# <h3>Developers</h3>
#
# <p>Write queries/apps.</p>
#
# <h3>End Users</h3>
#
# <p>Use applications.</p>
#
# <hr>
#
# <h1>📘 7️⃣ Core Functionalities of a DBMS</h1>
#
# <p>This is VERY important for exams ⭐</p>
#
# <hr>
#
# <h1>✅ 1️⃣ Data Storage Management</h1>
#
# <p>DBMS stores data in:</p>
#
# <ul>
# <li>Organized format</li>
# <li>Structured tables</li>
# <li>Efficient indexing</li>
# </ul>
#
# <p>👉 Ensures fast retrieval.</p>
#
# <hr>
#
# <h1>✅ 2️⃣ Data Retrieval</h1>
#
# <p>Allows users to get data using queries.</p>
#
# <p>Example:</p>
#
# <pre><code>SELECT * FROM students;
# </code></pre>
#
# <p>👉 Fast and accurate.</p>
#
# <hr>
#
# <h1>✅ 3️⃣ Data Manipulation</h1>
#
# <p>Allows:</p>
#
# <p>✔ Insert<br>
# ✔ Update<br>
# ✔ Delete</p>
#
# <p>(DBMS handles safely)</p>
#
# <hr>
#
# <h1>✅ 4️⃣ Data Definition</h1>
#
# <p>Defines database structure.</p>
#
# <p>Using DDL:</p>
#
# <ul>
# <li>CREATE</li>
# <li>ALTER</li>
# <li>DROP</li>
# </ul>
#
# <p>Example:</p>
#
# <pre><code>CREATE TABLE students;
# </code></pre>
#
# <hr>
#
# <h1>✅ 5️⃣ Security Management</h1>
#
# <p>Protects data from unauthorized access.</p>
#
# <p>Includes:</p>
#
# <p>✔ Authentication (login)<br>
# ✔ Authorization (permissions)<br>
# ✔ Encryption</p>
#
# <p>Example:<br>
# Only admin can delete records.</p>
#
# <hr>
#
# <h1>✅ 6️⃣ Integrity Enforcement</h1>
#
# <p>Ensures data correctness.</p>
#
# <p>Using:</p>
#
# <p>✔ Constraints<br>
# ✔ Validation rules</p>
#
# <p>Example:<br>
# Age cannot be negative.</p>
#
# <hr>
#
# <h1>✅ 7️⃣ Concurrency Control</h1>
#
# <p>Multiple users can access data safely.</p>
#
# <p>Example:<br>
# Two people booking tickets simultaneously.</p>
#
# <p>DBMS prevents conflicts.</p>
#
# <hr>
#
# <h1>✅ 8️⃣ Transaction Management</h1>
#
# <p>A transaction = group of operations.</p>
#
# <p>DBMS ensures:</p>
#
# <p>✔ All succeed OR<br>
# ✔ All fail</p>
#
# <p>(ACID properties)</p>
#
# <p>Example:<br>
# Money transfer.</p>
#
# <hr>
#
# <h1>✅ 9️⃣ Backup and Recovery</h1>
#
# <p>If system crashes:</p>
#
# <p>✔ Data can be restored<br>
# ✔ No data loss</p>
#
# <p>Methods:</p>
#
# <ul>
# <li>Backup copies</li>
# <li>Logs</li>
# </ul>
#
# <hr>
#
# <h1>✅ 🔟 Data Dictionary Management</h1>
#
# <p>DBMS stores metadata:</p>
#
# <ul>
# <li>Table names</li>
# <li>Column types</li>
# <li>Constraints</li>
# </ul>
#
# <p>👉 Like a catalog of database.</p>
#
# <hr>
#
# <h1>✅ 1️⃣1️⃣ Query Processing</h1>
#
# <p>DBMS:</p>
#
# <p>✔ Parses queries<br>
# ✔ Optimizes them<br>
# ✔ Executes efficiently</p>
#
# <p>Example:<br>
# Chooses fastest method to search.</p>
#
# <hr>
#
# <h1>✅ 1️⃣2️⃣ Redundancy Control</h1>
#
# <p>Avoids duplicate data.</p>
#
# <p>Example:<br>
# One student record stored once.</p>
#
# <hr>
#
# <h1>📘 Advantages of DBMS</h1>
#
# <hr>
#
# <p>✔ Reduced redundancy<br>
# ✔ Better security<br>
# ✔ Easy data access<br>
# ✔ Multi-user support<br>
# ✔ Backup & recovery<br>
# ✔ Data consistency<br>
# ✔ Centralized control</p>
#
# <hr>
#
# <h1>📘 Disadvantages of DBMS</h1>
#
# <p>(Important for theory questions)</p>
#
# <hr>
#
# <p>❌ Expensive software<br>
# ❌ Requires training<br>
# ❌ Complex setup<br>
# ❌ High hardware cost</p>
#
# <hr>
#
# <h1>📘 DBMS vs Database (Common Confusion)</h1>
#
# <table>
# <tr><th>Database</th><th>DBMS</th></tr>
# <tr><td>Collection of data</td><td>Software to manage data</td></tr>
# <tr><td>Passive</td><td>Active</td></tr>
# <tr><td>Stores data</td><td>Controls data</td></tr>
# </table>
#
# <p>👉 DBMS manages the database.</p>
#
# <hr>
#
# <h1>📘 DBMS Users (Very Important)</h1>
#
# <hr>
#
# <h2>👤 Database Administrator (DBA)</h2>
#
# <p>Responsibilities:</p>
#
# <p>✔ Security<br>
# ✔ Backup<br>
# ✔ Performance tuning<br>
# ✔ Access control</p>
#
# <hr>
#
# <h2>👨‍💻 Developers</h2>
#
# <p>✔ Write queries<br>
# ✔ Build apps</p>
#
# <hr>
#
# <h2>👥 End Users</h2>
#
# <p>✔ Use applications<br>
# ✔ Retrieve data</p>
#
# <hr>
#
# <h1>📘 Real-World Example</h1>
#
# <h2>🏦 Banking System</h2>
#
# <p>DBMS handles:</p>
#
# <p>✔ Accounts<br>
# ✔ Transactions<br>
# ✔ Security<br>
# ✔ Concurrency<br>
# ✔ Backup</p>
#
# <p>Without DBMS, banking fails.</p>
#
# <hr>
#
# <h1>📘 Exam-Ready Summary</h1>
#
# <hr>
#
# <p>✅ DBMS = Software to manage databases<br>
# ✅ Provides storage, retrieval, security<br>
# ✅ Controls access and integrity<br>
# ✅ Supports transactions & concurrency<br>
# ✅ Offers backup & recovery<br>
# ✅ Reduces redundancy<br>
# ✅ Users: DBA, developers, end-users</p>
#
# <hr>

# %% [markdown]
# # <center> 6- Pratical of MySQL on either jupyter notebook, MySQL workbench or ApacheXampp.

# %% [markdown]
# In this lecture use ApacheXampp: create database and then create table with 3 columns with primary key: then insert 2-3 rows, search the values and also edit/update the values and also delete some values.

# %% [markdown]
# ## MySQL Practical using mysql.connector()

# %%
import mysql.connector

# %%
# in the services.msc turn on the MySQL or MySQL80 service.
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="zain",
)

cursor = conn.cursor()

# %% [markdown]
# <span style="font-size: 18px;"> <b>Checking all the databases in the DBMS

# %%
cursor.execute("Show Databases")

print("List of databases:")

for db in cursor:
    print(db[0])
# Out:
# List of databases:
# dream11_olap
# dsmp
# information_schema
# mysql
# oltp_ipl_database
# performance_schema
# sakila
# sys
# world

# %% [markdown]
# <span style="font-size: 18px;"> <b>Creating a Database

# %%
cursor.execute("CREATE DATABASE IF NOT EXISTS dsmp")

# %%
cursor.execute("Use dsmp")

# %% [markdown]
# # <center>7- Database Keys

# %% [markdown]
# <h2>Database Keys and Types</h2>
#
# <p>Great 👍<br>
# <strong>Database Keys</strong> are one of the MOST IMPORTANT topics in DBMS.<br>
# They are asked in:</p>
#
# <p>✅ Exams<br>
# ✅ Interviews<br>
# ✅ SQL design questions<br>
# ✅ Real-world database design</p>
#
# <p>If you master keys, you understand how databases maintain <strong>uniqueness, relationships, and integrity</strong>.</p>
#
# <p>I’ll give you:</p>
#
# <p>✔ Complete theory<br>
# ✔ Clear examples<br>
# ✔ Exam-ready definitions<br>
# ✔ Practical understanding<br>
# ✔ Common mistakes<br>
# ✔ Interview-level clarity</p>
#
# <p>So nothing is left out.</p>
#
# <hr>
#
# <h1>📘 10️⃣ Database Keys (Complete Notes)</h1>
#
# <hr>
#
# <h1>✅ 1️⃣ What is a Database Key?</h1>
#
# <h2>🔹 Definition (Exam-Ready)</h2>
#
# <blockquote>
# A <strong>database key</strong> is an attribute (or set of attributes) used to uniquely identify a record in a table and/or establish relationships between tables.
# </blockquote>
#
# <hr>
#
# <h2>🔹 Simple Meaning</h2>
#
# <p>A key is a column (or group of columns) that helps:</p>
#
# <p>✔ Identify rows uniquely<br>
# ✔ Connect tables<br>
# ✔ Maintain data accuracy</p>
#
# <hr>
#
# <h2>🔹 Example Table</h2>
#
# <h3>STUDENTS Table</h3>
#
# <table>
# <tr><th>Roll_No</th><th>Name</th><th>Email</th><th>Phone</th></tr>
# <tr><td>101</td><td>Ali</td><td>ali@gmail.com</td><td>9999</td></tr>
# <tr><td>102</td><td>Sara</td><td>sara@gmail.com</td><td>8888</td></tr>
# </table>
#
# <p>Here:</p>
#
# <ul>
# <li>Roll_No can identify each student<br>
# 👉 So it can be a key.</li>
# </ul>
#
# <hr>
#
# <h1>✅ 2️⃣ Why Are Keys Important?</h1>
#
# <p>Keys ensure:</p>
#
# <p>✔ No duplicate records<br>
# ✔ Accurate data retrieval<br>
# ✔ Proper relationships<br>
# ✔ Data integrity<br>
# ✔ Efficient searching</p>
#
# <p>👉 Without keys, databases become messy and unreliable.</p>
#
# <hr>
#
# <h1>📘 TYPES OF DATABASE KEYS</h1>
#
# <hr>
#
# <h1>🔑 1️⃣ Super Key</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>A <strong>Super Key</strong> is any column or combination of columns that uniquely identifies a row.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <table>
# <tr><th>Roll_No</th><th>Email</th><th>Name</th></tr>
# </table>
#
# <p>Possible super keys:</p>
#
# <p>* Roll_No<br>
# * Email<br>
# * Roll_No + Name<br>
# * Email + Name</p>
#
# <p>👉 Even extra columns still count if uniqueness is maintained.</p>
#
# <hr>
#
# <h2>✅ Key Idea</h2>
#
# <p>Super key may contain <strong>extra attributes</strong>.</p>
#
# <hr>
#
# <h1>🔑 2️⃣ Candidate Key</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>A <strong>Candidate Key</strong> is a minimal super key.</p>
#
# <p>👉 No unnecessary columns.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <table>
# <tr><th>Roll_No</th><th>Email</th><th>Name</th></tr>
# </table>
#
# <p>Candidate keys:</p>
#
# <p>✔ Roll_No<br>
# ✔ Email</p>
#
# <p>Both uniquely identify rows.</p>
#
# <hr>
#
# <h2>✅ Key Idea</h2>
#
# <p>Minimal & unique.</p>
#
# <hr>
#
# <h1>🔑 3️⃣ Primary Key (VERY IMPORTANT ⭐)</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>A <strong>Primary Key</strong> is the candidate key chosen to uniquely identify each record.</p>
#
# <hr>
#
# <h2>✅ Rules</h2>
#
# <p>✔ Unique<br>
# ✔ NOT NULL<br>
# ✔ Only one per table</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <table>
# <tr><th>Roll_No (PK)</th><th>Name</th></tr>
# </table>
#
# <p>Roll_No = Primary Key.</p>
#
# <hr>
#
# <h2>✅ Real-Life Example</h2>
#
# <p>Aadhaar number<br>
# Passport number<br>
# Employee ID</p>
#
# <hr>
#
# <h2>⚠ Common Mistake</h2>
#
# <p>Primary key:</p>
#
# <p>❌ Cannot repeat<br>
# ❌ Cannot be NULL</p>
#
# <hr>
#
# <h1>🔑 4️⃣ Alternate Key</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>Candidate keys NOT chosen as primary key.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <p>Candidate keys:</p>
#
# <p>* Roll_No<br>
# * Email</p>
#
# <p>If Roll_No = Primary Key<br>
# 👉 Email = Alternate Key</p>
#
# <hr>
#
# <h1>🔑 5️⃣ Composite Key</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>A key made of <strong>multiple columns</strong>.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <h3>ENROLLMENTS Table</h3>
#
# <table>
# <tr><th>Student_ID</th><th>Course_ID</th><th>Grade</th></tr>
# </table>
#
# <p>Neither column alone is unique.</p>
#
# <p>But:</p>
#
# <p>✔ Student_ID + Course_ID<br>
# 👉 Together form composite key.</p>
#
# <hr>
#
# <h2>✅ Used When</h2>
#
# <p>One column alone can't ensure uniqueness.</p>
#
# <hr>
#
# <h1>🔑 6️⃣ Foreign Key (VERY IMPORTANT ⭐)</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>A <strong>Foreign Key</strong> is a column that refers to the primary key of another table.</p>
#
# <p>👉 Creates relationships.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <h3>STUDENTS Table</h3>
#
# <table>
# <tr><th>Student_ID (PK)</th><th>Name</th></tr>
# </table>
#
# <hr>
#
# <h3>COURSES Table</h3>
#
# <table>
# <tr><th>Course_ID</th><th>Student_ID (FK)</th></tr>
# </table>
#
# <p>Student_ID in Courses table<br>
# 👉 References STUDENTS table.</p>
#
# <hr>
#
# <h2>✅ Purpose</h2>
#
# <p>✔ Link tables<br>
# ✔ Maintain referential integrity<br>
# ✔ Prevent invalid data</p>
#
# <hr>
#
# <h2>⚠ Example Rule</h2>
#
# <p>You cannot insert Student_ID = 999<br>
# If 999 doesn't exist in Students table.</p>
#
# <hr>
#
# <h1>🔑 7️⃣ Unique Key</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>Ensures all values are unique.</p>
#
# <hr>
#
# <h2>✅ Difference from Primary Key</h2>
#
# <table>
# <tr><th>Primary Key</th><th>Unique Key</th></tr>
# <tr><td>Only one allowed</td><td>Multiple allowed</td></tr>
# <tr><td>Cannot be NULL</td><td>Can have one NULL (DB dependent)</td></tr>
# </table>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <p>Email column as unique key.</p>
#
# <hr>
#
# <h1>🔑 8️⃣ Natural Key</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>A key from real-world data.</p>
#
# <hr>
#
# <h2>✅ Examples</h2>
#
# <p>* Aadhaar number<br>
# * Passport number<br>
# * Email ID</p>
#
# <hr>
#
# <h2>✅ Pros</h2>
#
# <p>Meaningful data.</p>
#
# <hr>
#
# <h2>❌ Cons</h2>
#
# <p>May change over time.</p>
#
# <p>Example:<br>
# Email can change.</p>
#
# <hr>
#
# <h1>🔑 9️⃣ Surrogate Key</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>Artificial key created by DB.</p>
#
# <p>Usually auto-increment ID.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <table>
# <tr><th>ID</th><th>Name</th></tr>
# <tr><td>1</td><td>Ali</td></tr>
# <tr><td>2</td><td>Sara</td></tr>
# </table>
#
# <p>ID is surrogate key.</p>
#
# <hr>
#
# <h2>✅ Advantages</h2>
#
# <p>✔ Stable<br>
# ✔ Never changes<br>
# ✔ Simple indexing</p>
#
# <hr>
#
# <p>👉 Modern DB design prefers surrogate keys.</p>
#
# <hr>
#
# <h1>🔑 🔟 Secondary Key</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>Non-unique field used for searching.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <p>City column.</p>
#
# <p>Many students can have same city.</p>
#
# <hr>
#
# <h1>📘 Key Comparison Summary</h1>
#
# <table>
# <tr><th>Key Type</th><th>Unique</th><th>NULL Allowed</th><th>Purpose</th></tr>
# <tr><td>Super Key</td><td>Yes</td><td>No</td><td>Identify rows</td></tr>
# <tr><td>Candidate Key</td><td>Yes</td><td>No</td><td>Minimal super key</td></tr>
# <tr><td>Primary Key</td><td>Yes</td><td>No</td><td>Main identifier</td></tr>
# <tr><td>Alternate Key</td><td>Yes</td><td>No</td><td>Backup candidate</td></tr>
# <tr><td>Foreign Key</td><td>No</td><td>Yes</td><td>Link tables</td></tr>
# <tr><td>Composite Key</td><td>Yes</td><td>No</td><td>Multi-column ID</td></tr>
# <tr><td>Unique Key</td><td>Yes</td><td>Sometimes</td><td>Prevent duplicates</td></tr>
# <tr><td>Natural Key</td><td>Yes</td><td>No</td><td>Real-world ID</td></tr>
# <tr><td>Surrogate Key</td><td>Yes</td><td>No</td><td>Artificial ID</td></tr>
# </table>
#
# <hr>
#
# <h1>📘 Real-World Example (Full Understanding)</h1>
#
# <hr>
#
# <h2>E-COMMERCE DATABASE</h2>
#
# <h3>USERS Table</h3>
#
# <table>
# <tr><th>user_id (PK)</th><th>email (Unique)</th><th>name</th></tr>
# </table>
#
# <hr>
#
# <h3>ORDERS Table</h3>
#
# <table>
# <tr><th>order_id (PK)</th><th>user_id (FK)</th><th>amount</th></tr>
# </table>
#
# <hr>
#
# <h3>ORDER_ITEMS Table</h3>
#
# <table>
# <tr><th>order_id</th><th>product_id</th></tr>
# </table>
#
# <p>Composite key:<br>
# ✔ order_id + product_id</p>
#
# <hr>
#
# <h1>📘 Interview-Level Tips ⭐</h1>
#
# <hr>
#
# <h2>✔ Primary vs Unique Key</h2>
#
# <p>Primary:</p>
#
# <p>* Only one<br>
# * No NULL</p>
#
# <p>Unique:</p>
#
# <p>* Many allowed<br>
# * Can allow NULL</p>
#
# <hr>
#
# <h2>✔ Surrogate vs Natural Key</h2>
#
# <p>Surrogate preferred for:</p>
#
# <p>* Performance<br>
# * Stability<br>
# * Simplicity</p>
#
# <hr>
#
# <h2>✔ Foreign Key Importance</h2>
#
# <p>Ensures:<br>
# ✔ No orphan records<br>
# ✔ Data integrity</p>
#
# <hr>
#
# <h1>📘 Common Mistakes Students Make</h1>
#
# <hr>
#
# <p>❌ Thinking primary key can repeat<br>
# ❌ Confusing candidate vs primary<br>
# ❌ Forgetting composite keys<br>
# ❌ Ignoring foreign keys in design</p>
#
# <hr>
#
# <h1>📘 Exam-Ready Summary</h1>
#
# <hr>
#
# <p>✅ Keys uniquely identify rows<br>
# ✅ Primary key = main identifier<br>
# ✅ Candidate keys = possible PKs<br>
# ✅ Foreign key = connects tables<br>
# ✅ Composite key = multiple columns<br>
# ✅ Surrogate key = artificial ID<br>
# ✅ Keys maintain integrity & relationships</p>
#
# <hr>

# %% [markdown]
# # <center>8- Cardinality of Relationships

# %% [markdown]
# <h2>Cardinality of Relationships</h2>
#
# <p>Great 👍<br>
# <strong>Cardinality of Relationships</strong> is a core concept in database design and ER modeling.<br>
# It is heavily asked in:</p>
#
# <p>✅ Exams<br>
# ✅ Interviews<br>
# ✅ ER diagram questions<br>
# ✅ Database design problems</p>
#
# <p>If you truly understand cardinality, you’ll design better databases and avoid common relationship mistakes.</p>
#
# <p>I’ll give you:</p>
#
# <p>✔ Complete theory<br>
# ✔ Clear examples<br>
# ✔ Exam-ready definitions<br>
# ✔ Practical database view<br>
# ✔ Common mistakes<br>
# ✔ Interview clarity</p>
#
# <p>So nothing important is left out.</p>
#
# <hr>
#
# <h1>📘 Cardinality of Relationships (Complete Notes)</h1>
#
# <hr>
#
# <h1>✅ 1️⃣ What is Cardinality?</h1>
#
# <h2>🔹 Definition (Exam-Ready)</h2>
#
# <blockquote>
# <strong>Cardinality specifies the number of instances of one entity that can or must be associated with each instance of another entity in a relationship.</strong>
# </blockquote>
#
# <hr>
#
# <h2>🔹 Simple Meaning</h2>
#
# <p>Cardinality tells us:</p>
#
# <p>👉 <strong>How many records of Table A can relate to Table B</strong></p>
#
# <p>Example:</p>
#
# <ul>
# <li>One student can enroll in many courses</li>
# <li>One course can have many students</li>
# </ul>
#
# <p>This is cardinality.</p>
#
# <hr>
#
# <h1>✅ 2️⃣ Why Cardinality is Important</h1>
#
# <p>Cardinality helps:</p>
#
# <p>✔ Design correct relationships<br>
# ✔ Avoid data duplication<br>
# ✔ Maintain integrity<br>
# ✔ Create proper foreign keys<br>
# ✔ Design efficient schemas</p>
#
# <p>👉 Without cardinality, relationships become wrong.</p>
#
# <hr>
#
# <h1>✅ 3️⃣ Cardinality in ER Model</h1>
#
# <p>In ER diagrams, cardinality defines:</p>
#
# <ul>
# <li>Relationship strength</li>
# <li>Participation rules</li>
# <li>Data structure design</li>
# </ul>
#
# <p>It answers:</p>
#
# <blockquote>
# “How many of one entity relate to another?”
# </blockquote>
#
# <hr>
#
# <h1>📘 4️⃣ Types of Cardinality</h1>
#
# <p>There are <strong>3 main types</strong>:</p>
#
# <p>1️⃣ One-to-One (1:1)<br>
# 2️⃣ One-to-Many (1:N)<br>
# 3️⃣ Many-to-Many (M:N)</p>
#
# <p>(Some books also include Many-to-One, but it’s just the reverse of 1:N.)</p>
#
# <hr>
#
# <h1>🔷 1️⃣ One-to-One (1:1)</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>One record in Entity A relates to <strong>only one</strong> record in Entity B.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <p>Person ↔ Passport</p>
#
# <ul>
# <li>One person → One passport</li>
# <li>One passport → One person</li>
# </ul>
#
# <hr>
#
# <h2>✅ Table Example</h2>
#
# <h3>PERSON Table</h3>
#
# <table>
# <tr><th>person_id</th><th>name</th></tr>
# </table>
#
# <h3>PASSPORT Table</h3>
#
# <table>
# <tr><th>passport_id</th><th>person_id (FK)</th></tr>
# </table>
#
# <p>Each person has one passport.</p>
#
# <hr>
#
# <h2>✅ When Used</h2>
#
# <p>✔ Sensitive data separation<br>
# ✔ Security reasons<br>
# ✔ Optional data storage</p>
#
# <hr>
#
# <h2>⚠ Note</h2>
#
# <p>1:1 relationships are less common.</p>
#
# <p>Often merged into one table.</p>
#
# <hr>
#
# <h1>🔷 2️⃣ One-to-Many (1:N) ⭐ MOST COMMON</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>One record in A relates to <strong>many</strong> records in B.</p>
#
# <p>But each record in B relates to <strong>one</strong> record in A.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <p>Teacher → Students</p>
#
# <ul>
# <li>One teacher teaches many students</li>
# <li>Each student has one teacher</li>
# </ul>
#
# <hr>
#
# <h2>✅ Table Example</h2>
#
# <h3>TEACHER Table</h3>
#
# <table>
# <tr><th>teacher_id</th><th>name</th></tr>
# </table>
#
# <h3>STUDENT Table</h3>
#
# <table>
# <tr><th>student_id</th><th>name</th><th>teacher_id (FK)</th></tr>
# </table>
#
# <p>teacher_id is foreign key in STUDENT table.</p>
#
# <hr>
#
# <h2>✅ Real-Life Examples</h2>
#
# <p>✔ One customer → many orders<br>
# ✔ One department → many employees<br>
# ✔ One author → many books</p>
#
# <hr>
#
# <h2>✅ Implementation Rule</h2>
#
# <p>👉 Foreign key goes on the “many” side.</p>
#
# <hr>
#
# <h1>🔷 3️⃣ Many-to-Many (M:N)</h1>
#
# <hr>
#
# <h2>✅ Definition</h2>
#
# <p>Many records in A relate to many in B.</p>
#
# <hr>
#
# <h2>❌ Problem</h2>
#
# <p>Relational DB cannot directly implement M:N.</p>
#
# <hr>
#
# <h2>✅ Solution: Junction Table</h2>
#
# <p>We break it into two 1:N relationships.</p>
#
# <hr>
#
# <h2>✅ Example</h2>
#
# <h3>STUDENTS</h3>
#
# <table>
# <tr><th>student_id</th><th>name</th></tr>
# </table>
#
# <h3>COURSES</h3>
#
# <table>
# <tr><th>course_id</th><th>course_name</th></tr>
# </table>
#
# <h3>ENROLLMENT (junction table)</h3>
#
# <table>
# <tr><th>student_id (FK)</th><th>course_id (FK)</th></tr>
# </table>
#
# <p>Composite key:<br>
# (student_id + course_id)</p>
#
# <hr>
#
# <h2>✅ Real-Life Examples</h2>
#
# <p>✔ Orders ↔ Products<br>
# ✔ Actors ↔ Movies<br>
# ✔ Doctors ↔ Patients</p>
#
# <hr>
#
# <h1>📘 5️⃣ Minimum & Maximum Cardinality</h1>
#
# <p>Cardinality also defines:</p>
#
# <p>✔ Minimum participation<br>
# ✔ Maximum participation</p>
#
# <hr>
#
# <h2>🔹 Minimum Cardinality</h2>
#
# <p>Minimum number of relationships.</p>
#
# <p>Example:</p>
#
# <ul>
# <li>A student must enroll in <strong>at least 1</strong> course.</li>
# </ul>
#
# <hr>
#
# <h2>🔹 Maximum Cardinality</h2>
#
# <p>Maximum allowed relationships.</p>
#
# <p>Example:</p>
#
# <ul>
# <li>A course can have <strong>many</strong> students.</li>
# </ul>
#
# <hr>
#
# <h2>✅ Notation</h2>
#
# <table>
# <tr><th>Symbol</th><th>Meaning</th></tr>
# <tr><td>0</td><td>Optional</td></tr>
# <tr><td>1</td><td>Mandatory</td></tr>
# <tr><td>N</td><td>Many</td></tr>
# </table>
#
# <hr>
#
# <h2>✅ Examples</h2>
#
# <p>(0,1)</p>
# <p>Optional one</p>
#
# <p>(1,1)</p>
# <p>Exactly one</p>
#
# <p>(0,N)</p>
# <p>Zero or many</p>
#
# <p>(1,N)</p>
# <p>One or many</p>
#
# <hr>
#
# <h1>📘 6️⃣ Participation Constraint (Related Concept)</h1>
#
# <hr>
#
# <h2>🔹 Total Participation</h2>
#
# <p>Every entity must participate.</p>
#
# <p>Example:<br>
# Every student must have a roll number.</p>
#
# <hr>
#
# <h2>🔹 Partial Participation</h2>
#
# <p>Participation optional.</p>
#
# <p>Example:<br>
# Employee may or may not get bonus.</p>
#
# <hr>
#
# <h1>📘 7️⃣ Cardinality vs Degree (Common Confusion)</h1>
#
# <hr>
#
# <h2>✅ Cardinality</h2>
#
# <p>Number of instances in relationship.</p>
#
# <p>Example:<br>
# 1:N</p>
#
# <hr>
#
# <h2>✅ Degree</h2>
#
# <p>Number of entities involved.</p>
#
# <p>Example:<br>
# Binary relationship → 2 entities<br>
# Ternary → 3 entities</p>
#
# <hr>
#
# <h1>📘 8️⃣ Real-World Case Study</h1>
#
# <hr>
#
# <h2>Online Shopping System</h2>
#
# <hr>
#
# <h3>Customer → Orders</h3>
#
# <p>One customer → many orders<br>
# 👉 1:N</p>
#
# <hr>
#
# <h3>Orders ↔ Products</h3>
#
# <p>One order → many products<br>
# One product → many orders<br>
# 👉 M:N (use junction table)</p>
#
# <hr>
#
# <h3>User ↔ Profile</h3>
#
# <p>One user → one profile<br>
# 👉 1:1</p>
#
# <hr>
#
# <h1>📘 9️⃣ Common Mistakes Students Make</h1>
#
# <hr>
#
# <p>❌ Confusing 1:N with M:N<br>
# ❌ Forgetting junction tables<br>
# ❌ Putting foreign key on wrong side<br>
# ❌ Ignoring minimum cardinality<br>
# ❌ Assuming all relationships are many-to-many</p>
#
# <hr>
#
# <h1>📘 🔟 Interview Tips ⭐</h1>
#
# <hr>
#
# <h2>✔ Where to place Foreign Key?</h2>
#
# <p>Always on:<br>
# 👉 The “Many” side.</p>
#
# <hr>
#
# <h2>✔ How to implement M:N?</h2>
#
# <p>👉 Use junction table.</p>
#
# <hr>
#
# <h2>✔ Most common relationship?</h2>
#
# <p>👉 One-to-Many.</p>
#
# <hr>
#
# <h2>✔ Can 1:1 be merged?</h2>
#
# <p>Yes, often merged into one table.</p>
#
# <hr>
#
# <h1>📘 Exam-Ready Summary</h1>
#
# <hr>
#
# <p>✅ Cardinality defines how many entities relate<br>
# ✅ Types: 1:1, 1:N, M:N<br>
# ✅ 1:N is most common<br>
# ✅ M:N requires junction table<br>
# ✅ Cardinality helps correct DB design<br>
# ✅ Foreign key goes on “many” side<br>
# ✅ Minimum & maximum cardinality define participation</p>

# %% [markdown]
# # <center>9- Read 2 blogs

# %%
'''
1- Row vs Column Oriented Databases: https://dataschool.com/data-modeling-101/row-vs-column-oriented-databases/
2- What is redis (read from below)
'''
# Out:
# '\n1- Row vs Column Oriented Databases: https://dataschool.com/data-modeling-101/row-vs-column-oriented-databases/\n2- What is redis (read from below)\n'

# %% [markdown]
# <h2>Redis (In-Memory Database)</h2>
#
# <p>Great 👍<br>
# Now you’re entering a <strong>modern database technology</strong> that is heavily used in real-world systems.</p>
#
# <p><strong>Redis</strong> is extremely popular in:</p>
#
# <p>✅ High-performance systems<br>
# ✅ Scalable web apps<br>
# ✅ Caching layers<br>
# ✅ Real-time applications<br>
# ✅ System design interviews</p>
#
# <p>I’ll give you:</p>
#
# <p>✔ Deep conceptual clarity<br>
# ✔ Practical understanding<br>
# ✔ Architecture insight<br>
# ✔ Use cases<br>
# ✔ Interview-level notes<br>
# ✔ Beginner → Advanced coverage</p>
#
# <p>So nothing important is left out.</p>
#
# <hr>
#
# <h1>📘 What is Redis? (Complete Notes)</h1>
#
# <hr>
#
# <h1>✅ 1️⃣ What is Redis?</h1>
#
# <h2>🔹 Definition (Exam/Interview Ready)</h2>
#
# <blockquote>
# <strong>Redis (Remote Dictionary Server)</strong> is an open-source, in-memory data structure store used as a database, cache, and message broker.
# </blockquote>
#
# <hr>
#
# <h2>🔹 Simple Meaning</h2>
#
# <p>Redis is a <strong>super-fast database that stores data in RAM instead of disk.</strong></p>
#
# <p>👉 Because RAM is very fast → Redis is extremely fast.</p>
#
# <hr>
#
# <h2>🔹 One-line Understanding</h2>
#
# <p>👉 <strong>Redis = Ultra-fast in-memory key-value database</strong></p>
#
# <hr>
#
# <h1>✅ 2️⃣ Why Redis Exists</h1>
#
# <p>Traditional databases:</p>
#
# <p>❌ Slower for real-time needs<br>
# ❌ Disk-based I/O latency<br>
# ❌ Not ideal for caching</p>
#
# <p>Redis was created to:</p>
#
# <p>✔ Provide ultra-low latency<br>
# ✔ Handle massive requests/sec<br>
# ✔ Store temporary or fast-access data</p>
#
# <hr>
#
# <h1>✅ 3️⃣ Key Characteristics of Redis</h1>
#
# <hr>
#
# <h2>⚡ In-Memory Storage</h2>
#
# <p>Stores data in RAM.</p>
#
# <p>Result:<br>
# ✔ Microsecond latency<br>
# ✔ Extremely fast reads/writes</p>
#
# <hr>
#
# <h2>🔑 Key-Value Store</h2>
#
# <p>Data stored as:</p>
#
# <pre><code>Key → Value
# </code></pre>
#
# <p>Example:</p>
#
# <pre><code>"user:101" → "Ali"
# </code></pre>
#
# <hr>
#
# <h2>🧱 Data Structure Store</h2>
#
# <p>Redis supports advanced data structures.</p>
#
# <p>Not just strings!</p>
#
# <hr>
#
# <h2>🔥 High Performance</h2>
#
# <p>Can handle:<br>
# 👉 Millions of operations per second.</p>
#
# <hr>
#
# <h2>💾 Persistence Support</h2>
#
# <p>Even though in-memory, Redis can save data to disk.</p>
#
# <p>So data isn't always lost.</p>
#
# <hr>
#
# <h2>🔁 Replication</h2>
#
# <p>Supports master-slave replication.</p>
#
# <p>Used for:<br>
# ✔ High availability<br>
# ✔ Backup systems</p>
#
# <hr>
#
# <h2>📦 Lightweight</h2>
#
# <p>Simple and efficient design.</p>
#
# <hr>
#
# <h1>✅ 4️⃣ Redis Data Types (VERY IMPORTANT)</h1>
#
# <p>Redis is special because it supports multiple data structures.</p>
#
# <hr>
#
# <h2>🔹 1. Strings</h2>
#
# <p>Most basic type.</p>
#
# <p>Example:</p>
#
# <pre><code>SET name "Ali"
# </code></pre>
#
# <p>Used for:<br>
# ✔ Caching<br>
# ✔ Counters<br>
# ✔ Tokens</p>
#
# <hr>
#
# <h2>🔹 2. Lists</h2>
#
# <p>Ordered collection.</p>
#
# <p>Example:</p>
#
# <pre><code>LPUSH tasks "Task1"
# </code></pre>
#
# <p>Used for:<br>
# ✔ Queues<br>
# ✔ Task lists<br>
# ✔ Messaging</p>
#
# <hr>
#
# <h2>🔹 3. Sets</h2>
#
# <p>Unordered unique values.</p>
#
# <p>Example:</p>
#
# <pre><code>SADD users "Ali"
# </code></pre>
#
# <p>Used for:<br>
# ✔ Unique visitors<br>
# ✔ Tags<br>
# ✔ Membership tracking</p>
#
# <hr>
#
# <h2>🔹 4. Sorted Sets (ZSET)</h2>
#
# <p>Set with scores.</p>
#
# <p>Example:<br>
# Leaderboard.</p>
#
# <p>Used for:<br>
# ✔ Rankings<br>
# ✔ Score systems<br>
# ✔ Priority queues</p>
#
# <hr>
#
# <h2>🔹 5. Hashes</h2>
#
# <p>Key-value pairs inside a key.</p>
#
# <p>Example:</p>
#
# <pre><code>HSET user:1 name "Ali" age 22
# </code></pre>
#
# <p>Used for:<br>
# ✔ User profiles<br>
# ✔ Objects storage</p>
#
# <hr>
#
# <h2>🔹 6. Bitmaps</h2>
#
# <p>Used for bit-level operations.</p>
#
# <p>Used for:<br>
# ✔ Analytics<br>
# ✔ Tracking flags</p>
#
# <hr>
#
# <h2>🔹 7. HyperLogLog</h2>
#
# <p>Used for approximate counting.</p>
#
# <p>Example:<br>
# Unique website visitors.</p>
#
# <hr>
#
# <h2>🔹 8. Streams</h2>
#
# <p>Log-like data structure.</p>
#
# <p>Used for:<br>
# ✔ Event streaming<br>
# ✔ Messaging systems</p>
#
# <hr>
#
# <h1>✅ 5️⃣ How Redis Works (Internals Simplified)</h1>
#
# <hr>
#
# <h2>Step-by-Step</h2>
#
# <p>1️⃣ Client sends request<br>
# 2️⃣ Redis processes in memory<br>
# 3️⃣ Returns result instantly</p>
#
# <p>No heavy disk reads → super fast.</p>
#
# <hr>
#
# <h2>Single-threaded Model</h2>
#
# <p>Redis uses single-threaded event loop.</p>
#
# <p>Why still fast?</p>
#
# <p>✔ No locking overhead<br>
# ✔ Efficient design<br>
# ✔ In-memory operations</p>
#
# <hr>
#
# <h1>✅ 6️⃣ Persistence in Redis</h1>
#
# <p>Redis can save data to disk.</p>
#
# <hr>
#
# <h2>🔹 RDB (Snapshots)</h2>
#
# <p>Takes periodic snapshots.</p>
#
# <p>✔ Fast recovery<br>
# ✔ Less disk usage<br>
# ❌ Possible small data loss</p>
#
# <hr>
#
# <h2>🔹 AOF (Append Only File)</h2>
#
# <p>Logs every write operation.</p>
#
# <p>✔ Safer<br>
# ✔ More durable<br>
# ❌ Larger file size</p>
#
# <hr>
#
# <h1>✅ 7️⃣ Redis Caching (Most Common Use)</h1>
#
# <hr>
#
# <h2>How Caching Works</h2>
#
# <p>Without Redis:<br>
# App → Database (slow)</p>
#
# <p>With Redis:<br>
# App → Redis (fast) → Database (if needed)</p>
#
# <hr>
#
# <h2>Example</h2>
#
# <p>Website loads user profile:</p>
#
# <p>✔ First fetch → DB<br>
# ✔ Store in Redis<br>
# ✔ Next fetch → Redis</p>
#
# <p>👉 Faster performance.</p>
#
# <hr>
#
# <h1>✅ 8️⃣ Pub/Sub Messaging</h1>
#
# <p>Redis supports publish/subscribe.</p>
#
# <p>Example:<br>
# Chat apps.</p>
#
# <p>One service publishes, others subscribe.</p>
#
# <hr>
#
# <h1>✅ 9️⃣ Redis Use Cases (VERY IMPORTANT)</h1>
#
# <hr>
#
# <h2>🚀 1. Caching</h2>
#
# <p>Most popular use.</p>
#
# <p>Examples:<br>
# ✔ Web apps<br>
# ✔ APIs<br>
# ✔ DB query caching</p>
#
# <hr>
#
# <h2>📊 2. Real-Time Analytics</h2>
#
# <p>Track:<br>
# ✔ Page views<br>
# ✔ Clicks<br>
# ✔ Live stats</p>
#
# <hr>
#
# <h2>🎮 3. Gaming</h2>
#
# <p>✔ Leaderboards<br>
# ✔ Real-time scoring<br>
# ✔ Session data</p>
#
# <hr>
#
# <h2>🛒 4. E-commerce</h2>
#
# <p>✔ Shopping carts<br>
# ✔ Recommendations<br>
# ✔ Inventory counters</p>
#
# <hr>
#
# <h2>💬 5. Chat & Messaging</h2>
#
# <p>✔ Pub/Sub systems<br>
# ✔ Notifications</p>
#
# <hr>
#
# <h2>🔐 6. Session Management</h2>
#
# <p>Store user sessions.</p>
#
# <hr>
#
# <h1>✅ 🔟 Advantages of Redis</h1>
#
# <hr>
#
# <p>✔ Extremely fast<br>
# ✔ Supports rich data types<br>
# ✔ Scalable<br>
# ✔ Easy to use<br>
# ✔ Great for caching<br>
# ✔ High availability<br>
# ✔ Real-time processing</p>
#
# <hr>
#
# <h1>❌ 1️⃣1️⃣ Disadvantages</h1>
#
# <hr>
#
# <p>❌ RAM is expensive<br>
# ❌ Not ideal for huge permanent data<br>
# ❌ Single-thread limitation<br>
# ❌ Data loss risk if not persisted</p>
#
# <hr>
#
# <h1>✅ 1️⃣2️⃣ Redis vs Traditional Databases</h1>
#
# <table>
# <tr><th>Redis</th><th>SQL DB</th></tr>
# <tr><td>In-memory</td><td>Disk-based</td></tr>
# <tr><td>Ultra-fast</td><td>Slower</td></tr>
# <tr><td>Key-value</td><td>Table-based</td></tr>
# <tr><td>Temporary data</td><td>Permanent data</td></tr>
# <tr><td>Simple queries</td><td>Complex queries</td></tr>
# </table>
#
# <hr>
#
# <h1>✅ 1️⃣3️⃣ When to Use Redis</h1>
#
# <p>✔ Need ultra-fast speed<br>
# ✔ Caching required<br>
# ✔ Real-time systems<br>
# ✔ Session storage<br>
# ✔ Leaderboards<br>
# ✔ Rate limiting</p>
#
# <hr>
#
# <h1>❌ When NOT to Use Redis</h1>
#
# <p>❌ Long-term storage<br>
# ❌ Very large datasets<br>
# ❌ Complex relational queries</p>
#
# <hr>
#
# <h1>✅ 1️⃣4️⃣ Redis in System Design Interviews ⭐</h1>
#
# <p>Common questions:</p>
#
# <p>✔ How to scale caching?<br>
# 👉 Use Redis.</p>
#
# <p>✔ How to build leaderboard?<br>
# 👉 Sorted sets.</p>
#
# <p>✔ Rate limiting?<br>
# 👉 Redis counters.</p>
#
# <p>✔ Session storage?<br>
# 👉 Redis.</p>
#
# <hr>
#
# <h1>✅ 1️⃣5️⃣ Real-World Companies Using Redis</h1>
#
# <p>Used by:<br>
# ✔ Twitter<br>
# ✔ GitHub<br>
# ✔ Instagram<br>
# ✔ Netflix<br>
# ✔ Amazon</p>
#
# <hr>
#
# <h1>📘 Beginner Practical Advice</h1>
#
# <hr>
#
# <h2>Step 1:</h2>
#
# <p>Learn SQL first (foundation).</p>
#
# <h2>Step 2:</h2>
#
# <p>Learn Redis basics:<br>
# ✔ SET<br>
# ✔ GET<br>
# ✔ EXPIRE<br>
# ✔ DEL</p>
#
# <h2>Step 3:</h2>
#
# <p>Use Redis with Python/Node.</p>
#
# <hr>
#
# <h1>📘 Exam/Interview Summary</h1>
#
# <hr>
#
# <p>✅ Redis = In-memory key-value store<br>
# ✅ Extremely fast<br>
# ✅ Used for caching<br>
# ✅ Supports many data structures<br>
# ✅ Offers persistence options<br>
# ✅ Common in system design<br>
# ✅ Not a replacement for SQL DB<br>
# ✅ Best as a complement</p>
#
# <hr>
