# %% [markdown]
# <center>  <span style="font-size: 48px;"> <b> <i> Tableau

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# <h3><center>The Story of Olympics</h3></center>
#
# <p><strong>Magazine Concept:</strong> <em>The story of Olympics (story)</em></p>
#
# <hr>
#
# <h4>1. Overall Analysis → Dashboard</h4>
# <ul>
#   <li>Map</li>
#   <li>Medal Tally</li>
# </ul>
#
# <h4>2. Overall EDA → Dashboard</h4>
# <ul>
#   <li>Number of Athletes</li>
#   <li>Number of Countries</li>
#   <li>Gender Pie Chart</li>
#   <li>Age Histogram</li>
#   <li>Height and Weight Scatterplot</li>
# </ul>
#
# <h4>3. Country-Wise Analysis → Dashboard</h4>
# <ul>
#   <li>Year-wise Medal Tally</li>
#   <li>Top Athletes</li>
#   <li>Top Sports</li>
# </ul>
